# %%
# Imorting necessary libraries
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Task 1:-

# %%
from collections import defaultdict
from typing import List

# Our Tokenizer Class
class Tokenizer:
    # Class Constructor to declare and initialize variables
    def __init__(self):
        self.vocab = set()  # Vocabulary, unique tokens in the corpus
        self.vocab.add("$")
        self.frequency_corpus = defaultdict(int)  # Unigram counts, frequency of each unique token
        self.merge_rules = []    # All the merge rules learned and to be appended in order as they are learned 

    # a function that learns the vocabulary
    def learn_vocabulary(self, corpus: List[str], num_merges: int):
        # Initialize vocabulary with characters and their frequencies
        
        # Construct a frequency corpus i.e. Unigram counts of unique tokens
        for sentence in corpus:
            for word in sentence.split():
                modified_word = ""
                for char in word:
                    self.vocab.add(char)
                    modified_word = modified_word + char + "-"
                modified_word = modified_word + "$"
                self.frequency_corpus[modified_word] += 1

        # Learn the merge rules
        for merge in range(num_merges):
            pair_frequency = defaultdict(int)     # This stores the character pair frequency for each merge rule iteration 
            
            # Generating pair frequencies
            for word in self.frequency_corpus:
                symbols = word.split("-")
                for i in range(len(symbols) - 1):
                    pair_frequency[(symbols[i], symbols[i + 1])] += 1

            if not pair_frequency:
                break

            # Get the character pair frequency with maximum count
            best_pair = max(pair_frequency, key=pair_frequency.get)
            self.vocab.add(best_pair[0]+best_pair[1])
            
            # Add that pair with maximum frequency in the merge rules if it doesn't exist
            if best_pair not in self.merge_rules:
                self.merge_rules.append(best_pair)

            # Update the frequency corpus for next iteration
            new_frequency_corpus = defaultdict(int)
            for word in self.frequency_corpus:
                new_word = word.replace(best_pair[0]+"-"+best_pair[1], best_pair[0]+best_pair[1])
                new_frequency_corpus[new_word] = self.frequency_corpus[word]
            self.frequency_corpus = new_frequency_corpus
        
        ### WRITING MERGE RULES TO TEXT FILE
        # Clear past contents of the file
        try:
            with open("merge_rules.txt", "w") as file:
                pass
        except Exception as e:
            print(f"Error clearing file: {e}")
            
        # Write all merge_rules to merge_rules.txt for submittables
        for rule in self.merge_rules:
            r = ",".join(rule)
            try:
                with open("merge_rules.txt", "a") as file:
                    file.write(r + "\n")
            except Exception as e:
                print(f"Error writing merge rule to merge_rules.txt: {e}")
            
        
        ### WRITING VOCABULARY TO TEXT FILE
        # Clear past contents of the file
        try:
            with open("vocab.txt", "w") as file:
                pass
        except Exception as e:
            print(f"Error clearing file: {e}")
            
        # Write all tokens found to tokens.txt for submittables
        tokens = list(self.vocab)
        tokens = sorted(tokens, key=lambda x: (len(x), x))
        for token in tokens:
            try:
                with open("vocab.txt", "a") as file:
                    file.write(token + "\n")
            except Exception as e:
                print(f"Error writing token to vocab.txt: {e}")
        
        
    # A fucntion that tokenizes the text based on merge rules
    def tokenize(self, sample: str) -> List[str]:
        actual_tokens = []
        
        # A set to store intermediate tokens
        intermediate_tokens = set()
        
        # Split the snetence into list of words
        sample_list = sample.split()

        for word in sample_list:
            word = word+"$"
            wordpart_list = [] # To keep track of individual characters
            for letter in word:
                wordpart_list.append(letter)
                intermediate_tokens.add(letter)

            # For each rule in merge_rules combine the corresonding pairs of characters in the word
            for rule in self.merge_rules:
                i=0
                while i<len(wordpart_list)-1:
                    if rule[0]+rule[1] == wordpart_list[i]+wordpart_list[i+1]:
                        intermediate_tokens.add(wordpart_list[i]+wordpart_list[i+1])
                        wordpart_list[i] = wordpart_list[i]+wordpart_list[i+1]
                        del wordpart_list[i+1]
                    i = i+1
            # Add the final merged tokens to actual tokens list
            for subpart in wordpart_list:
                actual_tokens.append(subpart)
        print("All found tokens: ", intermediate_tokens)
        
        ### WRITING SAMPLE TOKENS TO TEXT FILE
            
        # Write all tokens found to tokenized_samples.txt for submittables
        try:
            with open("tokenized_samples.txt", "a") as file:
                file.write(",".join(actual_tokens) + "\n")
        except Exception as e:
            print(f"Error writing tokens of sammple to tokenized_samples.txt: {e}") 
        
        
        ### WRITING ALL FOUND TOKENS TO TEXT FILE
            
        # Write all tokens found to tokens.txt for submittables
        tokens = list(intermediate_tokens)
        tokens = sorted(tokens, key=lambda x: (len(x), x))
        for token in tokens:
            try:
                with open("tokens.txt", "a") as file:
                    file.write(token + "\n")
            except Exception as e:
                print(f"Error writing token to tokens.txt: {e}")
             
        print("Tokenized sample: ", actual_tokens)
        return actual_tokens
                


# # Example Usage
# corpus = ["hello", "world", "he", "she", "hers"]
# tokenizer = Tokenizer()
# tokenizer.learn_vocabulary(corpus, num_merges=10)
# sample_text = "helloworld"
# tokens = tokenizer.tokenize(sample_text)
# print(tokens)

# %%
# Read corpus from a text file
# corpus_file_path = r"C:\Users\shree\OneDrive\Desktop\IIITD Sem 4\NLP\A1\corpus.txt"
with open("corpus.txt", 'r', encoding='utf-8') as file:
    corpus = file.read().splitlines()

tokenizer = Tokenizer()
tokenizer.learn_vocabulary(corpus, 10)

# %%
tokenizer.merge_rules
# Out:
# [('s', '$'),
#  ('i', 'n'),
#  ('e', '$'),
#  ('d', '$'),
#  ('e', 'r'),
#  ('e', 'd$'),
#  ('in', 'g'),
#  ('y', '$'),
#  ('ing', '$'),
#  ('o', 'n')]

# %%
tokenizer.vocab
# Out:
# {'$',
#  'a',
#  'b',
#  'c',
#  'd',
#  'd$',
#  'e',
#  'e$',
#  'ed$',
#  'er',
#  'f',
#  'g',
#  'h',
#  'i',
#  'in',
#  'ing',
#  'ing$',
#  'j',
#  'k',
#  'l',
#  'm',
#  'n',
#  'o',
#  'on',
#  'p',
#  'q',
#  'r',
#  's',
#  's$',
#  't',
#  'u',
#  'v',
#  'w',
#  'x',
#  'y',
#  'y$',
#  'z'}

# %%
tokenizer.tokenize("i love nlp ")
# Out:
# All found tokens:  {'i', 'o', 'p', 'e$', '$', 'n', 'l', 'e', 'v'}
# Tokenized sample:  ['i', '$', 'l', 'o', 'v', 'e$', 'n', 'l', 'p', '$']
# ['i', '$', 'l', 'o', 'v', 'e$', 'n', 'l', 'p', '$']

# %%
tokenizer.frequency_corpus
# Out:
# defaultdict(int,
#             {'i-$': 3789,
#              's-t-a-n-d$': 10,
#              'h-er-e$': 37,
#              'f-e-e-l-$': 1637,
#              'e-m-p-t-y$': 9,
#              'a-$': 916,
#              'c-l-a-s-s$': 13,
#              'p-o-s-t-$': 14,
#              'c-o-u-n-t-$': 4,
#              'l-in-k-$': 2,
#              'h-r-e-f-$': 25,
#              'h-t-t-p-$': 30,
#              'm-o-o-s-h-i-l-u-$': 1,
#              'l-i-t-er-a-l-l-y$': 4,
#              'j-u-s-t-$': 226,
#              't-e-x-t-$': 3,
#              't-y-c-h-e-l-l-e$': 1,
#              't-o-$': 1340,
#              's-e-e$': 45,
#              'i-f-$': 134,
#              's-h-e$': 72,
#              'w-a-n-t-s$': 7,
#              'h-a-n-g-$': 1,
#              'o-u-t-$': 113,
#              'b-e-c-a-u-s-e$': 183,
#              'r-e-a-d-ing$': 13,
#              'w-h-a-t-$': 125,
#              'w-r-o-t-e$': 4,
#              'a-b-o-u-t-$': 298,
#              'm-y$': 642,
#              'n-on-e-x-i-s-t-e-n-t-$': 1,
#              's-o-c-i-a-l-$': 7,
#              'l-i-f-e$': 96,
#              'm-a-d-e$': 36,
#              'm-e$': 382,
#              's-o-$': 366,
#              'p-a-t-h-e-t-i-c-$': 6,
#              'r-e-a-l-l-y$': 157,
#              'r-e-g-r-e-t-f-u-l-$': 6,
#              'w-h-e-n-$': 228,
#              'h-e-a-r-ing$': 4,
#              't-h-a-t-$': 796,
#              's-h-in-a-e$': 2,
#              'g-o-t-$': 41,
#              'm-a-r-r-i-ed$': 4,
#              'a-n-o-t-h-er-$': 19,
#              'm-a-n-$': 13,
#              'o-h-$': 8,
#              'i-t-$': 515,
#              's$': 82,
#              's-a-d$': 24,
#              'h-o-p-e$': 20,
#              'a-l-e-x-$': 1,
#              'a-n-d$': 1453,
#              'c-a-n-$': 136,
#              'b-e$': 275,
#              'c-o-u-p-l-e$': 13,
#              'in-$': 509,
#              'r-e-a-l-$': 13,
#              't-h-e-y$': 109,
#              'r-e$': 21,
#              'p-er-f-e-c-t-$': 9,
#              'f-o-r-$': 387,
#              'e-a-c-h-$': 17,
#              'o-t-h-er-$': 47,
#              'b-e-l-i-e-v-ed$': 2,
#              'w-a-s$': 339,
#              't-r-u-e$': 8,
#              'l-o-v-e$': 70,
#              'd-e-v-a-s-t-a-t-ed$': 8,
#              'w-a-n-t-ed$': 20,
#              's-e-t-t-l-e$': 3,
#              'd-o-w-n-$': 31,
#              'h-a-v-e$': 302,
#              't-h-e$': 1277,
#              'w-h-o-l-e$': 14,
#              'm-a-r-r-i-a-g-e$': 1,
#              'k-i-d-s$': 16,
#              't-h-ing$': 23,
#              'w-i-t-h-$': 307,
#              'h-i-m-$': 84,
#              'u-n-i-m-p-o-r-t-a-n-t-$': 4,
#              'in-a-d-e-q-u-a-t-e$': 10,
#              'v-er-y$': 125,
#              'l-o-w-$': 10,
#              'a-l-r-e-a-d-y$': 28,
#              'h-o-r-r-i-b-l-e$': 7,
#              'a-g-a-in-$': 54,
#              'p-er-s-on-i-f-y-ing$': 1,
#              'a-n-$': 72,
#              'a-c-t-$': 4,
#              'w-er-e$': 47,
#              'n-o-t-$': 279,
#              'c-a-u-s-e$': 13,
#              'o-f-$': 751,
#              't-h-e-i-r-$': 57,
#              'p-r-o-g-e-n-y$': 1,
#              'w-h-o-$': 87,
#              's-h-o-u-l-d$': 50,
#              'g-e-n-u-f-l-e-c-t-ing$': 1,
#              'a-t-$': 240,
#              'h-er-$': 97,
#              'w-r-on-g-ed$': 9,
#              'w-o-m-a-n-$': 12,
#              'f-e-e-t-$': 5,
#              'i-l-l-$': 23,
#              'p-a-r-a-p-h-r-a-s-e$': 1,
#              'r-a-n-t-ed$': 1,
#              'b-e-ing$': 86,
#              'a-b-l-e$': 18,
#              't-r-u-s-t-$': 11,
#              'a-n-y-b-o-d-y$': 4,
#              'h-u-r-t-$': 11,
#              'f-e-e-l-ing$': 794,
#              'r-e-j-e-c-t-ed$': 8,
#              'e-t-c-$': 8,
#              'a-c-h-ing$': 6,
#              'a-l-l-$': 179,
#              't-i-m-e-s$': 28,
#              'd-a-y$': 60,
#              'd-u-m-b-$': 6,
#              'f-i-r-s-t-$': 27,
#              'r-u-n-$': 8,
#              't-h-r-o-u-g-h-$': 41,
#              's-e-e-m-s$': 17,
#              'o-v-er-$': 62,
#              'h-e-a-d$': 16,
#              'a-m-p-$': 8,
#              'l-i-t-t-l-e$': 112,
#              't-o-o-$': 61,
#              'm-u-c-h-$': 75,
#              's-t-r-u-g-g-l-ing$': 2,
#              'b-r-a-in-$': 6,
#              'm-e-n-t-i-on-$': 9,
#              't-h-i-s$': 307,
#              'on-e$': 85,
#              'd-o-e-s-n-$': 9,
#              't-$': 136,
#              'f-a-k-e$': 6,
#              'i-m-$': 405,
#              'm-o-r-e$': 124,
#              's-c-a-r-ed$': 12,
#              'l-i-k-e$': 463,
#              'd-r-a-m-a-s$': 1,
#              'o-r-$': 188,
#              't-h-r-i-l-l-er-s$': 1,
#              'a-r-e$': 132,
#              'a-c-t-u-a-l-l-y$': 30,
#              'c-a-p-a-b-l-e$': 3,
#              'h-a-p-p-e-n-ing$': 5,
#              'l-e-a-v-e$': 14,
#              'd-i-s-t-u-r-b-ed$': 8,
#              'g-r-o-g-g-y$': 8,
#              's-u-p-er-$': 5,
#              't-i-r-ed$': 9,
#              'd-u-r-ing$': 10,
#              'm-o-s-t-$': 39,
#              'f-a-l-l-$': 6,
#              'w-e$': 83,
#              'e-n-d-ed$': 4,
#              'u-p-$': 139,
#              's-t-a-y-ing$': 4,
#              'h-o-m-e$': 31,
#              't-h-a-n-k-s-g-i-v-ing$': 2,
#              'in-s-t-e-a-d$': 12,
#              'm-a-k-ing$': 22,
#              'h-o-u-r-$': 7,
#              't-r-i-p-$': 4,
#              'j-i-m-m-y-s$': 1,
#              'f-a-m-i-l-y$': 37,
#              'a-w-k-w-a-r-d$': 7,
#              'h-a-v-e-n-t-$': 16,
#              'b-e-e-n-$': 114,
#              'l-a-t-e-l-y$': 21,
#              'a-m-$': 310,
#              's-er-i-o-u-s-l-y$': 6,
#              'd-e-p-r-e-s-s-ed$': 11,
#              'i-s$': 330,
#              'u-n-f-o-r-t-u-n-a-t-e$': 4,
#              'h-a-d$': 98,
#              't-a-k-e$': 31,
#              't-h-e-s-e$': 69,
#              'd-r-a-s-t-i-c-$': 1,
#              'm-e-a-s-u-r-e-s$': 2,
#              'n-o-t-i-c-e$': 7,
#              'a-s$': 238,
#              't-r-u-l-y$': 11,
#              'l-o-v-ed$': 26,
#              'p-o-s-t-ing$': 4,
#              'n-e-w-$': 37,
#              'w-o-r-k-$': 46,
#              'f-l-i-c-k-r-$': 1,
#              'in-t-er-a-c-t-ing$': 1,
#              'p-e-o-p-l-e$': 113,
#              'f-r-o-m-$': 116,
#              'w-o-r-l-d$': 23,
#              's-t-i-l-l-$': 104,
#              'd-i-s-a-p-p-o-in-t-ed$': 8,
#              't-h-o-u-g-h-$': 40,
#              't-h-o-u-g-h-t-$': 31,
#              'e-x-h-a-u-s-t-ed$': 4,
#              'e-m-o-t-i-on-s$': 11,
#              'h-e-l-d$': 1,
#              'f-r-u-s-t-r-a-t-i-on-$': 1,
#              'c-on-f-u-s-i-on-$': 2,
#              'h-a-v-ing$': 37,
#              'g-i-v-e$': 26,
#              'l-o-o-k-$': 38,
#              'b-l-a-n-k-$': 5,
#              'w-h-i-t-e$': 4,
#              'p-i-e-c-e$': 5,
#              'p-a-p-er-$': 4,
#              'w-a-n-t-$': 106,
#              'f-i-l-l-$': 4,
#              'c-o-l-o-u-r-s$': 3,
#              'm-o-t-i-on-$': 1,
#              'b-u-t-$': 349,
#              'l-e-f-t-$': 34,
#              'p-l-a-c-e$': 22,
#              'h-e-a-r-t-b-r-o-k-e-n-$': 7,
#              'd-i-d-n-t-$': 53,
#              'r-e-s-p-on-d$': 1,
#              's-o-m-e$': 97,
#              'd-a-y-s$': 34,
#              'c-a-n-t-$': 37,
#              'p-u-t-$': 19,
#              'on-$': 236,
#              's-m-i-l-e$': 12,
#              'p-r-e-t-e-n-d$': 3,
#              'g-r-e-a-t-$': 12,
#              'l-e-t-$': 27,
#              'n-e-g-a-t-i-v-i-t-y$': 1,
#              'c-r-e-e-p-$': 2,
#              'o-k-$': 9,
#              'h-o-w-$': 111,
#              't-h-ing-s$': 67,
#              'n-o-$': 72,
#              'w-h-er-e$': 34,
#              'c-r-y-ing$': 4,
#              's-o-r-r-y$': 11,
#              'm-y-s-e-l-f-$': 119,
#              's-h-a-m-e$': 2,
#              'd-i-r-t-y$': 2,
#              's-r-c-$': 6,
#              's-t-o-p-$': 14,
#              's-h-i-t-t-y$': 11,
#              'g-e-n-er-a-l-$': 6,
#              'n-o-w-$': 87,
#              'w-r-i-t-e$': 11,
#              'c-on-t-in-u-o-u-s-l-y$': 1,
#              'u-s-ed$': 18,
#              'd-e-f-e-c-t-i-v-e$': 1,
#              'y-o-u-n-g-er-$': 5,
#              'y-e-t-$': 24,
#              'd-i-d$': 50,
#              's-o-m-e-t-i-m-e-s$': 41,
#              'd-i-s-c-o-u-r-a-g-ed$': 9,
#              'w-h-y$': 46,
#              's-h-a-d-o-w-s$': 1,
#              'c-o-m-e$': 30,
#              'h-e-a-r-t-$': 20,
#              'l-on-e-l-y$': 18,
#              'l-on-g-$': 25,
#              'h-e-a-v-e-n-$': 3,
#              'j-e-s-u-s$': 3,
#              'p-o-r-t-i-on-$': 1,
#              'c-on-s-t-a-n-t-$': 7,
#              'f-r-i-e-n-d$': 24,
#              'h-e$': 105,
#              'h-i-s$': 65,
#              'e-y-e$': 6,
#              's-p-a-r-r-o-w-$': 1,
#              'k-n-o-w-$': 141,
#              'w-a-t-c-h-e-s$': 3,
#              'd-o-$': 147,
#              'a-l-l-o-w-$': 4,
#              's-i-t-$': 12,
#              'c-y-c-l-e$': 2,
#              't-o-d-a-y$': 36,
#              'w-i-l-l-$': 109,
#              'n-a-s-t-y$': 2,
#              'b-i-g-$': 13,
#              'b-l-o-w-$': 1,
#              'f-i-g-h-t-$': 9,
#              'p-u-b-l-i-c-$': 2,
#              'h-u-m-i-l-i-a-t-ed$': 4,
#              'p-r-o-v-e-n-$': 1,
#              'r-i-g-h-t-$': 47,
#              'u-n-s-t-a-b-l-e$': 1,
#              'b-a-d$': 23,
#              'p-er-s-on-$': 26,
#              'v-i-c-t-i-m-i-z-ed$': 3,
#              'b-y$': 166,
#              'd-r-a-g-$': 2,
#              'o-u-r-$': 45,
#              'c-o-u-n-t-r-y$': 5,
#              'h-e-a-d-s$': 1,
#              's-a-n-d$': 2,
#              't-r-a-d-i-t-i-on-a-l-i-s-t-s$': 1,
#              'h-e-s-i-t-a-t-e$': 1,
#              'c-a-l-l-$': 14,
#              't-h-e-m-$': 106,
#              'c-on-s-er-v-a-t-i-v-e-s$': 2,
#              'f-e-a-r-$': 8,
#              'o-f-f-e-n-d-ing$': 1,
#              'h-on-e-s-t-$': 4,
#              'g-o-d$': 20,
#              't-h-in-k-$': 91,
#              'c-r-e-a-t-ed$': 4,
#              'y-e-a-r-s$': 27,
#              'a-g-o-$': 8,
#              's-t-u-f-f-$': 15,
#              's-k-e-l-e-t-a-l-$': 1,
#              'r-e-m-a-in-s$': 2,
#              'k-in-d$': 29,
#              'h-o-a-x-$': 1,
#              'n-e-ed$': 58,
#              'f-in-d$': 35,
#              'w-a-y$': 88,
#              'g-e-t-$': 104,
#              'h-o-p-e-l-e-s-s$': 6,
#              'g-o-ing$': 77,
#              's-a-y$': 49,
#              'm-a-k-e-s$': 40,
#              'u-n-l-o-v-ed$': 7,
#              's-h-i-t-$': 4,
#              't-h-a-t-s$': 26,
#              'o-v-er-l-y$': 4,
#              'd-r-a-m-a-t-i-c-$': 2,
#              'p-r-e-t-t-y$': 49,
#              'j-o-a-n-$': 1,
#              's-a-w-$': 7,
#              'd-i-s-a-p-p-o-in-t-m-e-n-t-$': 3,
#              'l-i-f-t-ed$': 1,
#              's-p-i-r-i-t-$': 5,
#              'c-o-r-in-t-h-i-a-n-s$': 2,
#              't-r-y-ing$': 31,
#              's-o-u-n-d$': 4,
#              'on-c-e$': 12,
#              'w-h-i-l-e$': 27,
#              'h-u-m-a-n-$': 2,
#              'm-o-r-n-ing$': 16,
#              'h-e-a-d-a-c-h-e$': 1,
#              'e-x-t-r-e-m-e-l-y$': 16,
#              'p-h-y-s-i-c-a-l-l-y$': 4,
#              'p-u-n-i-s-h-ed$': 4,
#              's-o-m-e-t-h-ing$': 86,
#              'd-i-d-n-$': 18,
#              'e-v-e-n-$': 79,
#              's-t-a-r-t-$': 27,
#              't-a-k-ing$': 16,
#              'm-$': 59,
#              'w-o-r-k-ing$': 11,
#              'c-o-p-e$': 1,
#              'a-w-f-u-l-$': 8,
#              'h-o-s-p-i-t-a-l-$': 3,
#              'n-i-g-h-t-$': 20,
#              'h-e-l-p-l-e-s-s$': 15,
#              'l-o-t-$': 28,
#              'a-l-m-o-s-t-$': 21,
#              'e-v-er-y$': 33,
#              'd-o-e-s$': 22,
#              'b-l-o-g-$': 18,
#              't-i-m-e-l-y$': 1,
#              'm-i-s-s$': 11,
#              'g-u-i-l-t-$': 3,
#              'r-e-a-c-t-ed$': 1,
#              't-er-r-i-b-l-e$': 4,
#              's-a-i-d$': 28,
#              's-a-k-e$': 1,
#              's-a-y-ing$': 15,
#              'e-x-c-i-t-ed$': 14,
#              'in-t-r-o-d-u-c-ed$': 2,
#              'l-i-b-r-a-r-y$': 2,
#              'e-n-v-i-r-on-m-e-n-t-$': 5,
#              's-a-m-e$': 21,
#              't-i-m-e$': 120,
#              's-t-r-e-s-s-ed$': 14,
#              'm-e-a-n-s$': 6,
#              'g-e-t-t-ing$': 44,
#              'h-o-l-i-d-a-y$': 8,
#              'd-on-t-$': 70,
#              'i-t-s$': 112,
#              'd-e-v-e-s-t-a-t-ed$': 1,
#              'w-o-u-l-d$': 101,
#              'g-r-a-v-e$': 1,
#              'd-i-s-s-er-v-i-c-e$': 1,
#              'f-e-e-l-ing-s$': 49,
#              'n-e-v-er-$': 29,
#              'r-e-c-a-l-l-$': 3,
#              'q-u-i-t-e$': 46,
#              'w-o-r-t-h-l-e-s-s$': 6,
#              'u-g-l-y$': 6,
#              'a-f-a-er-y-t-a-l-e-in-m-a-k-e-b-e-l-i-e-v-e$': 1,
#              'm-e-l-a-n-c-h-o-l-y$': 5,
#              't-on-i-g-h-t-$': 12,
#              'k-in-d-a-$': 12,
#              'p-a-in-t-$': 3,
#              'd-o-o-r-$': 4,
#              'i-v-e$': 90,
#              'n-e-e-d-y$': 6,
#              'w-o-u-n-d$': 4,
#              'd-r-i-v-ing$': 4,
#              'b-u-t-t-er-f-l-i-e-s$': 2,
#              't-e-e-n-a-g-er-$': 3,
#              'k-i-s-s-ed$': 1,
#              't-h-e-n-$': 44,
#              'r-o-t-t-e-n-$': 3,
#              'w-e-e-k-$': 22,
#              'a-f-t-er-$': 50,
#              'e-x-p-e-c-t-ing$': 4,
#              'y-o-u-r-$': 62,
#              's-on-$': 5,
#              'u-h-u-r-u-$': 1,
#              'p-er-s-e-c-u-t-ed$': 2,
#              'm-e-n-$': 9,
#              'm-a-r-t-h-a-$': 1,
#              'k-a-r-u-a-$': 1,
#              'c-a-r-r-y-ing$': 1,
#              'b-a-g-s$': 1,
#              'u-n-w-e-l-c-o-m-e$': 5,
#              'o-f-t-e-n-$': 25,
#              'b-a-c-k-$': 59,
#              'a-s-h-a-m-ed$': 7,
#              'd-on-e$': 19,
#              'e-a-r-l-i-er-$': 4,
#              's-i-c-k-$': 9,
#              'c-a-r-e$': 10,
#              'p-u-p-p-y$': 1,
#              'l-i-v-ing$': 12,
#              'm-o-t-h-er-$': 12,
#              's-e-n-t-i-m-e-n-t-a-l-$': 6,
#              'd-i-s-t-in-c-t-l-y$': 1,
#              'r-e-m-e-m-b-er-$': 37,
#              'c-h-i-l-d$': 8,
#              'c-e-l-e-b-r-a-t-ing$': 4,
#              'p-a-r-e-n-t-s$': 7,
#              't-h-$': 1,
#              'b-i-r-t-h-d-a-y-s$': 1,
#              's-e-e-m-ed$': 5,
#              't-r-o-u-b-l-e$': 3,
#              's-l-e-e-p-ing$': 3,
#              'a-n-x-i-e-t-y$': 4,
#              'c-a-u-s-ing$': 4,
#              's-u-f-f-er-$': 5,
#              'l-a-c-k-$': 3,
#              'm-o-t-i-v-a-t-i-on-$': 1,
#              'd-r-i-v-e$': 9,
#              'q-u-i-c-k-l-y$': 4,
#              'b-e-c-o-m-ing$': 5,
#              'c-h-o-r-e$': 1,
#              's-a-t-i-s-f-i-ed$': 5,
#              'd-u-l-l-$': 5,
#              'u-n-in-t-er-e-s-t-ing$': 1,
#              'n-e-g-l-e-c-t-f-u-l-$': 1,
#              'a-l-i-v-e$': 5,
#              'h-a-p-p-y$': 33,
#              'a-n-y$': 40,
#              'g-o-o-d$': 64,
#              'a-n-y-on-e$': 25,
#              't-o-u-g-h-t-$': 1,
#              't-r-y$': 23,
#              'h-a-r-d$': 18,
#              'g-i-r-l-f-r-i-e-n-d$': 2,
#              's-u-r-e$': 33,
#              's-t-r-u-g-g-l-ed$': 2,
#              's-u-b-p-a-r-$': 1,
#              'v-a-r-i-o-u-s$': 2,
#              'a-r-e-a-s$': 3,
#              'a-l-w-a-y-s$': 48,
#              'n-e-x-t-$': 15,
#              'r-e-l-i-s-h-$': 1,
#              'h-a-t-e$': 19,
#              'a-l-s-o-$': 65,
#              'a-f-r-a-i-d$': 23,
#              'e-x-t-e-n-d-ed$': 3,
#              'f-e-e-l-s$': 57,
#              'k-n-o-w-ing$': 14,
#              'a-l-on-e$': 19,
#              'c-r-a-p-p-y$': 7,
#              'h-a-p-p-e-n-$': 11,
#              's-t-u-d-y-ing$': 3,
#              'd-i-s-c-o-v-er-ing$': 2,
#              'w-o-r-d-s$': 14,
#              'c-r-o-s-s-ed$': 1,
#              'm-in-d$': 11,
#              'p-o-r-t-r-a-y$': 2,
#              'e-x-a-c-t-$': 2,
#              'm-e-a-n-ing$': 2,
#              'm-i-s-s-ed$': 10,
#              'd-e-s-t-a-s-h-ing$': 1,
#              'c-u-t-s$': 1,
#              'f-a-b-r-i-c-$': 2,
#              'i-d$': 30,
#              'b-o-u-g-h-t-$': 3,
#              'm-a-k-e$': 70,
#              'c-l-o-t-h-ing$': 1,
#              'h-a-s$': 56,
#              's-a-t-$': 9,
#              'a-r-o-u-n-d$': 55,
#              'c-er-t-i-f-i-ed$': 1,
#              'v-i-a-$': 2,
#              'a-c-e$': 1,
#              's-o-r-t-$': 17,
#              'l-a-m-e$': 6,
#              'w-a-s-n-t-$': 14,
#              'p-r-o-b-a-b-l-y$': 14,
#              'w-o-u-l-d-n-t-$': 5,
#              't-o-l-d$': 9,
#              'y-o-u-$': 225,
#              'm-o-m-e-n-t-$': 20,
#              'on-l-y$': 67,
#              'm-a-s-t-er-$': 2,
#              'w-e-e-k-e-n-d-s$': 3,
#              's-u-b-m-i-s-s-i-v-e$': 5,
#              'b-i-t-$': 80,
#              'd-i-s-h-e-a-r-t-e-n-ed$': 3,
#              'w-i-s-e$': 2,
#              'r-e-c-e-n-t-l-y$': 7,
#              'u-n-h-a-p-p-y$': 5,
#              'g-r-a-b-b-ed$': 1,
#              's-h-o-e-s$': 6,
#              's-o-c-k-s$': 2,
#              'l-a-z-y$': 6,
#              'c-a-r-$': 7,
#              't-e-a-c-h-er-$': 2,
#              'g-r-e-e-t-ed$': 2,
#              'o-m-g-$': 1,
#              'n-i-c-e$': 14,
#              'm-i-s-er-a-b-l-e$': 9,
#              'e-v-er-$': 33,
#              's-in-c-e$': 23,
#              'g-r-a-d-u-a-t-ed$': 1,
#              'h-i-g-h-$': 10,
#              's-c-h-o-o-l-$': 19,
#              'f-e-l-t-$': 51,
#              'b-e-t-t-er-$': 27,
#              't-h-u-r-s-d-a-y$': 1,
#              'f-r-i-d-a-y$': 4,
#              'e-n-o-u-g-h-$': 36,
#              'in-t-o-$': 48,
#              'f-o-g-g-y$': 2,
#              'l-a-s-t-$': 35,
#              'y-e-a-r-$': 31,
#              'n-o-w-h-er-e$': 2,
#              'n-e-a-r-$': 2,
#              'c-l-o-s-ing$': 2,
#              't-y-p-e$': 6,
#              'c-o-u-l-d$': 78,
#              'h-o-m-e-s-i-c-k-$': 5,
#              'c-on-t-a-g-i-o-u-s$': 1,
#              'd-e-s-p-er-a-t-e-l-y$': 6,
#              'w-a-n-t-ing$': 9,
#              'c-u-d-d-l-e$': 1,
#              's-e-l-f-i-s-h-$': 13,
#              'p-h-y-s-i-c-a-l-$': 7,
#              'n-e-e-d-ed$': 9,
#              'f-r-on-t-$': 8,
#              's-e-a-t-$': 1,
#              'p-a-in-$': 18,
#              'l-a-r-g-er-$': 1,
#              'p-o-in-t-$': 19,
#              'd-i-s-a-d-v-a-n-t-a-g-ed$': 1,
#              'b-e-l-i-e-v-e$': 15,
#              't-h-er-e$': 81,
#              'h-u-m-a-n-i-t-y$': 1,
#              's-u-b-j-e-c-t-s$': 1,
#              'p-o-t-e-n-t-i-a-l-$': 4,
#              'c-o-m-m-u-n-i-c-a-t-i-on-$': 1,
#              's-h-a-r-ing$': 9,
#              'i-d-e-a-s$': 3,
#              'c-o-m-m-on-$': 3,
#              'g-r-o-u-n-d$': 5,
#              'l-a-n-g-u-a-g-e$': 3,
#              'a-d-o-l-e-s-c-e-n-c-e$': 1,
#              's-i-t-u-a-t-i-on-$': 13,
#              'r-e-v-er-t-$': 1,
#              's-h-y$': 11,
#              's-e-l-f-$': 18,
#              'e-s-t-e-e-m-$': 1,
#              'b-e-g-a-n-$': 10,
#              'c-on-t-r-a-c-t-i-on-s$': 2,
#              'in-t-e-n-s-i-t-y$': 2,
#              'c-r-e-a-t-u-r-e$': 3,
#              't-w-o-$': 32,
#              'c-a-m-e$': 12,
#              'c-l-o-s-e$': 9,
#              'p-a-c-k-ing$': 3,
#              'h-e-a-d-ing$': 2,
#              'w-on-d-er-ed$': 3,
#              'l-e-s-s$': 43,
#              'w-o-r-s-e$': 6,
#              'l-e-a-s-t-$': 23,
#              'f-a-r-$': 11,
#              'c-on-c-er-n-ed$': 4,
#              'b-l-u-e$': 2,
#              'a-c-h-e$': 3,
#              'l-i-s-t-l-e-s-s$': 2,
#              'n-o-w-a-d-a-y-s$': 1,
#              'u-s-e-l-e-s-s$': 1,
#              's-t-a-n-d-ing$': 1,
#              's-i-d-e-l-in-e-s$': 1,
#              'w-e-t-$': 1,
#              'l-e-t-t-u-c-e$': 1,
#              's-o-m-e-on-e$': 32,
#              'f-l-o-w-er-s$': 4,
#              'w-u-s-s$': 1,
#              'r-e-l-y$': 4,
#              'c-er-t-a-in-$': 7,
#              'a-d-d$': 7,
#              'on-s$': 1,
#              'a-v-a-i-l-a-b-l-e$': 2,
#              'm-i-d-o-r-i-$': 1,
#              'a-d$': 1,
#              'c-r-ing-e$': 3,
#              'h-e-l-p-$': 40,
#              't-r-o-u-b-l-ed$': 3,
#              'd-on-$': 59,
#              'd-i-s-r-e-s-p-e-c-t-ed$': 1,
#              'e-a-s-i-l-y$': 7,
#              'a-g-i-t-a-t-ed$': 29,
#              'in-d-e-c-i-s-i-v-e$': 7,
#              'e-f-f-ing$': 1,
#              'm-i-l-$': 1,
#              'h-a-t-ed$': 13,
#              'm-o-v-ing$': 4,
#              's-l-o-w-er-$': 1,
#              'g-e-n-er-a-l-l-y$': 6,
#              'l-e-t-h-a-r-g-i-c-$': 6,
#              't-h-a-n-$': 68,
#              'r-i-d-e$': 3,
#              't-r-a-i-l-$': 1,
#              'h-i-d-e$': 4,
#              's-e-c-r-e-t-$': 3,
#              'in-s-i-d-e$': 13,
#              'a-w-a-y$': 27,
#              'e-v-er-y-on-e$': 19,
#              'a-s-s-i-s-t-a-n-c-e$': 2,
#              'f-l-o-a-t-ed$': 2,
#              'b-e-l-o-w-$': 2,
#              's-u-r-f-a-c-e$': 3,
#              'c-o-u-l-d-n-t-$': 11,
#              's-e-e-m-$': 8,
#              'b-r-ing$': 6,
#              'a-b-o-v-e$': 4,
#              'w-a-t-er-$': 8,
#              'k-n-e-w-$': 8,
#              's-h-a-k-ing$': 2,
#              'm-a-n-y$': 42,
#              'r-e-a-s-on-s$': 7,
#              'c-y-s-t-$': 1,
#              'd-r-a-m-a-$': 1,
#              's-t-a-r-t-ed$': 28,
#              'c-o-l-d$': 20,
#              'f-a-s-t-$': 2,
#              'd-r-a-in-ed$': 2,
#              'w-h-in-e-y$': 2,
#              'c-e-l-e-b-r-a-t-e-s$': 1,
#              'e-i-d$': 1,
#              's-o-m-e-w-h-a-t-$': 9,
#              's-p-e-n-t-$': 12,
#              'w-e-e-k-s$': 8,
#              'z-o-m-b-i-e$': 2,
#              'm-o-d-e$': 2,
#              'n-u-m-b-$': 7,
#              'o-v-er-c-o-m-e$': 3,
#              'v-o-i-c-e$': 6,
#              't-e-l-l-ing$': 11,
#              'c-on-s-i-s-t-e-n-t-l-y$': 2,
#              'f-i-r-m-l-y$': 1,
#              'd-i-s-g-u-s-t-ing$': 1,
#              'h-u-g-e$': 2,
#              'w-a-l-k-ed$': 4,
#              't-h-o-s-e$': 42,
#              'b-e-l-i-e-v-ing$': 1,
#              'h-i-l-l-$': 2,
#              'e-n-t-i-r-e$': 7,
#              'm-a-in-t-a-in-$': 4,
#              'm-o-o-d$': 10,
#              'y-o-u-r-e$': 21,
#              's-e-e-n-$': 6,
#              'b-i-g-g-er-$': 5,
#              'b-o-t-h-er-ed$': 15,
#              'm-i-g-h-t-$': 28,
#              'c-h-a-n-g-ed$': 2,
#              'u-s$': 30,
#              'd-i-s-m-a-y-ed$': 1,
#              'p-l-e-a-s-ed$': 7,
#              't-e-l-l-s$': 2,
#              't-a-k-e-n-$': 10,
#              's-t-a-f-f-$': 2,
#              'b-l-a-n-k-ed$': 1,
#              'l-e-s-s-on-$': 4,
#              's-e-a-m-l-e-s-s-l-y$': 1,
#              'j-u-m-p-ed$': 3,
#              's-u-p-p-o-r-t-$': 12,
#              'w-i-t-h-o-u-t-$': 32,
#              's-t-u-p-i-d$': 12,
#              'in-f-er-r-ing$': 1,
#              'g-u-i-l-t-y$': 4,
#              's-h-a-r-e$': 14,
#              'c-h-a-l-l-e-n-g-e-s$': 1,
#              't-h-r-o-w-n-$': 3,
#              'f-in-a-n-c-i-a-l-l-y$': 2,
#              'e-m-o-t-i-on-a-l-l-y$': 5,
#              'm-e-d-i-c-a-l-l-y$': 1,
#              'f-a-c-t-$': 13,
#              'a-b-u-s-ed$': 7,
#              'a-d-o-r-e$': 2,
#              'g-i-f-t-$': 3,
#              'l-i-s-t-$': 7,
#              'k-n-o-w-s$': 3,
#              's-u-r-p-r-i-s-e-s$': 2,
#              'u-n-g-r-a-t-e-f-u-l-$': 7,
#              'h-e-l-l-i-p-$': 1,
#              'l-y-ing$': 3,
#              'k-i-d$': 5,
#              'h-e-l-l-$': 4,
#              's-t-o-o-p-$': 1,
#              'p-e-n-d-ing$': 1,
#              'h-i-m-s-e-l-f-$': 8,
#              'u-n-r-e-a-s-on-a-b-l-e$': 1,
#              'l-i-e$': 4,
#              't-o-w-a-r-d-s$': 18,
#              's-e-e-ing$': 15,
#              'p-r-o-b-l-e-m-s$': 6,
#              's-t-e-m-s$': 1,
#              't-h-er-a-p-e-u-t-i-c-$': 1,
#              'c-o-m-p-l-e-t-e-l-y$': 13,
#              't-er-m-s$': 3,
#              's-t-e-p-$': 3,
#              'p-l-a-t-e$': 3,
#              'h-er-s-e-l-f-$': 3,
#              'r-e-a-d-y$': 8,
#              'w-e-e-p-y$': 4,
#              'e-m-o-t-i-on-a-l-$': 9,
#              'a-t-t-a-c-h-m-e-n-t-$': 1,
#              's-i-m-p-l-y$': 12,
#              'e-l-s-e$': 18,
#              'u-n-d-er-s-t-a-n-d$': 17,
#              'l-o-g-i-c-$': 3,
#              's-t-u-d-e-n-t-$': 2,
#              'c-on-g-r-e-s-s$': 1,
#              'b-o-r-ing$': 12,
#              'f-a-u-x-$': 1,
#              'd-i-a-m-on-d$': 1,
#              'r-ing-s$': 2,
#              'm-a-y$': 20,
#              'r-a-n-t-$': 1,
#              'b-u-r-d-e-n-ed$': 6,
#              's-t-o-r-e$': 2,
#              'd-e-f-e-a-t-ed$': 5,
#              't-e-l-l-$': 20,
#              'm-o-m-$': 11,
#              'c-r-a-z-y$': 6,
#              'p-r-in-t-ing$': 2,
#              's-er-v-i-c-e$': 2,
#              'h-a-i-r-$': 10,
#              'i-m-p-r-o-v-ed$': 1,
#              's-t-i-c-k-in-e-s-s$': 1,
#              'l-ing-er-ing$': 2,
#              'g-o-$': 62,
#              's-e-n-s-e$': 19,
#              'i-s-s-u-e$': 5,
#              'on-e-s$': 7,
#              's-t-r-on-g-$': 13,
#              'd-e-a-l-$': 3,
#              'b-e-c-o-m-e$': 14,
#              'j-a-d-ed$': 5,
#              'w-a-i-t-ing$': 8,
#              's-u-m-m-er-$': 5,
#              'm-o-m-e-n-t-s$': 9,
#              'v-e$': 15,
#              'r-e-s-i-g-n-ed$': 1,
#              'e-x-t-e-n-t-$': 4,
#              'c-h-a-p-t-er-$': 2,
#              's-t-$': 4,
#              'p-a-u-l-$': 1,
#              'c-a-n-n-o-t-$': 6,
#              'a-n-y-t-h-ing$': 34,
#              's-u-c-h-$': 35,
#              'd-a-u-g-h-t-er-$': 3,
#              'b-r-a-n-d-i-s-h-$': 1,
#              'a-r-t-i-c-l-e$': 3,
#              'f-u-n-$': 10,
#              'b-ed$': 12,
#              'l-a-t-e$': 5,
#              'w-h-e-n-e-v-er-$': 4,
#              't-r-a-g-i-c-$': 4,
#              'u-n-t-i-l-$': 15,
#              'p-i-c-k-ed$': 3,
#              'm-o-v-ed$': 2,
#              'c-z-e-c-h-$': 1,
#              'r-e-p-u-b-l-i-c-$': 1,
#              'c-h-r-i-s$': 2,
#              's-e-n-t-$': 2,
#              'p-a-c-k-a-g-e$': 1,
#              'f-o-o-d$': 11,
#              'm-u-s-i-c-$': 11,
#              'r-e-m-in-d$': 5,
#              'p-u-l-l-$': 11,
#              'r-er-e-a-d$': 2,
#              's-t-a-r-t-ing$': 16,
#              's-u-r-r-e-a-l-$': 1,
#              'r-e-m-in-d-er-s$': 1,
#              'l-u-l-l-s$': 1,
#              'w-h-e-t-h-er-$': 12,
#              'a-w-e-s-o-m-e$': 5,
#              'w-o-r-k-o-u-t-s$': 1,
#              'f-in-a-l-l-y$': 10,
#              'r-e-a-l-i-s-e$': 4,
#              'e-f-f-e-c-t-s$': 3,
#              'w-e-i-r-d$': 53,
#              'c-on-f-i-d-e-n-t-$': 7,
#              'z-i-m-m-er-m-a-n-$': 1,
#              'w-on-t-$': 17,
#              'w-o-r-r-i-ed$': 6,
#              'n-er-v-o-u-s$': 17,
#              'j-o-b-$': 13,
#              'b-e-s-t-$': 10,
#              'h-e-a-v-e-n-l-y$': 1,
#              'f-a-t-h-er-$': 5,
#              'l-o-s-t-$': 16,
#              'd-e-p-r-e-s-s-i-on-$': 3,
#              'p-i-t-$': 1,
#              'f-a-i-l-u-r-e$': 2,
#              'c-r-i-t-i-c-i-z-ed$': 1,
#              'r-e-s-e-n-t-f-u-l-$': 8,
#              'b-r-o-k-e$': 4,
#              'c-h-i-l-d-r-e-n-$': 11,
#              't-w-i-t-t-er-$': 3,
#              'v-a-in-$': 5,
#              'o-u-t-f-i-t-$': 1,
#              'a-l-r-i-g-h-t-$': 2,
#              'n-o-t-h-ing$': 10,
#              't-v-$': 4,
#              'f-i-x-$': 2,
#              's-e-v-e-n-t-y$': 1,
#              'h-a-p-p-e-n-ed$': 10,
#              'c-l-a-s-s-e-s$': 4,
#              't-e-a-c-h-er-s$': 3,
#              'm-e-a-n-$': 20,
#              'f-r-i-e-n-d-s$': 29,
#              'c-o-p-$': 1,
#              't-er-r-i-f-i-ed$': 19,
#              'm-in-u-t-e$': 3,
#              'p-a-r-t-n-er-$': 4,
#              'v-i-e-w-$': 6,
#              'h-u-n-d-r-e-d-s$': 1,
#              'j-a-c-k-e-t-s$': 1,
#              'o-b-t-a-in-$': 2,
#              'c-a-u-g-h-t-$': 5,
#              's-u-r-g-e-on-s$': 1,
#              'e-v-a-l-u-a-t-ing$': 1,
#              'a-r-e-a-$': 6,
#              's-t-er-i-l-e$': 1,
#              'c-l-e-a-n-$': 4,
#              's-m-e-l-l-ing$': 2,
#              'b-r-i-m-m-ing$': 1,
#              'n-u-m-er-o-u-s$': 2,
#              'd-e-v-i-c-e-s$': 1,
#              'r-e-a-l-i-z-e$': 10,
#              'm-e-t-$': 6,
#              'n-on-e$': 3,
#              'g-o-a-l-s$': 3,
#              'e-x-p-l-a-in-$': 4,
#              'e-m-b-a-r-r-a-s-s-ed$': 4,
#              'd-e-s-c-r-i-b-e$': 7,
#              'p-a-in-f-u-l-$': 2,
#              'b-r-e-a-k-u-p-$': 1,
#              'w-e-n-t-$': 16,
#              'l-o-o-k-ing$': 31,
#              'a-n-g-u-i-s-h-ed$': 1,
#              'b-e-t-r-a-y-ed$': 4,
#              'd-i-s-i-l-l-u-s-i-on-ed$': 1,
#              'a-t-t-e-n-d$': 2,
#              'i-m-p-o-r-t-a-n-t-$': 13,
#              'l-i-v-e-s$': 6,
#              'b-l-o-g-g-ing$': 8,
#              'd-i-s-g-u-s-t-ed$': 8,
#              'b-r-u-s-h-$': 6,
#              'r-e-t-u-r-n-ing$': 1,
#              's-p-a-in-$': 1,
#              's-o-b-$': 1,
#              'r-e-l-e-a-s-e$': 2,
#              't-e-c-h-n-i-q-u-e-s$': 3,
#              'u-s-ing$': 9,
#              'e-x-p-er-t-$': 2,
#              'f-a-c-e$': 17,
#              'l-i-q-u-i-d$': 1,
#              'f-o-u-n-d-a-t-i-on-$': 4,
#              's-e-p-h-o-r-a-$': 1,
#              'm-in-er-a-l-$': 1,
#              'p-o-w-d-er-$': 3,
#              'c-o-l-l-e-c-t-i-on-$': 2,
#              'b-on-e-s$': 1,
#              'n-o-b-o-d-y$': 4,
#              'c-a-r-e-s$': 4,
#              'g-on-e$': 6,
#              'e-i-t-h-er-$': 7,
#              'k-i-l-l-s$': 1,
#              'd-o-e-s-n-t-$': 7,
#              't-r-e-a-t-$': 4,
#              'g-h-o-s-t-$': 1,
#              's-i-g-h-$': 3,
#              'd-a-m-n-$': 7,
#              'b-e-g-in-$': 7,
#              'u-n-p-l-e-a-s-a-n-t-$': 2,
#              'a-n-i-m-e$': 1,
#              'f-a-n-d-o-m-$': 1,
#              't-u-r-n-ed$': 2,
#              'r-a-d-i-o-$': 1,
#              'h-o-p-ing$': 5,
#              'l-i-f-t-$': 2,
#              's-p-i-r-i-t-s$': 1,
#              'in-c-a-p-a-b-l-e$': 1,
#              'q-u-e-s-t-i-on-ing$': 2,
#              'e-v-er-y-t-h-ing$': 31,
#              'a-d-m-i-t-t-ing$': 3,
#              'g-l-o-a-t-ing$': 1,
#              'w-h-i-c-h-$': 58,
#              's-p-e-a-k-$': 6,
#              'on-l-in-e$': 6,
#              'd-r-o-p-$': 2,
#              'l-i-s-t-s$': 2,
#              'd-i-s-r-e-g-a-r-d-ed$': 1,
#              'q-u-i-t-$': 1,
#              's-c-r-e-w-$': 2,
#              'f-r-a-m-e$': 1,
#              's-h-o-p-$': 1,
#              'b-e-s-i-d-e-s$': 1,
#              'b-r-i-t-i-s-h-$': 2,
#              'm-in-e$': 7,
#              'b-e-a-t-e-n-$': 5,
#              'e-v-i-l-$': 1,
#              'r-e-s-t-$': 8,
#              't-r-i-ed$': 9,
#              's-p-e-n-d$': 6,
#              'u-s-u-a-l-l-y$': 9,
#              'o-f-f-er-s$': 2,
#              'i-g-n-o-r-ed$': 7,
#              'y-o-u-d$': 2,
#              'm-o-u-n-t-a-in-$': 1,
#              't-o-g-e-t-h-er-$': 13,
#              'm-o-t-i-v-a-t-ed$': 3,
#              'l-e-a-r-n-$': 7,
#              'l-e-s-s-on-s$': 3,
#              'h-i-s-t-o-r-y$': 4,
#              'o-t-h-er-w-i-s-e$': 3,
#              'd-o-o-m-ed$': 3,
#              'r-e-p-e-a-t-$': 3,
#              'm-i-s-t-a-k-e-s$': 1,
#              'u-n-i-v-er-s-e$': 7,
#              't-h-in-k-s$': 2,
#              'h-a-n-d-l-e$': 7,
#              'g-i-v-ing$': 8,
#              's-u-f-f-er-ing$': 4,
#              'r-e-j-e-c-t-i-on-$': 3,
#              's-h-i-r-l-e-y$': 2,
#              'm-a-c-l-a-in-e$': 1,
#              'c-h-i-c-k-$': 3,
#              'f-l-i-c-k-$': 1,
#              'j-u-l-i-a-$': 2,
#              'r-o-b-er-t-s$': 2,
#              'd-e-m-a-n-d-s$': 2,
#              'd-r-u-g-s$': 2,
#              'r-e-m-o-r-s-e-f-u-l-$': 4,
#              'd-e-c-i-s-i-on-$': 3,
#              'k-i-c-k-ing$': 1,
#              'c-h-e-a-p-$': 2,
#              'o-w-n-$': 29,
#              'a-m-o-u-n-t-$': 8,
#              's-l-e-e-p-$': 11,
#              'c-h-o-i-c-e$': 2,
#              'z-er-o-$': 1,
#              'e-n-er-g-y$': 8,
#              'm-e-d-s$': 1,
#              'v-i-t-a-m-in-s$': 1,
#              'l-o-t-s$': 3,
#              'f-l-u-i-d-s$': 1,
#              'h-o-p-e-s$': 2,
#              't-o-m-o-r-r-o-w-$': 4,
#              's-u-p-p-o-s-e$': 8,
#              'm-a-g-a-z-in-e$': 1,
#              'p-r-e-s-e-n-t-ing$': 3,
#              'p-r-a-c-t-i-c-a-l-$': 4,
#              't-i-p-s$': 3,
#              'r-e-a-d-er-s$': 11,
#              'e-d-i-t-o-r-s$': 1,
#              's-p-i-c-e$': 2,
#              'o-r-d-er-$': 8,
#              'd-e-n-y-ing$': 1,
#              't-e-m-p-o-r-a-r-i-l-y$': 1,
#              'w-o-u-n-d-ed$': 1,
#              'i-d-i-o-t-$': 3,
#              'y-o-g-a-$': 1,
#              's-m-a-l-l-e-s-t-$': 1,
#              'r-e-s-p-on-s-i-b-i-l-i-t-y$': 2,
#              'l-a-r-g-e$': 3,
#              'r-e-s-p-on-s-i-b-i-l-i-t-i-e-s$': 2,
#              ...})

# %% [markdown]
# # TASK 2
# ### Task 2: Subtask 1&2&3: Implement Bigram Langage Model and Smoothing methods in BigramLM class

# %%
# !pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Downloading transformers-4.37.2-py3-none-any.whl (8.4 MB)
#      ---------------------------------------- 8.4/8.4 MB 14.5 MB/s eta 0:00:00
# Collecting filelock (from transformers)
#   Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers)
#   Downloading huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
#      ------------------------------------- 330.1/330.1 kB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\amey\appdata\roaming\python\python311\site-packages (from transformers) (1.23.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\amey\appdata\roaming\python\python311\site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\amey\appdata\roaming\python\python311\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\amey\appdata\roaming\python\python311\site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in c:\users\amey\appdata\roaming\python\python311\site-packages (from transformers) (2.28.2)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.1-cp311-none-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 27.8 MB/s eta 0:00:00
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.2-cp311-none-win_amd64.whl (269 kB)
#      ------------------------------------- 269.6/269.6 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in c:\users\amey\appdata\roaming\python\python311\site-packages (from transformers) (4.65.0)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.19.3->transformers)
#   Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#      -------------------------------------- 169.0/169.0 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\amey\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\amey\appdata\roaming\python\python311\site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\amey\appdata\roaming\python\python311\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amey\appdata\roaming\python\python311\site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amey\appdata\roaming\python\python311\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\amey\appdata\roaming\python\python311\site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amey\appdata\roaming\python\python311\site-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: safetensors, fsspec, filelock, huggingface-hub, tokenizers, transformers
# Successfully installed filelock-3.13.1 fsspec-2023.12.2 huggingface-hub-0.20.3 safetensors-0.4.2 tokenizers-0.15.1 transformers-4.37.2
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Using code from utils.py directly

# %%
from transformers import pipeline

classifier = pipeline("text-classification",model='bhadresh-savani/distilbert-base-uncased-emotion', return_all_scores=True,)

def emotion_scores(sample): 
    emotion=classifier(sample)
    return emotion[0]
# Out:
# Some layers from the model checkpoint at bhadresh-savani/distilbert-base-uncased-emotion were not used when initializing TFDistilBertForSequenceClassification: ['dropout_19']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at bhadresh-savani/distilbert-base-uncased-emotion and are newly initialized: ['dropout_59']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Checkign the function emotion_scores() from utils.py
emotion_scores("cheerful")
# Out:
# [{'label': 'sadness', 'score': 0.0013014927972108126},
#  {'label': 'joy', 'score': 0.9962917566299438},
#  {'label': 'love', 'score': 0.0008716191514395177},
#  {'label': 'anger', 'score': 0.0008998109260573983},
#  {'label': 'fear', 'score': 0.00034155105822719634},
#  {'label': 'surprise', 'score': 0.0002938536345027387}]

# %% [markdown]
# ### Task 2: SubTask 1 & 2 & 3
# ### All BigramLM() class methods, Laplace and KneserNey Implementation, and Emotion Incorporation in Standard Bigram Probabilities

# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import pickle
import warnings
warnings.filterwarnings('ignore')

class BigramLM:
    def __init__(self):
        self.bigram_counts = defaultdict(lambda: defaultdict(int))
        self.unigram_counts = defaultdict(int)
        self.bigramDictionary = defaultdict(int)
        self.bigramProbabilities = defaultdict(int)
        self.laplaceProbabilities = defaultdict(int)
        self.kneserneyProbabilities = defaultdict(int)
        self.vocab = set()
        self.discount = 0.75               # Kneser Ney Discount Factor
        self.probability_comparison_frame = pd.DataFrame()
        self.probability_comparison_frame_available = pd.DataFrame()
        self.bigram_emotion_dictionary = defaultdict(list)

    # Task2: Subtask1: method to learn the model
    def learn_model(self, dataset):
        for sentence in dataset:
            tokens = sentence
            tokens.append('$')  # Adding End of Sentence marker
            
            # Construct a bigram and unigram counts dictionary for further reference
            for i in range(len(tokens)):
                prev_token = tokens[i - 1]
                current_token = tokens[i]

                self.bigram_counts[prev_token][current_token] += 1
                self.unigram_counts[prev_token] += 1
                self.vocab.add(prev_token)
                self.bigramDictionary[(prev_token, current_token)] += 1

        self.calculate_probability()
        # self.add_emotion_component_to_bigram_probabilities() # Commenting as already created and stored using pickle
        self.import_stored_pickle_file()
#         self.build_laplace_and_kneserNey_probabilities()
    
    def build_laplace_and_kneserNey_probabilities(self):
        for bigram in self.bigramDictionary:
            self.laplaceProbabilities[bigram] = self.laplace_smoothing_probability(bigram)
            self.kneserneyProbabilities[bigram] = self.kneserney_smoothing_probability(bigram)
            
    # Function to calculate the emotion-oriented bigram probability
    def emotion_bigram_probability(self, bigram, emotion, beta):
        # Get emotion scores for the current word
        # emotion_scores_wi = emotion_scores(bigram[0]+bigram[1])

        # Calculate the emotion component (beta) based on the desired emotion (e.g., joy)
        # emotion_factor = emotion_scores_wi[emotion] if emotion in emotion_scores_wi else 0.0
        
        emotion_factor = 0.5

        for d in self.bigram_emotion_dictionary[bigram][1]:
            if d['label'] == emotion:
                emotion_factor = d['score']
                break

        # Calculate the emotion-oriented bigram probability
        emotion_oriented_bigram_probability = (self.bigramProbabilities[bigram]) + (beta * emotion_factor)
        return emotion_oriented_bigram_probability
    
    # Function to construct a sepearte dictionary with bigram_probabilty scores and corresponding emotion scores of each bigram
    # and later saving it to pickle for future reference. this function will only be called once and later saved pickle file will be used 
    def add_emotion_component_to_bigram_probabilities(self):
        for bigram in self.bigramProbabilities:
            self.bigram_emotion_dictionary[bigram] = [self.bigramProbabilities[bigram], emotion_scores(bigram[0]+" "+bigram[1])]
        # Save the dictionary to a file using pickle
        with open("bigram_emotion_dictionary.pkl", 'wb') as file:
            pickle.dump(self.bigram_emotion_dictionary, file)
     
    # Function to import previously saved pickle file, in previous defined function
    def import_stored_pickle_file(self):
        # Load the dictionary from the saved file
        with open("bigram_emotion_dictionary.pkl", 'rb') as file:
            self.bigram_emotion_dictionary = pickle.load(file)
      
    # Generate the most probable next token given a specific emotion
    def generate_next_token_by_emotion(self, prev_token, emotion, beta=0.1):
        if prev_token in self.bigram_counts:
            next_tokens = list(self.bigram_counts[prev_token].keys())
            probabilities = np.array([self.emotion_bigram_probability((prev_token, token), emotion, beta) for token in next_tokens])
            
            probabilities = probabilities/probabilities.sum()
            next_token = np.random.choice(next_tokens, p=probabilities)
            return next_token

        return None

    # Function for generating samples corresponding to a specific emotion (e.g., joy)
    def generate_emotion_oriented_samples(self, emotion, beta=0.1, num_samples=5, start_token="$"):
        if len(start_token.split()) ==0:
            start_token = "$"    
        start_token = start_token.split()[-1]
        
        if num_samples>300:
            print("Can generate only upto 300 samples")
            
#         if num_samples<=50:
#             iterations = num_samples*6
#         else:
#             iterations = 300

        iterations = num_samples
        
        # First store all the generated sentences in list
        generated_sentences = []
        
        # For each iteration, generate 1 sentence
        for _ in range(iterations):
            sample_list = []
            prev_token = start_token
            for i in range(10):
                next_token = self.generate_next_token_by_emotion(prev_token, emotion, beta)
                print(prev_token, end=" ")
                sample_list.append(prev_token)
                prev_token = next_token
            print()
            generated_sentences.append(" ".join(sample_list))
            
#         top_k = self.get_top_sentences_by_key(generated_sentences, emotion, num_samples)

        try:
            with open(f"{emotion}.txt", 'w') as file:
                pass  # Doing nothing inside the block, just opening in write mode to clear content
        except Exception as e:
            print(f"Error clearing file: {e}")
        # Save the generated sentences to corresponding text files
        for element in generated_sentences:
            print(element)
            try:
                # Open the file in append mode
                with open(f"{emotion}.txt", 'a') as file:
                    # Append the string to the end of the file
                    file.write(element + '\n')
            except Exception as e:
                print(f"Error writing sample to file: {e}")      
        print()
    
    # Rank top 50 sentences by their specific emotion scores and return  
    def get_top_sentences_by_key(self, input_sentences, emotion, k):
        # Apply the black-box function to each sentence and create a list of dictionaries
        sample_level_scores = dict()
        for sentence in input_sentences:
            escores = emotion_scores(sentence)
            escore = 0.5 
            for d in escores:
                if d['label']==emotion:
                    escore = d['score']
                    break
            sample_level_scores[sentence] = escore    
        sorted_items = sorted(sample_level_scores.items(), key=lambda x: x[1], reverse=True)  
        top_keys = [key for key, value in sorted_items[:k]]
        return top_keys

    # Generate the bigram dictionary     
    def calculate_probability(self):
        for bigram in self.bigramDictionary:
            self.bigramProbabilities[bigram] = (self.bigramDictionary[bigram]) / (self.unigram_counts[bigram[0]])
    
    # Task 2 : SubTask 2: Implement laplace smoothing
    def laplace_smoothing_probability(self, bigram):
        prefix_count = self.unigram_counts[bigram[0]]
        if bigram not in self.bigramDictionary:
            return ((1)/(prefix_count+len(self.vocab))) 
        
        bigram_count = self.bigramDictionary[bigram]
        return ((bigram_count+1)/(prefix_count+len(self.vocab)))      
        
    # Task 2 : SubTask 2: Implement Kneser Ney smoothing
    def kneserney_smoothing_probability(self, bigram):
        prefix_count = self.unigram_counts[bigram[0]]
        bigram_count = 0
        if bigram in self.bigramDictionary:
            bigram_count = self.bigramDictionary[bigram]
        
        bigram_types_with_suffix = len([x for x in self.bigramDictionary if x[1]==bigram[1]]) # fixed suffix, variable prefix(wi-1)
        bigram_types_with_prefix = len([x for x in self.bigramDictionary if x[0]==bigram[0]]) # fixed prefix, variable suffix(wi)
        total_bigram_types = len(self.bigramDictionary)
        
        discounted_prob = max(bigram_count - self.discount, 0) / prefix_count
        alpha_parameter = (self.discount / prefix_count) * bigram_types_with_prefix
        pcontinuation = bigram_types_with_suffix / total_bigram_types
        
        return discounted_prob + alpha_parameter * pcontinuation
           
    # Generate next token by standard bigram probability 
    def generate_next_token(self, prev_token):
        if prev_token in self.bigram_counts:
            next_tokens = list(self.bigram_counts[prev_token].keys())
            probabilities = [self.bigramProbabilities[(prev_token, token)] for token in next_tokens]
            next_token = np.random.choice(next_tokens, p=probabilities)
            return next_token

        return None

    # Generate next token by Laplace probability
    def generate_next_token_using_laplace(self, prev_token):
        next_tokens = [token for token in self.unigram_counts]
        
        probabilities = np.array([self.laplace_smoothing_probability((prev_token, token)) for token in next_tokens])
        
        next_token = np.random.choice(next_tokens, p=probabilities)
        return next_token

    # Generate next token by Kneser Ney probability
    def generate_next_token_using_kneserney(self, prev_token):
        next_tokens = [token for token in self.unigram_counts]
        
        probabilities = np.array([self.kneserney_smoothing_probability((prev_token, token)) for token in next_tokens])
        next_token = np.random.choice(next_tokens, p=probabilities)
        return next_token
        
    # Generate given number of sentences by standard bigram porbabilty
    def generate_sentences_standard_bigram(self, num_samples, start_token="$"):
        if len(start_token.split()) ==0:
            start_token = "$"
            
        start_token = start_token.split()[-1]
        for x in range(num_samples):
            prev_token = start_token
            for i in range(10):
                next_token = self.generate_next_token(prev_token)
                print(prev_token, end=" ")
                prev_token = next_token
            print()
        print()
        
    # Generate given number of sentences by Laplace porbabilty
    def generate_sentences_laplace(self, num_samples, start_token="$"):
        if len(start_token.split()) ==0:
            start_token = "$"
            
        start_token = start_token.split()[-1]
        for x in range(num_samples):
            prev_token = start_token
            for i in range(10):
                next_token = self.generate_next_token_using_laplace(prev_token)
                print(prev_token, end=" ")
                prev_token = next_token
            print()
        print()
        
    # Generate given number of sentences by KneserNey porbabilty        
    def generate_sentences_kneserney(self, num_samples, start_token="$"):
        if len(start_token.split()) ==0:
            start_token = "$"
            
        start_token = start_token.split()[-1]
        for x in range(num_samples):
            prev_token = start_token
            for i in range(10):
                next_token = self.generate_next_token_using_kneserney(prev_token)
                print(prev_token, end=" ")
                prev_token = next_token
            print()
        print()
       
    # Task2: Subtask2 : Function to compare and return the Laplace and kneserNey probabilities
    def compare_probabilities(self, prev_token="$"):
        if len(prev_token.split()) ==0:
            prev_token = "$"
            
        prev_token = prev_token.split()[-1]
        if prev_token in self.bigram_counts:
            available_next_tokens = list(self.bigram_counts[prev_token].keys())
            probabilities_bigram = [self.bigramProbabilities[(prev_token, token)] for token in available_next_tokens]
            
            all_tokens = np.array([token for token in self.unigram_counts])
            probabilities_laplace = np.array([self.laplace_smoothing_probability((prev_token, token)) for token in self.unigram_counts])
            probabilities_kneserney = np.array([self.kneserney_smoothing_probability((prev_token, token)) for token in self.unigram_counts])

            # Set display options for float formatting
            pd.set_option('display.float_format', '{:.8f}'.format)
            # Create Probability DataFrame
            self.probability_comparison_frame = pd.DataFrame({
                'Token': all_tokens,
                'Laplace Probability': probabilities_laplace,
                'KneserNey Probability': probabilities_kneserney
            })
            
            self.probability_comparison_frame_available = self.probability_comparison_frame[self.probability_comparison_frame["Token"].isin(available_next_tokens)]
            self.probability_comparison_frame_available["Bigram Probability"] = probabilities_bigram
            print("Probability Comparison of All Tokens")
            print(self.probability_comparison_frame)
            
            print("\nProbability Comparison of Next Available Tokens in Bigram Dictionary")
            print(self.probability_comparison_frame_available)
            return

        return None

with open("corpus.txt", "r", encoding="utf-8") as file:
    corpus = [line.strip().split() for line in file] 

bigram_model = BigramLM()
bigram_model.learn_model(corpus)

# %% [markdown]
# ## Task2 : Subtask 1: Generate some sentences

# %%
# generate_sentences_standard_bigram(number_of_samples, start_token->optional)
bigram_model.generate_sentences_standard_bigram(10)
# Out:
# $ i feel ecstatic and regard to a particularly mad
# $ i am earning again this triangle $ i feel
# $ im in the fierce looking for hussein whom i
# $ i m going to make some sort of my
# $ i could better on me more confident a purchase
# $ i feel the perfect fit all the fierce feels
# $ i like $ i get this time in high
# $ im really nice treat $ im not achieved and
# $ im suppose its so im feeling like this story
# $ i feel very loved $ i am a way

# %%
# generate_sentences_laplace(number_of_samples, start_token->optional)
bigram_model.generate_sentences_laplace(10)
# Out:
# $ nude advice tend waking seek whats holy gosh sharing
# $ apocalypses chocolating downright oblige disbelieving various accustomed outraged stranger
# $ unusual if impostor roads demon generational aa shower hold
# $ buffed frizz trials forest recently increasingly goes space sale
# $ i can fandoms zenos putting warfighter distinct comfort disgusting
# $ i feel facebook devoted burgeoning wimpy feel all numbing
# $ i don southern midori serving fell news seen wondering
# $ hart greater every depending child arun renowned desperate close
# $ unimportant checked fangirls artisan army exhausted facebook tasks uncoiling
# $ vibe securities homis pine radiator vunerable bringing inspiring retrospect

# %%
# generate_sentences_kneserney(number_of_samples, start_token->optional)
bigram_model.generate_sentences_kneserney(10)
# Out:
# $ i loki song considering mistake as the culprit death
# $ i just whats cleaning you know what i can
# $ i m about the down to others watched the
# $ i really dramatically for minds $ i have to
# $ i felt at my to sit it bounces lately
# $ i can way it table s to right now
# $ i just miss the universe am desperately i started
# $ i feel so im feeling a bit to do
# $ i am $ i am feeling rather than i
# $ i have found this isnt concerns to not idea

# %% [markdown]
# ## Task2 : Subtask 2: Compare Laplace and KneserNey

# %%
bigram_model.compare_probabilities()
# Out:
# Probability Comparison of All Tokens
#            Token  Laplace Probability  KneserNey Probability
# 0              $           0.00012771             0.00023928
# 1              i           0.26934866             0.87810280
# 2          stand           0.00012771             0.00000156
# 3           here           0.00012771             0.00000623
# 4           feel           0.00012771             0.00002181
# ...          ...                  ...                    ...
# 5425      google           0.00012771             0.00000019
# 5426  stellarium           0.00012771             0.00000019
# 5427       theyd           0.00012771             0.00000019
# 5428       peter           0.00012771             0.00000019
# 5429      robbed           0.00012771             0.00000019
#
# [5430 rows x 3 columns]
#
# Probability Comparison of Next Available Tokens in Bigram Dictionary
#         Token  Laplace Probability  KneserNey Probability  Bigram Probability
# 1           i           0.26934866             0.87810280          0.87833333
# 6           a           0.00051086             0.00098247          0.00291667
# 40       when           0.00114943             0.00305082          0.08833333
# 58         in           0.00025543             0.00017153          0.01791667
# 75        the           0.00051086             0.00100078          0.00041667
# 106       ill           0.00102171             0.00260709          0.00333333
# 135      this           0.00025543             0.00013084          0.00125000
# 140        im           0.02720307             0.08803368          0.00041667
# 156    during           0.00025543             0.00010611          0.00041667
# 178        is           0.00025543             0.00013473          0.00041667
# 227        on           0.00025543             0.00014019          0.00125000
# 237        no           0.00025543             0.00011176          0.00041667
# 400       ive           0.00561941             0.01761001          0.00333333
# 494        id           0.00114943             0.00302375          0.00041667
# 4111   heated           0.00025543             0.00010436          0.00041667
# 4489  occured           0.00025543             0.00010436          0.00041667

# %% [markdown]
# ## Argument:
#
# As we can see, their is a huge difference in Laplace probabilities and original Bigram probabilities. This is because Laplace smoothing steals a large amount of probabilities from non-zero counts of tokens to distribute it into tokens with zero occurrences. Thus in Laplace smoothing, the reconstructed counts of non-zero tokens could change largely sometimes by a factor of 10 from their original counts. For example, token "i" has a Laplace probability of 0.269 compared to its original probability of 0.87 i.e. a 1/3rd of difference from original probability while KneserNey has somewhat managed to maintain the probability in proportion with original probability.
# Thus Laplace haven't worked in our Bigram model well and doesn't work well in general for n-grams.
#
# On the other hand, Kneser-Ney has somewhat maintained the probabilities with original Bigram probabilities compared to Laplace.
#
# Thus KneserNey smoothing is better than Laplace in this case

# %% [markdown]
# ## Task2 : Subtask 3: Output

# %%
# Checkign the bigram emotion dictionary that we build
bigram_model.bigram_emotion_dictionary
# Out:
# defaultdict(list,
#             {('$', 'i'): [0.8783333333333333,
#               [{'label': 'sadness', 'score': 0.10423965752124786},
#                {'label': 'joy', 'score': 0.22589899599552155},
#                {'label': 'love', 'score': 0.009581828489899635},
#                {'label': 'anger', 'score': 0.5985594391822815},
#                {'label': 'fear', 'score': 0.05375984311103821},
#                {'label': 'surprise', 'score': 0.007960204035043716}]],
#              ('i', 'stand'): [0.0005278437582475588,
#               [{'label': 'sadness', 'score': 0.03286624699831009},
#                {'label': 'joy', 'score': 0.6205080151557922},
#                {'label': 'love', 'score': 0.005959461908787489},
#                {'label': 'anger', 'score': 0.3174057602882385},
#                {'label': 'fear', 'score': 0.02032058872282505},
#                {'label': 'surprise', 'score': 0.002939873840659857}]],
#              ('stand', 'here'): [0.1,
#               [{'label': 'sadness', 'score': 0.01706150360405445},
#                {'label': 'joy', 'score': 0.08863870799541473},
#                {'label': 'love', 'score': 0.004713396541774273},
#                {'label': 'anger', 'score': 0.8493222594261169},
#                {'label': 'fear', 'score': 0.03744061663746834},
#                {'label': 'surprise', 'score': 0.002823571441695094}]],
#              ('here', 'i'): [0.16216216216216217,
#               [{'label': 'sadness', 'score': 0.0434395968914032},
#                {'label': 'joy', 'score': 0.2999154031276703},
#                {'label': 'love', 'score': 0.006999645382165909},
#                {'label': 'anger', 'score': 0.5763959884643555},
#                {'label': 'fear', 'score': 0.06560315936803818},
#                {'label': 'surprise', 'score': 0.007646265905350447}]],
#              ('i', 'feel'): [0.2684085510688836,
#               [{'label': 'sadness', 'score': 0.00825438555330038},
#                {'label': 'joy', 'score': 0.9858514666557312},
#                {'label': 'love', 'score': 0.002996954834088683},
#                {'label': 'anger', 'score': 0.0004264604358468205},
#                {'label': 'fear', 'score': 0.0015617568278685212},
#                {'label': 'surprise', 'score': 0.0009089621598832309}]],
#              ('feel', 'empty'): [0.0012217470983506415,
#               [{'label': 'sadness', 'score': 0.9989351630210876},
#                {'label': 'joy', 'score': 0.0002819137880578637},
#                {'label': 'love', 'score': 0.0002048028545686975},
#                {'label': 'anger', 'score': 0.0002405795967206359},
#                {'label': 'fear', 'score': 0.00017187480989377946},
#                {'label': 'surprise', 'score': 0.0001657181273913011}]],
#              ('empty', 'a'): [0.1111111111111111,
#               [{'label': 'sadness', 'score': 0.8936554789543152},
#                {'label': 'joy', 'score': 0.005435160361230373},
#                {'label': 'love', 'score': 0.001276118797250092},
#                {'label': 'anger', 'score': 0.09191250801086426},
#                {'label': 'fear', 'score': 0.005690691992640495},
#                {'label': 'surprise', 'score': 0.0020300152245908976}]],
#              ('a', 'class'): [0.001091703056768559,
#               [{'label': 'sadness', 'score': 0.07965762168169022},
#                {'label': 'joy', 'score': 0.13080742955207825},
#                {'label': 'love', 'score': 0.009628672152757645},
#                {'label': 'anger', 'score': 0.5294419527053833},
#                {'label': 'fear', 'score': 0.23553228378295898},
#                {'label': 'surprise', 'score': 0.014932024292647839}]],
#              ('class', 'post'): [0.07692307692307693,
#               [{'label': 'sadness', 'score': 0.06426210701465607},
#                {'label': 'joy', 'score': 0.11039337515830994},
#                {'label': 'love', 'score': 0.00572242122143507},
#                {'label': 'anger', 'score': 0.4875027537345886},
#                {'label': 'fear', 'score': 0.32266390323638916},
#                {'label': 'surprise', 'score': 0.009455408900976181}]],
#              ('post', 'count'): [0.07142857142857142,
#               [{'label': 'sadness', 'score': 0.03694777563214302},
#                {'label': 'joy', 'score': 0.1635637879371643},
#                {'label': 'love', 'score': 0.007834730669856071},
#                {'label': 'anger', 'score': 0.3940301239490509},
#                {'label': 'fear', 'score': 0.38215938210487366},
#                {'label': 'surprise', 'score': 0.015464132651686668}]],
#              ('count', 'link'): [0.25,
#               [{'label': 'sadness', 'score': 0.05700260028243065},
#                {'label': 'joy', 'score': 0.6150254607200623},
#                {'label': 'love', 'score': 0.024591999128460884},
#                {'label': 'anger', 'score': 0.1566273272037506},
#                {'label': 'fear', 'score': 0.12518784403800964},
#                {'label': 'surprise', 'score': 0.02156483195722103}]],
#              ('link', 'href'): [0.5,
#               [{'label': 'sadness', 'score': 0.03599173203110695},
#                {'label': 'joy', 'score': 0.7433592081069946},
#                {'label': 'love', 'score': 0.009290722198784351},
#                {'label': 'anger', 'score': 0.14768454432487488},
#                {'label': 'fear', 'score': 0.05955115333199501},
#                {'label': 'surprise', 'score': 0.004122631158679724}]],
#              ('href', 'http'): [1.0,
#               [{'label': 'sadness', 'score': 0.03582065925002098},
#                {'label': 'joy', 'score': 0.6180650591850281},
#                {'label': 'love', 'score': 0.008792777545750141},
#                {'label': 'anger', 'score': 0.22560444474220276},
#                {'label': 'fear', 'score': 0.1060946136713028},
#                {'label': 'surprise', 'score': 0.00562242278829217}]],
#              ('http', 'mooshilu'): [0.03333333333333333,
#               [{'label': 'sadness', 'score': 0.055967777967453},
#                {'label': 'joy', 'score': 0.5432828068733215},
#                {'label': 'love', 'score': 0.01360287144780159},
#                {'label': 'anger', 'score': 0.23066213726997375},
#                {'label': 'fear', 'score': 0.14691509306430817},
#                {'label': 'surprise', 'score': 0.00956934317946434}]],
#              ('mooshilu', '$'): [1.0,
#               [{'label': 'sadness', 'score': 0.10362249612808228},
#                {'label': 'joy', 'score': 0.34166067838668823},
#                {'label': 'love', 'score': 0.011772985570132732},
#                {'label': 'anger', 'score': 0.45864567160606384},
#                {'label': 'fear', 'score': 0.072626031935215},
#                {'label': 'surprise', 'score': 0.011672214604914188}]],
#              ('i', 'literally'): [0.0002639218791237794,
#               [{'label': 'sadness', 'score': 0.012756098061800003},
#                {'label': 'joy', 'score': 0.04198290780186653},
#                {'label': 'love', 'score': 0.0016674718353897333},
#                {'label': 'anger', 'score': 0.923225998878479},
#                {'label': 'fear', 'score': 0.01776188798248768},
#                {'label': 'surprise', 'score': 0.0026056431233882904}]],
#              ('literally', 'just'): [0.25,
#               [{'label': 'sadness', 'score': 0.0354812890291214},
#                {'label': 'joy', 'score': 0.16118374466896057},
#                {'label': 'love', 'score': 0.00411845650523901},
#                {'label': 'anger', 'score': 0.7293803095817566},
#                {'label': 'fear', 'score': 0.06034058704972267},
#                {'label': 'surprise', 'score': 0.009495622478425503}]],
#              ('just', 'text'): [0.004424778761061947,
#               [{'label': 'sadness', 'score': 0.02339216321706772},
#                {'label': 'joy', 'score': 0.7345888614654541},
#                {'label': 'love', 'score': 0.005150957498699427},
#                {'label': 'anger', 'score': 0.2073078751564026},
#                {'label': 'fear', 'score': 0.02656414546072483},
#                {'label': 'surprise', 'score': 0.0029960444662719965}]],
#              ('text', 'tychelle'): [0.3333333333333333,
#               [{'label': 'sadness', 'score': 0.0508820079267025},
#                {'label': 'joy', 'score': 0.3104599714279175},
#                {'label': 'love', 'score': 0.009779227897524834},
#                {'label': 'anger', 'score': 0.3934396207332611},
#                {'label': 'fear', 'score': 0.22740411758422852},
#                {'label': 'surprise', 'score': 0.008035141043365002}]],
#              ('tychelle', 'to'): [1.0,
#               [{'label': 'sadness', 'score': 0.018336694687604904},
#                {'label': 'joy', 'score': 0.05249081924557686},
#                {'label': 'love', 'score': 0.011578735895454884},
#                {'label': 'anger', 'score': 0.7762421369552612},
#                {'label': 'fear', 'score': 0.13574595749378204},
#                {'label': 'surprise', 'score': 0.0056056370958685875}]],
#              ('to', 'see'): [0.011194029850746268,
#               [{'label': 'sadness', 'score': 0.06067473441362381},
#                {'label': 'joy', 'score': 0.6660733222961426},
#                {'label': 'love', 'score': 0.011967414058744907},
#                {'label': 'anger', 'score': 0.20922452211380005},
#                {'label': 'fear', 'score': 0.04007582366466522},
#                {'label': 'surprise', 'score': 0.011984151788055897}]],
#              ('see', 'if'): [0.06666666666666667,
#               [{'label': 'sadness', 'score': 0.055648140609264374},
#                {'label': 'joy', 'score': 0.5086234211921692},
#                {'label': 'love', 'score': 0.01076199859380722},
#                {'label': 'anger', 'score': 0.23989203572273254},
#                {'label': 'fear', 'score': 0.17158937454223633},
#                {'label': 'surprise', 'score': 0.013484995812177658}]],
#              ('if', 'she'): [0.007462686567164179,
#               [{'label': 'sadness', 'score': 0.03385219722986221},
#                {'label': 'joy', 'score': 0.029361093416810036},
#                {'label': 'love', 'score': 0.003520676400512457},
#                {'label': 'anger', 'score': 0.7227073907852173},
#                {'label': 'fear', 'score': 0.20759516954421997},
#                {'label': 'surprise', 'score': 0.0029634968377649784}]],
#              ('she', 'wants'): [0.027777777777777776,
#               [{'label': 'sadness', 'score': 0.006414561532437801},
#                {'label': 'joy', 'score': 0.008439782075583935},
#                {'label': 'love', 'score': 0.002204484073445201},
#                {'label': 'anger', 'score': 0.9771664142608643},
#                {'label': 'fear', 'score': 0.005216378718614578},
#                {'label': 'surprise', 'score': 0.0005583574529737234}]],
#              ('wants', 'to'): [0.42857142857142855,
#               [{'label': 'sadness', 'score': 0.010214275680482388},
#                {'label': 'joy', 'score': 0.031190963461995125},
#                {'label': 'love', 'score': 0.008670640178024769},
#                {'label': 'anger', 'score': 0.9367806911468506},
#                {'label': 'fear', 'score': 0.012198909185826778},
#                {'label': 'surprise', 'score': 0.0009445002651773393}]],
#              ('to', 'hang'): [0.0007462686567164179,
#               [{'label': 'sadness', 'score': 0.027212554588913918},
#                {'label': 'joy', 'score': 0.051184918731451035},
#                {'label': 'love', 'score': 0.003952174913138151},
#                {'label': 'anger', 'score': 0.8091684579849243},
#                {'label': 'fear', 'score': 0.10558594763278961},
#                {'label': 'surprise', 'score': 0.002895970828831196}]],
#              ('hang', 'out'): [1.0,
#               [{'label': 'sadness', 'score': 0.009432089515030384},
#                {'label': 'joy', 'score': 0.8736715316772461},
#                {'label': 'love', 'score': 0.005836353171616793},
#                {'label': 'anger', 'score': 0.0904858186841011},
#                {'label': 'fear', 'score': 0.018132302910089493},
#                {'label': 'surprise', 'score': 0.0024419245310127735}]],
#              ('out', 'because'): [0.008849557522123894,
#               [{'label': 'sadness', 'score': 0.01020867470651865},
#                {'label': 'joy', 'score': 0.009939336217939854},
#                {'label': 'love', 'score': 0.0012197727337479591},
#                {'label': 'anger', 'score': 0.9658795595169067},
#                {'label': 'fear', 'score': 0.011821269989013672},
#                {'label': 'surprise', 'score': 0.000931327638681978}]],
#              ('because', 'reading'): [0.00546448087431694,
#               [{'label': 'sadness', 'score': 0.03634018823504448},
#                {'label': 'joy', 'score': 0.07646901160478592},
#                {'label': 'love', 'score': 0.0037733663339167833},
#                {'label': 'anger', 'score': 0.7335743308067322},
#                {'label': 'fear', 'score': 0.1444682776927948},
#                {'label': 'surprise', 'score': 0.005374842323362827}]],
#              ('reading', 'what'): [0.07692307692307693,
#               [{'label': 'sadness', 'score': 0.029311323538422585},
#                {'label': 'joy', 'score': 0.2415405660867691},
#                {'label': 'love', 'score': 0.005015047267079353},
#                {'label': 'anger', 'score': 0.4709511995315552},
#                {'label': 'fear', 'score': 0.23403435945510864},
#                {'label': 'surprise', 'score': 0.019147535786032677}]],
#              ('what', 'i'): [0.344,
#               [{'label': 'sadness', 'score': 0.020912425592541695},
#                {'label': 'joy', 'score': 0.018594026565551758},
#                {'label': 'love', 'score': 0.001788830617442727},
#                {'label': 'anger', 'score': 0.9250249266624451},
#                {'label': 'fear', 'score': 0.03133287653326988},
#                {'label': 'surprise', 'score': 0.0023469107691198587}]],
#              ('i', 'just'): [0.015571390868302983,
#               [{'label': 'sadness', 'score': 0.07967972755432129},
#                {'label': 'joy', 'score': 0.03697045147418976},
#                {'label': 'love', 'score': 0.0012322039110586047},
#                {'label': 'anger', 'score': 0.7282768487930298},
#                {'label': 'fear', 'score': 0.15092602372169495},
#                {'label': 'surprise', 'score': 0.002914842450991273}]],
#              ('just', 'wrote'): [0.004424778761061947,
#               [{'label': 'sadness', 'score': 0.036702461540699005},
#                {'label': 'joy', 'score': 0.4589326083660126},
#                {'label': 'love', 'score': 0.00414098147302866},
#                {'label': 'anger', 'score': 0.4770679473876953},
#                {'label': 'fear', 'score': 0.020363332703709602},
#                {'label': 'surprise', 'score': 0.0027926978655159473}]],
#              ('wrote', 'about'): [0.25,
#               [{'label': 'sadness', 'score': 0.041137613356113434},
#                {'label': 'joy', 'score': 0.39448538422584534},
#                {'label': 'love', 'score': 0.013918326236307621},
#                {'label': 'anger', 'score': 0.4789581894874573},
#                {'label': 'fear', 'score': 0.06231841817498207},
#                {'label': 'surprise', 'score': 0.009182059206068516}]],
#              ('about', 'my'): [0.0738255033557047,
#               [{'label': 'sadness', 'score': 0.014840283431112766},
#                {'label': 'joy', 'score': 0.015420678071677685},
#                {'label': 'love', 'score': 0.0024684532545506954},
#                {'label': 'anger', 'score': 0.9440321326255798},
#                {'label': 'fear', 'score': 0.022071806713938713},
#                {'label': 'surprise', 'score': 0.0011666564969345927}]],
#              ('my', 'nonexistent'): [0.001557632398753894,
#               [{'label': 'sadness', 'score': 0.470567524433136},
#                {'label': 'joy', 'score': 0.17118938267230988},
#                {'label': 'love', 'score': 0.008943515829741955},
#                {'label': 'anger', 'score': 0.3233548700809479},
#                {'label': 'fear', 'score': 0.02339261770248413},
#                {'label': 'surprise', 'score': 0.0025521302595734596}]],
#              ('nonexistent', 'social'): [1.0,
#               [{'label': 'sadness', 'score': 0.14671526849269867},
#                {'label': 'joy', 'score': 0.03910491243004799},
#                {'label': 'love', 'score': 0.00226309010758996},
#                {'label': 'anger', 'score': 0.780265212059021},
#                {'label': 'fear', 'score': 0.02954927273094654},
#                {'label': 'surprise', 'score': 0.002102198312059045}]],
#              ('social', 'life'): [0.2857142857142857,
#               [{'label': 'sadness', 'score': 0.13813909888267517},
#                {'label': 'joy', 'score': 0.30629274249076843},
#                {'label': 'love', 'score': 0.009562970139086246},
#                {'label': 'anger', 'score': 0.4960280954837799},
#                {'label': 'fear', 'score': 0.04390186443924904},
#                {'label': 'surprise', 'score': 0.006075271870940924}]],
#              ('life', 'made'): [0.010416666666666666,
#               [{'label': 'sadness', 'score': 0.06314539164304733},
#                {'label': 'joy', 'score': 0.8154813051223755},
#                {'label': 'love', 'score': 0.005282101221382618},
#                {'label': 'anger', 'score': 0.10360614210367203},
#                {'label': 'fear', 'score': 0.009487266652286053},
#                {'label': 'surprise', 'score': 0.0029978398233652115}]],
#              ('made', 'me'): [0.4444444444444444,
#               [{'label': 'sadness', 'score': 0.11357714980840683},
#                {'label': 'joy', 'score': 0.3194361627101898},
#                {'label': 'love', 'score': 0.03829694911837578},
#                {'label': 'anger', 'score': 0.4871821999549866},
#                {'label': 'fear', 'score': 0.033928755670785904},
#                {'label': 'surprise', 'score': 0.00757878553122282}]],
#              ('me', 'feel'): [0.11518324607329843,
#               [{'label': 'sadness', 'score': 0.005674243438988924},
#                {'label': 'joy', 'score': 0.9866509437561035},
#                {'label': 'love', 'score': 0.005052507389336824},
#                {'label': 'anger', 'score': 0.0006009484059177339},
#                {'label': 'fear', 'score': 0.0013342475285753608},
#                {'label': 'surprise', 'score': 0.0006871749646961689}]],
#              ('feel', 'so'): [0.06719609040928527,
#               [{'label': 'sadness', 'score': 0.001390505232848227},
#                {'label': 'joy', 'score': 0.9799774289131165},
#                {'label': 'love', 'score': 0.01649037003517151},
#                {'label': 'anger', 'score': 0.00043171996367163956},
#                {'label': 'fear', 'score': 0.0004674117953982204},
#                {'label': 'surprise', 'score': 0.0012424332089722157}]],
#              ('so', 'pathetic'): [0.00546448087431694,
#               [{'label': 'sadness', 'score': 0.9958621263504028},
#                {'label': 'joy', 'score': 0.000412325985962525},
#                {'label': 'love', 'score': 0.00027783820405602455},
#                {'label': 'anger', 'score': 0.0029865491669625044},
#                {'label': 'fear', 'score': 0.00020007125567644835},
#                {'label': 'surprise', 'score': 0.00026114474167115986}]],
#              ('pathetic', '$'): [0.16666666666666666,
#               [{'label': 'sadness', 'score': 0.9581310749053955},
#                {'label': 'joy', 'score': 0.001299029216170311},
#                {'label': 'love', 'score': 0.0006132409325800836},
#                {'label': 'anger', 'score': 0.03843534737825394},
#                {'label': 'fear', 'score': 0.0008421383099630475},
#                {'label': 'surprise', 'score': 0.0006793061038479209}]],
#              ('i', 'really'): [0.008973343890208499,
#               [{'label': 'sadness', 'score': 0.05498948693275452},
#                {'label': 'joy', 'score': 0.6591706871986389},
#                {'label': 'love', 'score': 0.0038123426493257284},
#                {'label': 'anger', 'score': 0.24554656445980072},
#                {'label': 'fear', 'score': 0.0320492759346962},
#                {'label': 'surprise', 'score': 0.00443168543279171}]],
#              ('really', 'feel'): [0.07006369426751592,
#               [{'label': 'sadness', 'score': 0.00348957278765738},
#                {'label': 'joy', 'score': 0.9914169907569885},
#                {'label': 'love', 'score': 0.001963494112715125},
#                {'label': 'anger', 'score': 0.0006449971115216613},
#                {'label': 'fear', 'score': 0.0015229586279019713},
#                {'label': 'surprise', 'score': 0.0009619916090741754}]],
#              ('feel', 'regretful'): [0.0012217470983506415,
#               [{'label': 'sadness', 'score': 0.9987132549285889},
#                {'label': 'joy', 'score': 0.00041056351619772613},
#                {'label': 'love', 'score': 0.0002439176314510405},
#                {'label': 'anger', 'score': 0.00036696952884085476},
#                {'label': 'fear', 'score': 0.00014444049156736583},
#                {'label': 'surprise', 'score': 0.00012094598059775308}]],
#              ('regretful', 'when'): [0.16666666666666666,
#               [{'label': 'sadness', 'score': 0.9875882267951965},
#                {'label': 'joy', 'score': 0.001983677502721548},
#                {'label': 'love', 'score': 0.0006450397195294499},
#                {'label': 'anger', 'score': 0.009194656275212765},
#                {'label': 'fear', 'score': 0.00035430522984825075},
#                {'label': 'surprise', 'score': 0.00023419017088599503}]],
#              ('when', 'hearing'): [0.0043859649122807015,
#               [{'label': 'sadness', 'score': 0.013754674233496189},
#                {'label': 'joy', 'score': 0.05151702091097832},
#                {'label': 'love', 'score': 0.00266519864089787},
#                {'label': 'anger', 'score': 0.27934756875038147},
#                {'label': 'fear', 'score': 0.6458768248558044},
#                {'label': 'surprise', 'score': 0.006838721688836813}]],
#              ('hearing', 'that'): [0.5,
#               [{'label': 'sadness', 'score': 0.017543388530611992},
#                {'label': 'joy', 'score': 0.04785146191716194},
#                {'label': 'love', 'score': 0.003080504946410656},
#                {'label': 'anger', 'score': 0.8588192462921143},
#                {'label': 'fear', 'score': 0.06747844070196152},
#                {'label': 'surprise', 'score': 0.0052269804291427135}]],
#              ('that', 'shinae'): [0.001256281407035176,
#               [{'label': 'sadness', 'score': 0.00948810949921608},
#                {'label': 'joy', 'score': 0.011034149676561356},
#                {'label': 'love', 'score': 0.0028901146724820137},
#                {'label': 'anger', 'score': 0.93965083360672},
#                {'label': 'fear', 'score': 0.034525200724601746},
#                {'label': 'surprise', 'score': 0.0024116146378219128}]],
#              ('shinae', 'got'): [0.5,
#               [{'label': 'sadness', 'score': 0.0598832443356514},
#                {'label': 'joy', 'score': 0.3619542121887207},
#                {'label': 'love', 'score': 0.009081981144845486},
#                {'label': 'anger', 'score': 0.48836666345596313},
#                {'label': 'fear', 'score': 0.06966738402843475},
#                {'label': 'surprise', 'score': 0.01104654185473919}]],
#              ('got', 'married'): [0.024390243902439025,
#               [{'label': 'sadness', 'score': 0.04684164747595787},
#                {'label': 'joy', 'score': 0.2947778105735779},
#                {'label': 'love', 'score': 0.06863667815923691},
#                {'label': 'anger', 'score': 0.5348241925239563},
#                {'label': 'fear', 'score': 0.050136830657720566},
#                {'label': 'surprise', 'score': 0.004782843869179487}]],
#              ('married', 'to'): [0.25,
#               [{'label': 'sadness', 'score': 0.05127633735537529},
#                {'label': 'joy', 'score': 0.04130569100379944},
#                {'label': 'love', 'score': 0.13434183597564697},
#                {'label': 'anger', 'score': 0.6309580206871033},
#                {'label': 'fear', 'score': 0.13631665706634521},
#                {'label': 'surprise', 'score': 0.005801578052341938}]],
#              ('to', 'another'): [0.0014925373134328358,
#               [{'label': 'sadness', 'score': 0.02068500965833664},
#                {'label': 'joy', 'score': 0.04160934314131737},
#                {'label': 'love', 'score': 0.006850855890661478},
#                {'label': 'anger', 'score': 0.8581269383430481},
#                {'label': 'fear', 'score': 0.06601859629154205},
#                {'label': 'surprise', 'score': 0.00670925248414278}]],
#              ('another', 'man'): [0.05263157894736842,
#               [{'label': 'sadness', 'score': 0.022720135748386383},
#                {'label': 'joy', 'score': 0.01387135498225689},
#                {'label': 'love', 'score': 0.00236055557616055},
#                {'label': 'anger', 'score': 0.9207622408866882},
#                {'label': 'fear', 'score': 0.0375857800245285},
#                {'label': 'surprise', 'score': 0.002699917182326317}]],
#              ('man', 'oh'): [0.07692307692307693,
#               [{'label': 'sadness', 'score': 0.026930183172225952},
#                {'label': 'joy', 'score': 0.10005152970552444},
#                {'label': 'love', 'score': 0.007039567455649376},
#                {'label': 'anger', 'score': 0.8082700967788696},
#                {'label': 'fear', 'score': 0.0480046421289444},
#                {'label': 'surprise', 'score': 0.009703895077109337}]],
#              ('oh', 'it'): [0.125,
#               [{'label': 'sadness', 'score': 0.07625927031040192},
#                {'label': 'joy', 'score': 0.24200239777565002},
#                {'label': 'love', 'score': 0.016445891931653023},
#                {'label': 'anger', 'score': 0.5489014983177185},
#                {'label': 'fear', 'score': 0.07948379218578339},
#                {'label': 'surprise', 'score': 0.036907169967889786}]],
#              ('it', 's'): [0.05048543689320388,
#               [{'label': 'sadness', 'score': 0.04841827601194382},
#                {'label': 'joy', 'score': 0.15544995665550232},
#                {'label': 'love', 'score': 0.00592420157045126},
#                {'label': 'anger', 'score': 0.6086313128471375},
#                {'label': 'fear', 'score': 0.17405810952186584},
#                {'label': 'surprise', 'score': 0.007518066558986902}]],
#              ('s', 'really'): [0.012195121951219513,
#               [{'label': 'sadness', 'score': 0.042246825993061066},
#                {'label': 'joy', 'score': 0.6516071557998657},
#                {'label': 'love', 'score': 0.00697032967582345},
#                {'label': 'anger', 'score': 0.23640276491641998},
#                {'label': 'fear', 'score': 0.0543624609708786},
#                {'label': 'surprise', 'score': 0.008410472422838211}]],
#              ('really', 'sad'): [0.006369426751592357,
#               [{'label': 'sadness', 'score': 0.9973872303962708},
#                {'label': 'joy', 'score': 0.000690567831043154},
#                {'label': 'love', 'score': 0.00030374425114132464},
#                {'label': 'anger', 'score': 0.0010952885495498776},
#                {'label': 'fear', 'score': 0.0003630838473327458},
#                {'label': 'surprise', 'score': 0.0001600145042175427}]],
#              ('sad', 'i'): [0.08333333333333333,
#               [{'label': 'sadness', 'score': 0.9955524802207947},
#                {'label': 'joy', 'score': 0.0009533124975860119},
#                {'label': 'love', 'score': 0.00045896691153757274},
#                {'label': 'anger', 'score': 0.0024923738092184067},
#                {'label': 'fear', 'score': 0.00035582634154707193},
#                {'label': 'surprise', 'score': 0.0001870260020950809}]],
#              ('really', 'hope'): [0.012738853503184714,
#               [{'label': 'sadness', 'score': 0.0031633933540433645},
#                {'label': 'joy', 'score': 0.9871972799301147},
#                {'label': 'love', 'score': 0.0018069831421598792},
#                {'label': 'anger', 'score': 0.004734178073704243},
#                {'label': 'fear', 'score': 0.0024670292623341084},
#                {'label': 'surprise', 'score': 0.0006311247707344592}]],
#              ('hope', 'that'): [0.15,
#               [{'label': 'sadness', 'score': 0.0033714380115270615},
#                {'label': 'joy', 'score': 0.9842342734336853},
#                {'label': 'love', 'score': 0.0039656939916312695},
#                {'label': 'anger', 'score': 0.006109023001044989},
#                {'label': 'fear', 'score': 0.0017670581582933664},
#                {'label': 'surprise', 'score': 0.0005523767904378474}]],
#              ('that', 'alex'): [0.001256281407035176,
#               [{'label': 'sadness', 'score': 0.007231061812490225},
#                {'label': 'joy', 'score': 0.017422406002879143},
#                {'label': 'love', 'score': 0.003949661739170551},
#                {'label': 'anger', 'score': 0.9486035108566284},
#                {'label': 'fear', 'score': 0.021069170907139778},
#                {'label': 'surprise', 'score': 0.0017241118475794792}]],
#              ('alex', 'and'): [1.0,
#               [{'label': 'sadness', 'score': 0.037970468401908875},
#                {'label': 'joy', 'score': 0.20144420862197876},
#                {'label': 'love', 'score': 0.019321449100971222},
#                {'label': 'anger', 'score': 0.6137388944625854},
#                {'label': 'fear', 'score': 0.11829015612602234},
#                {'label': 'surprise', 'score': 0.009234766475856304}]],
#              ('and', 'shinae'): [0.0006882312456985547,
#               [{'label': 'sadness', 'score': 0.02548355981707573},
#                {'label': 'joy', 'score': 0.05952249467372894},
#                {'label': 'love', 'score': 0.011084427125751972},
#                {'label': 'anger', 'score': 0.8106154203414917},
#                {'label': 'fear', 'score': 0.08743690699338913},
#                {'label': 'surprise', 'score': 0.005857242736965418}]],
#              ('shinae', 'can'): [0.5,
#               [{'label': 'sadness', 'score': 0.05283650755882263},
#                {'label': 'joy', 'score': 0.1539619415998459},
#                {'label': 'love', 'score': 0.010946514084935188},
#                {'label': 'anger', 'score': 0.522132396697998},
#                {'label': 'fear', 'score': 0.24785074591636658},
#                {'label': 'surprise', 'score': 0.012271890416741371}]],
#              ('can', 'be'): [0.058823529411764705,
#               [{'label': 'sadness', 'score': 0.0399332121014595},
#                {'label': 'joy', 'score': 0.7467379570007324},
#                {'label': 'love', 'score': 0.006725167389959097},
#                {'label': 'anger', 'score': 0.1325874924659729},
#                {'label': 'fear', 'score': 0.06561435759067535},
#                {'label': 'surprise', 'score': 0.008401819504797459}]],
#              ('be', 'a'): [0.06545454545454546,
#               [{'label': 'sadness', 'score': 0.04141515865921974},
#                {'label': 'joy', 'score': 0.47748062014579773},
#                {'label': 'love', 'score': 0.009464023634791374},
#                {'label': 'anger', 'score': 0.42433643341064453},
#                {'label': 'fear', 'score': 0.04179761931300163},
#                {'label': 'surprise', 'score': 0.005506202112883329}]],
#              ('a', 'couple'): [0.009825327510917031,
#               [{'label': 'sadness', 'score': 0.009539627470076084},
#                {'label': 'joy', 'score': 0.014584136195480824},
#                {'label': 'love', 'score': 0.002417095936834812},
#                {'label': 'anger', 'score': 0.913445770740509},
#                {'label': 'fear', 'score': 0.05773666128516197},
#                {'label': 'surprise', 'score': 0.0022767914924770594}]],
#              ('couple', 'in'): [0.07692307692307693,
#               [{'label': 'sadness', 'score': 0.04763086140155792},
#                {'label': 'joy', 'score': 0.07394245266914368},
#                {'label': 'love', 'score': 0.053462591022253036},
#                {'label': 'anger', 'score': 0.6240092515945435},
#                {'label': 'fear', 'score': 0.1936679482460022},
#                {'label': 'surprise', 'score': 0.007286951411515474}]],
#              ('in', 'real'): [0.0019646365422396855,
#               [{'label': 'sadness', 'score': 0.034521326422691345},
#                {'label': 'joy', 'score': 0.5541649460792542},
#                {'label': 'love', 'score': 0.0042808991856873035},
#                {'label': 'anger', 'score': 0.291518896818161},
#                {'label': 'fear', 'score': 0.10818257182836533},
#                {'label': 'surprise', 'score': 0.007331347558647394}]],
#              ('real', 'life'): [0.23076923076923078,
#               [{'label': 'sadness', 'score': 0.07974094152450562},
#                {'label': 'joy', 'score': 0.49394020438194275},
#                {'label': 'love', 'score': 0.005619289819151163},
#                {'label': 'anger', 'score': 0.2299802154302597},
#                {'label': 'fear', 'score': 0.1828555017709732},
#                {'label': 'surprise', 'score': 0.007863846607506275}]],
#              ('life', 'they'): [0.010416666666666666,
#               [{'label': 'sadness', 'score': 0.12653377652168274},
#                {'label': 'joy', 'score': 0.14224377274513245},
#                {'label': 'love', 'score': 0.011347997933626175},
#                {'label': 'anger', 'score': 0.6873093247413635},
#                {'label': 'fear', 'score': 0.028120456263422966},
#                {'label': 'surprise', 'score': 0.00444472162052989}]],
#              ('they', 're'): [0.027522935779816515,
#               [{'label': 'sadness', 'score': 0.02176816761493683},
#                {'label': 'joy', 'score': 0.11863076686859131},
#                {'label': 'love', 'score': 0.0034834512043744326},
#                {'label': 'anger', 'score': 0.8313398957252502},
#                {'label': 'fear', 'score': 0.022347593680024147},
#                {'label': 'surprise', 'score': 0.0024301577359437943}]],
#              ('re', 'perfect'): [0.047619047619047616,
#               [{'label': 'sadness', 'score': 0.0007599213859066367},
#                {'label': 'joy', 'score': 0.9977188110351562},
#                {'label': 'love', 'score': 0.0005093047511763871},
#                {'label': 'anger', 'score': 0.0005246270447969437},
#                {'label': 'fear', 'score': 0.00027266136021353304},
#                {'label': 'surprise', 'score': 0.00021485630713868886}]],
#              ('perfect', 'for'): [0.2222222222222222,
#               [{'label': 'sadness', 'score': 0.0012242371449247003},
#                {'label': 'joy', 'score': 0.9956861734390259},
#                {'label': 'love', 'score': 0.0008322066278196871},
#                {'label': 'anger', 'score': 0.0013157948851585388},
#                {'label': 'fear', 'score': 0.0004740345466416329},
#                {'label': 'surprise', 'score': 0.0004675783566199243}]],
#              ('for', 'each'): [0.0103359173126615,
#               [{'label': 'sadness', 'score': 0.05629409849643707},
#                {'label': 'joy', 'score': 0.6132298111915588},
#                {'label': 'love', 'score': 0.023861447349190712},
#                {'label': 'anger', 'score': 0.2582980692386627},
#                {'label': 'fear', 'score': 0.03880541771650314},
#                {'label': 'surprise', 'score': 0.009511194191873074}]],
#              ('each', 'other'): [0.35294117647058826,
#               [{'label': 'sadness', 'score': 0.03712256997823715},
#                {'label': 'joy', 'score': 0.041995298117399216},
#                {'label': 'love', 'score': 0.10067518055438995},
#                {'label': 'anger', 'score': 0.7033397555351257},
#                {'label': 'fear', 'score': 0.11178035289049149},
#                {'label': 'surprise', 'score': 0.005086855497211218}]],
#              ('other', '$'): [0.0425531914893617,
#               [{'label': 'sadness', 'score': 0.08995342254638672},
#                {'label': 'joy', 'score': 0.3528788387775421},
#                {'label': 'love', 'score': 0.010191249661147594},
#                {'label': 'anger', 'score': 0.46317678689956665},
#                {'label': 'fear', 'score': 0.07288993149995804},
#                {'label': 'surprise', 'score': 0.01090974174439907}]],
#              ('i', 'believed'): [0.0002639218791237794,
#               [{'label': 'sadness', 'score': 0.002903260290622711},
#                {'label': 'joy', 'score': 0.9836940169334412},
#                {'label': 'love', 'score': 0.003398897359147668},
#                {'label': 'anger', 'score': 0.00707026943564415},
#                {'label': 'fear', 'score': 0.002245930954813957},
#                {'label': 'surprise', 'score': 0.0006874724058434367}]],
#              ('believed', 'it'): [0.5,
#               [{'label': 'sadness', 'score': 0.01196375023573637},
#                {'label': 'joy', 'score': 0.8709796667098999},
#                {'label': 'love', 'score': 0.006583471316844225},
#                {'label': 'anger', 'score': 0.09397878497838974},
#                {'label': 'fear', 'score': 0.014456464909017086},
#                {'label': 'surprise', 'score': 0.0020377621985971928}]],
#              ('it', 'was'): [0.07572815533980583,
#               [{'label': 'sadness', 'score': 0.04928325116634369},
#                {'label': 'joy', 'score': 0.21803061664104462},
#                {'label': 'love', 'score': 0.00585352024063468},
#                {'label': 'anger', 'score': 0.6655757427215576},
#                {'label': 'fear', 'score': 0.0529291108250618},
#                {'label': 'surprise', 'score': 0.008327753283083439}]],
#              ('was', 'true'): [0.0029498525073746312,
#               [{'label': 'sadness', 'score': 0.0023366992827504873},
#                {'label': 'joy', 'score': 0.990036129951477},
#                {'label': 'love', 'score': 0.0017535032238811255},
#                {'label': 'anger', 'score': 0.003979769069701433},
#                {'label': 'fear', 'score': 0.0011302895145490766},
#                {'label': 'surprise', 'score': 0.0007635955116711557}]],
#              ('true', 'love'): [0.125,
#               [{'label': 'sadness', 'score': 0.0022339853458106518},
#                {'label': 'joy', 'score': 0.976373553276062},
#                {'label': 'love', 'score': 0.01855941116809845},
#                {'label': 'anger', 'score': 0.0019326085457578301},
#                {'label': 'fear', 'score': 0.0005463965353555977},
#                {'label': 'surprise', 'score': 0.00035406765528023243}]],
#              ('love', 'and'): [0.07142857142857142,
#               [{'label': 'sadness', 'score': 0.028595365583896637},
#                {'label': 'joy', 'score': 0.13118988275527954},
#                {'label': 'love', 'score': 0.7156040072441101},
#                {'label': 'anger', 'score': 0.11111513525247574},
#                {'label': 'fear', 'score': 0.009702993556857109},
#                {'label': 'surprise', 'score': 0.0037925352808088064}]],
#              ('and', 'feel'): [0.02477632484514797,
#               [{'label': 'sadness', 'score': 0.002065615262836218},
#                {'label': 'joy', 'score': 0.9928286671638489},
#                {'label': 'love', 'score': 0.0028520040214061737},
#                {'label': 'anger', 'score': 0.0008261942421086133},
#                {'label': 'fear', 'score': 0.000891971867531538},
#                {'label': 'surprise', 'score': 0.000535555649548769}]],
#              ('feel', 'devastated'): [0.0030543677458766036,
#               [{'label': 'sadness', 'score': 0.9989332556724548},
#                {'label': 'joy', 'score': 0.00023113244969863445},
#                {'label': 'love', 'score': 0.00023360821069218218},
#                {'label': 'anger', 'score': 0.0002327342954231426},
#                {'label': 'fear', 'score': 0.0002058922837022692},
#                {'label': 'surprise', 'score': 0.00016336205590050668}]],
#              ('devastated', 'i'): [0.125,
#               [{'label': 'sadness', 'score': 0.9984695315361023},
#                {'label': 'joy', 'score': 0.00032853649463504553},
#                {'label': 'love', 'score': 0.00021359609672799706},
#                {'label': 'anger', 'score': 0.0005299504846334457},
#                {'label': 'fear', 'score': 0.00029241605079732835},
#                {'label': 'surprise', 'score': 0.00016592451720498502}]],
#              ('i', 'wanted'): [0.003167062549485352,
#               [{'label': 'sadness', 'score': 0.006121667101979256},
#                {'label': 'joy', 'score': 0.003396594198420644},
#                {'label': 'love', 'score': 0.006551163271069527},
#                {'label': 'anger', 'score': 0.9771320223808289},
#                {'label': 'fear', 'score': 0.006269738078117371},
#                {'label': 'surprise', 'score': 0.0005288373213261366}]],
#              ('wanted', 'to'): [0.75,
#               [{'label': 'sadness', 'score': 0.006256746593862772},
#                {'label': 'joy', 'score': 0.006811512168496847},
#                {'label': 'love', 'score': 0.010121711529791355},
#                {'label': 'anger', 'score': 0.955845057964325},
#                {'label': 'fear', 'score': 0.020020034164190292},
#                {'label': 'surprise', 'score': 0.0009449193603359163}]],
#              ('to', 'settle'): [0.002238805970149254,
#               [{'label': 'sadness', 'score': 0.04838338494300842},
#                {'label': 'joy', 'score': 0.38067948818206787},
#                {'label': 'love', 'score': 0.008699469268321991},
#                {'label': 'anger', 'score': 0.5260547995567322},
#                {'label': 'fear', 'score': 0.03295794874429703},
#                {'label': 'surprise', 'score': 0.0032249740324914455}]],
#              ('settle', 'down'): [0.3333333333333333,
#               [{'label': 'sadness', 'score': 0.08696971833705902},
#                {'label': 'joy', 'score': 0.8152388334274292},
#                {'label': 'love', 'score': 0.005948389880359173},
#                {'label': 'anger', 'score': 0.06221403554081917},
#                {'label': 'fear', 'score': 0.026798803359270096},
#                {'label': 'surprise', 'score': 0.0028303354047238827}]],
#              ('down', 'and'): [0.12903225806451613,
#               [{'label': 'sadness', 'score': 0.030473971739411354},
#                {'label': 'joy', 'score': 0.0411868579685688},
#                {'label': 'love', 'score': 0.005531990434974432},
#                {'label': 'anger', 'score': 0.8016166687011719},
#                {'label': 'fear', 'score': 0.11452138423919678},
#                {'label': 'surprise', 'score': 0.006669138558208942}]],
#              ('and', 'have'): [0.008947006194081212,
#               [{'label': 'sadness', 'score': 0.07019812613725662},
#                {'label': 'joy', 'score': 0.505724310874939},
#                {'label': 'love', 'score': 0.014043127186596394},
#                {'label': 'anger', 'score': 0.32552558183670044},
#                {'label': 'fear', 'score': 0.07288175821304321},
#                {'label': 'surprise', 'score': 0.011627060361206532}]],
#              ('have', 'the'): [0.029801324503311258,
#               [{'label': 'sadness', 'score': 0.053522780537605286},
#                {'label': 'joy', 'score': 0.3876320719718933},
#                {'label': 'love', 'score': 0.00935190636664629},
#                {'label': 'anger', 'score': 0.46642759442329407},
#                {'label': 'fear', 'score': 0.07581549882888794},
#                {'label': 'surprise', 'score': 0.007250177673995495}]],
#              ('the', 'whole'): [0.007830853563038372,
#               [{'label': 'sadness', 'score': 0.017912155017256737},
#                {'label': 'joy', 'score': 0.02929324097931385},
#                {'label': 'love', 'score': 0.0031791680958122015},
#                {'label': 'anger', 'score': 0.8977956771850586},
#                {'label': 'fear', 'score': 0.047178223729133606},
#                {'label': 'surprise', 'score': 0.004641522187739611}]],
#              ('whole', 'marriage'): [0.07142857142857142,
#               [{'label': 'sadness', 'score': 0.11923767626285553},
#                {'label': 'joy', 'score': 0.16404053568840027},
#                {'label': 'love', 'score': 0.09494840353727341},
#                {'label': 'anger', 'score': 0.5703769326210022},
#                {'label': 'fear', 'score': 0.0472724623978138},
#                {'label': 'surprise', 'score': 0.0041239941492676735}]],
#              ('marriage', 'and'): [1.0,
#               [{'label': 'sadness', 'score': 0.0828246995806694},
#                {'label': 'joy', 'score': 0.09725070744752884},
#                {'label': 'love', 'score': 0.05855126306414604},
#                {'label': 'anger', 'score': 0.6439273953437805},
#                {'label': 'fear', 'score': 0.11155218631029129},
#                {'label': 'surprise', 'score': 0.005893741734325886}]],
#              ('and', 'kids'): [0.0006882312456985547,
#               [{'label': 'sadness', 'score': 0.05843762680888176},
#                {'label': 'joy', 'score': 0.23743362724781036},
#                {'label': 'love', 'score': 0.014896649867296219},
#                {'label': 'anger', 'score': 0.6422038078308105},
#                {'label': 'fear', 'score': 0.03890387713909149},
#                {'label': 'surprise', 'score': 0.008124450221657753}]],
#              ('kids', 'thing'): [0.0625,
#               [{'label': 'sadness', 'score': 0.026910586282610893},
#                {'label': 'joy', 'score': 0.11767609417438507},
#                {'label': 'love', 'score': 0.0036665943916887045},
#                {'label': 'anger', 'score': 0.7572730183601379},
#                {'label': 'fear', 'score': 0.08765285462141037},
#                {'label': 'surprise', 'score': 0.006820837501436472}]],
#              ('thing', 'with'): [0.043478260869565216,
#               [{'label': 'sadness', 'score': 0.01476290263235569},
#                {'label': 'joy', 'score': 0.0821966677904129},
#                {'label': 'love', 'score': 0.0035150498151779175},
#                {'label': 'anger', 'score': 0.815569281578064},
#                {'label': 'fear', 'score': 0.07912857085466385},
#                {'label': 'surprise', 'score': 0.004827509168535471}]],
#              ('with', 'him'): [0.029315960912052116,
#               [{'label': 'sadness', 'score': 0.056353610008955},
#                {'label': 'joy', 'score': 0.44439077377319336},
#                {'label': 'love', 'score': 0.02099565602838993},
#                {'label': 'anger', 'score': 0.4036529064178467},
#                {'label': 'fear', 'score': 0.06357301026582718},
#                {'label': 'surprise', 'score': 0.01103402953594923}]],
#              ('him', '$'): [0.10714285714285714,
#               [{'label': 'sadness', 'score': 0.0863473042845726},
#                {'label': 'joy', 'score': 0.19862937927246094},
#                {'label': 'love', 'score': 0.010758903808891773},
#                {'label': 'anger', 'score': 0.6585070490837097},
#                {'label': 'fear', 'score': 0.03625442460179329},
#                {'label': 'surprise', 'score': 0.009502938017249107}]],
#              ('feel', 'unimportant'): [0.0012217470983506415,
#               [{'label': 'sadness', 'score': 0.9990436434745789},
#                {'label': 'joy', 'score': 0.0002124439924955368},
#                {'label': 'love', 'score': 0.00014488276792690158},
#                {'label': 'anger', 'score': 0.0002297593018738553},
#                {'label': 'fear', 'score': 0.00023152421636041254},
#                {'label': 'surprise', 'score': 0.0001376516156597063}]],
#              ('unimportant', 'so'): [0.25,
#               [{'label': 'sadness', 'score': 0.998145580291748},
#                {'label': 'joy', 'score': 0.0003945284115616232},
#                {'label': 'love', 'score': 0.00015537028957623988},
#                {'label': 'anger', 'score': 0.0007587854051962495},
#                {'label': 'fear', 'score': 0.0003873309469781816},
#                {'label': 'surprise', 'score': 0.00015840989362914115}]],
#              ('so', 'inadequate'): [0.00273224043715847,
#               [{'label': 'sadness', 'score': 0.9981813430786133},
#                {'label': 'joy', 'score': 0.00023457850329577923},
#                {'label': 'love', 'score': 0.00020164392481092364},
# ...
#                {'label': 'joy', 'score': 0.9958593249320984},
#                {'label': 'love', 'score': 0.0007592667825520039},
#                {'label': 'anger', 'score': 0.0014175315154716372},
#                {'label': 'fear', 'score': 0.00044635485392063856},
#                {'label': 'surprise', 'score': 0.0003982488706242293}]],
#              ('satisfied', 'and'): [0.2,
#               [{'label': 'sadness', 'score': 0.0011585865868255496},
#                {'label': 'joy', 'score': 0.9947773218154907},
#                {'label': 'love', 'score': 0.00098732253536582},
#                {'label': 'anger', 'score': 0.001941393711604178},
#                {'label': 'fear', 'score': 0.0005213532713241875},
#                {'label': 'surprise', 'score': 0.0006140667828731239}]],
#              ('feel', 'dull'): [0.0006108735491753207,
#               [{'label': 'sadness', 'score': 0.9987668991088867},
#                {'label': 'joy', 'score': 0.00031284429132938385},
#                {'label': 'love', 'score': 0.0002158299321308732},
#                {'label': 'anger', 'score': 0.00034316323581151664},
#                {'label': 'fear', 'score': 0.00015780127432662994},
#                {'label': 'surprise', 'score': 0.0002035070356214419}]],
#              ('dull', 'and'): [0.6,
#               [{'label': 'sadness', 'score': 0.950897753238678},
#                {'label': 'joy', 'score': 0.002015231642872095},
#                {'label': 'love', 'score': 0.0011546204332262278},
#                {'label': 'anger', 'score': 0.043976590037345886},
#                {'label': 'fear', 'score': 0.000784033618401736},
#                {'label': 'surprise', 'score': 0.0011715911095961928}]],
#              ('and', 'uninteresting'): [0.0006882312456985547,
#               [{'label': 'sadness', 'score': 0.09522341191768646},
#                {'label': 'joy', 'score': 0.0019395167473703623},
#                {'label': 'love', 'score': 0.003012234577909112},
#                {'label': 'anger', 'score': 0.8611234426498413},
#                {'label': 'fear', 'score': 0.03731628879904747},
#                {'label': 'surprise', 'score': 0.0013851937837898731}]],
#              ('uninteresting', '$'): [1.0,
#               [{'label': 'sadness', 'score': 0.012092389166355133},
#                {'label': 'joy', 'score': 0.0013218739768490195},
#                {'label': 'love', 'score': 0.0011836113408207893},
#                {'label': 'anger', 'score': 0.9463649988174438},
#                {'label': 'fear', 'score': 0.03794349730014801},
#                {'label': 'surprise', 'score': 0.0010936091421172023}]],
#              ('have', 'been'): [0.11920529801324503,
#               [{'label': 'sadness', 'score': 0.03474182263016701},
#                {'label': 'joy', 'score': 0.6656360626220703},
#                {'label': 'love', 'score': 0.010196670889854431},
#                {'label': 'anger', 'score': 0.25485438108444214},
#                {'label': 'fear', 'score': 0.029179396107792854},
#                {'label': 'surprise', 'score': 0.005391687620431185}]],
#              ('been', 'quite'): [0.008771929824561403,
#               [{'label': 'sadness', 'score': 0.013117137365043163},
#                {'label': 'joy', 'score': 0.8883865475654602},
#                {'label': 'love', 'score': 0.0038958953227847815},
#                {'label': 'anger', 'score': 0.07208169251680374},
#                {'label': 'fear', 'score': 0.016945060342550278},
#                {'label': 'surprise', 'score': 0.005573626141995192}]],
#              ('quite', 'neglectful'): [0.021739130434782608,
#               [{'label': 'sadness', 'score': 0.9949068427085876},
#                {'label': 'joy', 'score': 0.0004952260642312467},
#                {'label': 'love', 'score': 0.0003365206066519022},
#                {'label': 'anger', 'score': 0.003555862931534648},
#                {'label': 'fear', 'score': 0.00047221124987117946},
#                {'label': 'surprise', 'score': 0.00023336461163125932}]],
#              ('neglectful', 'to'): [1.0,
#               [{'label': 'sadness', 'score': 0.9868308305740356},
#                {'label': 'joy', 'score': 0.0004648930043913424},
#                {'label': 'love', 'score': 0.0004958659992553294},
#                {'label': 'anger', 'score': 0.01080095674842596},
#                {'label': 'fear', 'score': 0.0010929952841252089},
#                {'label': 'surprise', 'score': 0.00031444913474842906}]],
#              ('my', 'blog'): [0.004672897196261682,
#               [{'label': 'sadness', 'score': 0.055462904274463654},
#                {'label': 'joy', 'score': 0.32012706995010376},
#                {'label': 'love', 'score': 0.012031341902911663},
#                {'label': 'anger', 'score': 0.552493691444397},
#                {'label': 'fear', 'score': 0.05404696613550186},
#                {'label': 'surprise', 'score': 0.005838028620928526}]],
#              ('blog', 'and'): [0.1111111111111111,
#               [{'label': 'sadness', 'score': 0.036840084940195084},
#                {'label': 'joy', 'score': 0.6146916151046753},
#                {'label': 'love', 'score': 0.011059227399528027},
#                {'label': 'anger', 'score': 0.26315003633499146},
#                {'label': 'fear', 'score': 0.06962728500366211},
#                {'label': 'surprise', 'score': 0.004631697200238705}]],
#              ('and', 'am'): [0.0034411562284927736,
#               [{'label': 'sadness', 'score': 0.0731840506196022},
#                {'label': 'joy', 'score': 0.3301700949668884},
#                {'label': 'love', 'score': 0.01260156650096178},
#                {'label': 'anger', 'score': 0.4868348240852356},
#                {'label': 'fear', 'score': 0.08688139170408249},
#                {'label': 'surprise', 'score': 0.010328023694455624}]],
#              ('am', 'just'): [0.0064516129032258064,
#               [{'label': 'sadness', 'score': 0.0282486192882061},
#                {'label': 'joy', 'score': 0.7930776476860046},
#                {'label': 'love', 'score': 0.0034937888849526644},
#                {'label': 'anger', 'score': 0.14238667488098145},
#                {'label': 'fear', 'score': 0.029036710038781166},
#                {'label': 'surprise', 'score': 0.0037564560770988464}]],
#              ('just', 'to'): [0.022123893805309734,
#               [{'label': 'sadness', 'score': 0.027951974421739578},
#                {'label': 'joy', 'score': 0.3783198893070221},
#                {'label': 'love', 'score': 0.008985131047666073},
#                {'label': 'anger', 'score': 0.524728000164032},
#                {'label': 'fear', 'score': 0.05468552187085152},
#                {'label': 'surprise', 'score': 0.005329546052962542}]],
#              ('that', 'we'): [0.016331658291457288,
#               [{'label': 'sadness', 'score': 0.014004815369844437},
#                {'label': 'joy', 'score': 0.03999106213450432},
#                {'label': 'love', 'score': 0.004016616381704807},
#                {'label': 'anger', 'score': 0.9306249022483826},
#                {'label': 'fear', 'score': 0.009877681732177734},
#                {'label': 'surprise', 'score': 0.001484915497712791}]],
#              ('we', 'are'): [0.1686746987951807,
#               [{'label': 'sadness', 'score': 0.01736946776509285},
#                {'label': 'joy', 'score': 0.7645995020866394},
#                {'label': 'love', 'score': 0.007945816963911057},
#                {'label': 'anger', 'score': 0.19452372193336487},
#                {'label': 'fear', 'score': 0.012528904713690281},
#                {'label': 'surprise', 'score': 0.0030325737316161394}]],
#              ('are', 'here'): [0.007575757575757576,
#               [{'label': 'sadness', 'score': 0.025133686140179634},
#                {'label': 'joy', 'score': 0.5146608352661133},
#                {'label': 'love', 'score': 0.009044284000992775},
#                {'label': 'anger', 'score': 0.3799895942211151},
#                {'label': 'fear', 'score': 0.06541362404823303},
#                {'label': 'surprise', 'score': 0.005758000072091818}]],
#              ('here', 'alive'): [0.02702702702702703,
#               [{'label': 'sadness', 'score': 0.015450379811227322},
#                {'label': 'joy', 'score': 0.7137234807014465},
#                {'label': 'love', 'score': 0.006713038310408592},
#                {'label': 'anger', 'score': 0.1839272826910019},
#                {'label': 'fear', 'score': 0.07055260986089706},
#                {'label': 'surprise', 'score': 0.009633289650082588}]],
#              ('alive', 'and'): [0.2,
#               [{'label': 'sadness', 'score': 0.011994500644505024},
#                {'label': 'joy', 'score': 0.8601748943328857},
#                {'label': 'love', 'score': 0.005497443489730358},
#                {'label': 'anger', 'score': 0.07850208133459091},
#                {'label': 'fear', 'score': 0.03695129230618477},
#                {'label': 'surprise', 'score': 0.006879813969135284}]],
#              ('and', 'happy'): [0.004817618719889883,
#               [{'label': 'sadness', 'score': 0.0005969314952380955},
#                {'label': 'joy', 'score': 0.998084306716919},
#                {'label': 'love', 'score': 0.0005327363614924252},
#                {'label': 'anger', 'score': 0.00035738677252084017},
#                {'label': 'fear', 'score': 0.00019175600027665496},
#                {'label': 'surprise', 'score': 0.0002369225985603407}]],
#              ('happy', '$'): [0.2727272727272727,
#               [{'label': 'sadness', 'score': 0.0009471020894125104},
#                {'label': 'joy', 'score': 0.9974151849746704},
#                {'label': 'love', 'score': 0.0005305295344442129},
#                {'label': 'anger', 'score': 0.0005297567113302648},
#                {'label': 'fear', 'score': 0.0002800215734168887},
#                {'label': 'surprise', 'score': 0.00029748587985523045}]],
#              ('m', 'worthless'): [0.01694915254237288,
#               [{'label': 'sadness', 'score': 0.9876739382743835},
#                {'label': 'joy', 'score': 0.0016897181048989296},
#                {'label': 'love', 'score': 0.0003874917165376246},
#                {'label': 'anger', 'score': 0.009391888976097107},
#                {'label': 'fear', 'score': 0.0004508239799179137},
#                {'label': 'surprise', 'score': 0.00040617500781081617}]],
#              ('can', 't'): [0.11029411764705882,
#               [{'label': 'sadness', 'score': 0.04561888799071312},
#                {'label': 'joy', 'score': 0.09733135998249054},
#                {'label': 'love', 'score': 0.006673482246696949},
#                {'label': 'anger', 'score': 0.5654940605163574},
#                {'label': 'fear', 'score': 0.27757593989372253},
#                {'label': 'surprise', 'score': 0.007306234445422888}]],
#              ('t', 'do'): [0.03676470588235294,
#               [{'label': 'sadness', 'score': 0.05708235129714012},
#                {'label': 'joy', 'score': 0.16823038458824158},
#                {'label': 'love', 'score': 0.009470314718782902},
#                {'label': 'anger', 'score': 0.6513186097145081},
#                {'label': 'fear', 'score': 0.10721445083618164},
#                {'label': 'surprise', 'score': 0.00668388232588768}]],
#              ('do', 'any'): [0.006802721088435374,
#               [{'label': 'sadness', 'score': 0.023272575810551643},
#                {'label': 'joy', 'score': 0.2289559245109558},
#                {'label': 'love', 'score': 0.0050002350471913815},
#                {'label': 'anger', 'score': 0.6905255317687988},
#                {'label': 'fear', 'score': 0.0488603301346302},
#                {'label': 'surprise', 'score': 0.0033853715285658836}]],
#              ('any', 'good'): [0.05,
#               [{'label': 'sadness', 'score': 0.001965356757864356},
#                {'label': 'joy', 'score': 0.9937785267829895},
#                {'label': 'love', 'score': 0.0008811474544927478},
#                {'label': 'anger', 'score': 0.002205920172855258},
#                {'label': 'fear', 'score': 0.0006930588860996068},
#                {'label': 'surprise', 'score': 0.0004760166339110583}]],
#              ('good', 'for'): [0.03125,
#               [{'label': 'sadness', 'score': 0.003180157393217087},
#                {'label': 'joy', 'score': 0.9900475740432739},
#                {'label': 'love', 'score': 0.0014099548570811749},
#                {'label': 'anger', 'score': 0.0037580993957817554},
#                {'label': 'fear', 'score': 0.000811534991953522},
#                {'label': 'surprise', 'score': 0.0007927638362161815}]],
#              ('for', 'anyone'): [0.00516795865633075,
#               [{'label': 'sadness', 'score': 0.06145482510328293},
#                {'label': 'joy', 'score': 0.24345996975898743},
#                {'label': 'love', 'score': 0.013174427673220634},
#                {'label': 'anger', 'score': 0.656825065612793},
#                {'label': 'fear', 'score': 0.020101893693208694},
#                {'label': 'surprise', 'score': 0.004983816295862198}]],
#              ('anyone', 'even'): [0.04,
#               [{'label': 'sadness', 'score': 0.0060805934481322765},
#                {'label': 'joy', 'score': 0.014296334236860275},
#                {'label': 'love', 'score': 0.001536073861643672},
#                {'label': 'anger', 'score': 0.9588737487792969},
#                {'label': 'fear', 'score': 0.01743309386074543},
#                {'label': 'surprise', 'score': 0.0017800867790356278}]],
#              ('even', 'tought'): [0.012658227848101266,
#               [{'label': 'sadness', 'score': 0.05439331755042076},
#                {'label': 'joy', 'score': 0.6377122402191162},
#                {'label': 'love', 'score': 0.00701808650046587},
#                {'label': 'anger', 'score': 0.2538908123970032},
#                {'label': 'fear', 'score': 0.042644940316677094},
#                {'label': 'surprise', 'score': 0.004340664949268103}]],
#              ('tought', 'i'): [1.0,
#               [{'label': 'sadness', 'score': 0.036840882152318954},
#                {'label': 'joy', 'score': 0.22330793738365173},
#                {'label': 'love', 'score': 0.008049877360463142},
#                {'label': 'anger', 'score': 0.6809073686599731},
#                {'label': 'fear', 'score': 0.04751954227685928},
#                {'label': 'surprise', 'score': 0.0033743702806532383}]],
#              ('i', 'try'): [0.003430984428609132,
#               [{'label': 'sadness', 'score': 0.034999459981918335},
#                {'label': 'joy', 'score': 0.5258136987686157},
#                {'label': 'love', 'score': 0.005932009778916836},
#                {'label': 'anger', 'score': 0.4044150412082672},
#                {'label': 'fear', 'score': 0.026433629915118217},
#                {'label': 'surprise', 'score': 0.0024061708245426416}]],
#              ('try', 'and'): [0.13043478260869565,
#               [{'label': 'sadness', 'score': 0.019751805812120438},
#                {'label': 'joy', 'score': 0.3285492956638336},
#                {'label': 'love', 'score': 0.0068788668140769005},
#                {'label': 'anger', 'score': 0.5544683933258057},
#                {'label': 'fear', 'score': 0.0837516263127327},
#                {'label': 'surprise', 'score': 0.006599965505301952}]],
#              ('and', 'try'): [0.0027529249827942187,
#               [{'label': 'sadness', 'score': 0.02927735447883606},
#                {'label': 'joy', 'score': 0.46090957522392273},
#                {'label': 'love', 'score': 0.010881432332098484},
#                {'label': 'anger', 'score': 0.44011175632476807},
#                {'label': 'fear', 'score': 0.05152264982461929},
#                {'label': 'surprise', 'score': 0.0072972532361745834}]],
#              ('try', 'very'): [0.043478260869565216,
#               [{'label': 'sadness', 'score': 0.02167840488255024},
#                {'label': 'joy', 'score': 0.4093344211578369},
#                {'label': 'love', 'score': 0.007905560545623302},
#                {'label': 'anger', 'score': 0.4340679943561554},
#                {'label': 'fear', 'score': 0.11950840055942535},
#                {'label': 'surprise', 'score': 0.007505166810005903}]],
#              ...})

# %% [markdown]
# # Task 2: Subtask 4: Extrinsic Evaluation
# ### Part A: Generateing 50 samples for each emotion and save them in text files simultaneously

# %%
# Initially define how many emotions we have
emotions = ["sadness", "joy", "love", "anger", "fear", "surprise"]

# For each probable emotion, call the generate_emotion_oriented_samples(emotion, beta, num_of_samples) method from class
# BigramLM() to generate 50 samples for each emotion and save them in .txt files
for emotion_ in emotions:
    print("\nSamples for ", emotion_)
    bigram_model.generate_emotion_oriented_samples(emotion_, 0.75, 50)
# Out:
# Samples for  sadness
# $ a dark getting a retired wedding photographer $ i
# $ occured while $ during a synonym for an apology
# $ i often go out $ during the need drugs
# $ i suffer i is fake people can put upon
# $ ill also now unsuccessful $ i lack of color
# $ i split up on overcoming the loss of pathetic
# $ in stores because as worthless person $ i miss
# $ when the sentence in finance as time of all
# $ im usually even after my future $ i left
# $ ill also ached $ id an unwelcome in wide
# $ occured while $ ill get disturbed that suffer the
# $ on its inadequate or forget about rabbits i start
# $ ive never being hurt you always am left me
# $ i blanked a class the whitley family $ i
# $ i view when i exhausted all unloved $ i
# $ im aching for netflix as worthless person as ugly
# $ this pregnancy $ ill screw over reacting over mom
# $ ill get on the minority in new $ on
# $ on each and at peace love eating fresh new
# $ ill laugh because as time to sleep i exhausted
# $ i forgot my toes and start of lame about
# $ during the experiment but that without emotion only thing
# $ in life less see victoria take up feeling inadequate
# $ i sometimes writing careers but otherwise ok it seems
# $ i forgot my mother shirley demands drugs after went
# $ i must haves but medicine $ during my disappointment
# $ i exhausted $ ill mention him for and disasters
# $ i doubt theres no reason possess no where god
# $ im aching and sick $ in such a worthless
# $ the road layout looks really awkward talking about most
# $ i missed out boy i missed yoga because i
# $ i give up did i barely maintain long ago
# $ i exhausted $ a sandwich for xmas i hurt
# $ a submarine cartwheel before the sorrows lurking about a
# $ during most hated me with bad impression with all
# $ i fail my boring amp needs as being ignored
# $ ill will be worse i closed my poor and
# $ ill will break me get disturbed $ i lack
# $ i cleaned it again after being numb way instead
# $ i blog $ i made you get the emotional
# $ id know about americas heat of ourselves or live
# $ i exhausted $ ill desperately wanting the anxieties i
# $ i forgot my city the better do not $
# $ i failed the anxieties i expressed my time till
# $ i barely maintain long after my read and break
# $ im using in his work my grief i should
# $ i needed to this because life in finance as
# $ i sort of psychopathology how would have depression and
# $ the plight however unknown to crying again i left
# $ no reason $ i live so defective when things
# $ a dark getting a retired wedding photographer $ i
# $ occured while $ during a synonym for an apology
# $ i often go out $ during the need drugs
# $ i suffer i is fake people can put upon
# $ ill also now unsuccessful $ i lack of color
# $ i split up on overcoming the loss of pathetic
# $ in stores because as worthless person $ i miss
# $ when the sentence in finance as time of all
# $ im usually even after my future $ i left
# $ ill also ached $ id an unwelcome in wide
# $ occured while $ ill get disturbed that suffer the
# $ on its inadequate or forget about rabbits i start
# $ ive never being hurt you always am left me
# $ i blanked a class the whitley family $ i
# $ i view when i exhausted all unloved $ i
# $ im aching for netflix as worthless person as ugly
# $ this pregnancy $ ill screw over reacting over mom
# $ ill get on the minority in new $ on
# $ on each and at peace love eating fresh new
# $ ill laugh because as time to sleep i exhausted
# $ i forgot my toes and start of lame about
# $ during the experiment but that without emotion only thing
# $ in life less see victoria take up feeling inadequate
# $ i sometimes writing careers but otherwise ok it seems
# $ i forgot my mother shirley demands drugs after went
# $ i must haves but medicine $ during my disappointment
# $ i exhausted $ ill mention him for and disasters
# $ i doubt theres no reason possess no where god
# $ im aching and sick $ in such a worthless
# $ the road layout looks really awkward talking about most
# $ i missed out boy i missed yoga because i
# $ i give up did i barely maintain long ago
# $ i exhausted $ a sandwich for xmas i hurt
# $ a submarine cartwheel before the sorrows lurking about a
# $ during most hated me with bad impression with all
# $ i fail my boring amp needs as being ignored
# $ ill will be worse i closed my poor and
# $ ill will break me get disturbed $ i lack
# $ i cleaned it again after being numb way instead
# $ i blog $ i made you get the emotional
# $ id know about americas heat of ourselves or live
# $ i exhausted $ ill desperately wanting the anxieties i
# $ i forgot my city the better do not $
# $ i failed the anxieties i expressed my time till
# $ i barely maintain long after my read and break
# $ im using in his work my grief i should
# $ i needed to this because life in finance as
# $ i sort of psychopathology how would have depression and
# $ the plight however unknown to crying again i left
# $ no reason $ i live so defective when things
#
#
# Samples for  joy
# $ occured while feeling positive about pleasing everyone else $
# $ the companies of relief from seems to $ this
# $ a quiet reflection or what may give it feel
# $ this crunchy sweet with such as fantastic as expected
# $ in retrospect if anywhere and quality of completeness like
# $ when theres always tell you could do any lingering
# $ on average and delighted in far on mermaidhaire does
# $ is going to contain some ways i m happy
# $ ive passed my intellect but never felt was true
# $ occured while $ occured while preparing for her nicely
# $ id hoped $ in sincerity in terms of happening
# $ this invitation but everything for $ i expressed my
# $ i offer me wherever you even go home as
# $ on how your comments if you believe does justice
# $ during an international audience who approve and helpful to
# $ i seemed kind feelings entertained by now getting results
# $ i discovered through any sense i recommend the music
# $ i then feeling because i adapt and be keeping
# $ no energy and emerged in virtual silence $ i
# $ i ever change $ i vibrates up energy $
# $ a carefree $ im presenting myself smiling like here
# $ im putting the playing this affirmation over his understanding
# $ i grew up twas am working out pretty $
# $ i held all day and clean the dishes and
# $ this blessed and bright coloured lipsticks are self assured
# $ i feels so feel this patriotism only together $
# $ in brave and yes lovely now makes fun of
# $ i learned to switch off wipe out beautiful pearly
# $ i sit through enough that seems like feel my
# $ id like something productive organized and make themselves $
# $ is over on yahoo and comfy that scientists to
# $ is having something comes out beautiful pictures taken me
# $ on overcoming the changes and innocent with ian $
# $ a date will be just be determined to experience
# $ is sooo sweet luke around at $ occured while
# $ the usual progression of legacy $ this worth and
# $ this welcoming and self awareness $ i kinda boring
# $ this investment is way is welcomed and art into
# $ occured while so full of sunshine and done to
# $ i notice to day $ i carry on feeling
# $ this makes sense of went to actually $ a
# $ the decision kicking myself right track $ i remember
# $ during an edge of workouts $ i do around
# $ a chance to really hope that setting made me
# $ a surprise two friends online $ in getting debt
# $ in high school work like feel energized today a
# $ i are better but feel shes pretty carefree state
# $ this low and ethical views in heaven and laughable
# $ during the strong feeling much excitement for heaven heaven
# $ occured while i find a much larger point partly
# $ occured while feeling positive about pleasing everyone else $
# $ the companies of relief from seems to $ this
# $ a quiet reflection or what may give it feel
# $ this crunchy sweet with such as fantastic as expected
# $ in retrospect if anywhere and quality of completeness like
# $ when theres always tell you could do any lingering
# $ on average and delighted in far on mermaidhaire does
# $ is going to contain some ways i m happy
# $ ive passed my intellect but never felt was true
# $ occured while $ occured while preparing for her nicely
# $ id hoped $ in sincerity in terms of happening
# $ this invitation but everything for $ i expressed my
# $ i offer me wherever you even go home as
# $ on how your comments if you believe does justice
# $ during an international audience who approve and helpful to
# $ i seemed kind feelings entertained by now getting results
# $ i discovered through any sense i recommend the music
# $ i then feeling because i adapt and be keeping
# $ no energy and emerged in virtual silence $ i
# $ i ever change $ i vibrates up energy $
# $ a carefree $ im presenting myself smiling like here
# $ im putting the playing this affirmation over his understanding
# $ i grew up twas am working out pretty $
# $ i held all day and clean the dishes and
# $ this blessed and bright coloured lipsticks are self assured
# $ i feels so feel this patriotism only together $
# $ in brave and yes lovely now makes fun of
# $ i learned to switch off wipe out beautiful pearly
# $ i sit through enough that seems like feel my
# $ id like something productive organized and make themselves $
# $ is over on yahoo and comfy that scientists to
# $ is having something comes out beautiful pictures taken me
# $ on overcoming the changes and innocent with ian $
# $ a date will be just be determined to experience
# $ is sooo sweet luke around at $ occured while
# $ the usual progression of legacy $ this worth and
# $ this welcoming and self awareness $ i kinda boring
# $ this investment is way is welcomed and art into
# $ occured while so full of sunshine and done to
# $ i notice to day $ i carry on feeling
# $ this makes sense of went to actually $ a
# $ the decision kicking myself right track $ i remember
# $ during an edge of workouts $ i do around
# $ a chance to really hope that setting made me
# $ a surprise two friends online $ in getting debt
# $ in high school work like feel energized today a
# $ i are better but feel shes pretty carefree state
# $ this low and ethical views in heaven and laughable
# $ during the strong feeling much excitement for heaven heaven
# $ occured while i find a much larger point partly
#
#
# Samples for  love
# $ i love him feel romantic towards beloved if i
# $ i feel affectionate interested in love for many accessaries
# $ i hope could better than sweet rhythm imprinted on
# $ i feel gentle breath and forgiving lately so hot
# $ i embrace the cooperation $ i embrace the love
# $ i havent heard about supporting characters on loved posting
# $ i hear from to finally confirm what not caring
# $ i accepted in college on going and topping it
# $ im overreacting or caring for caring $ im loved
# $ im loving with its lovely polish $ i offer
# $ i desire and alive $ i loved long $
# $ i received and loved and supportive over sympathetic $
# $ i admire her tender cool $ i embrace the
# $ i have enjoyed about the longing urge to while
# $ i love him which is rarely handled well thought
# $ i believed there are likely make me to like
# $ i wished would ask me how my faithful reader
# $ i lve the gentle amusement $ im loving $
# $ i loved $ i forgive myself from my problem
# $ i liked doing it could genuinely looking over each
# $ i clung onto them $ i shared and art
# $ i wished would be loving kindness allow us at
# $ i liked doing something lovely yarn and caring who
# $ i love and all hot radiator $ i desire
# $ i wished would love me $ i liked how
# $ occured while everyone else was so devoted my love
# $ i need to people in love of designer shoes
# $ i feel beloved your lovely now im craving i
# $ im craving addiction to kiss me $ i liked
# $ i thank him to whether youre feeling that passionate
# $ i admire her tender about supporting other and since
# $ im still getting credit equals getting caught my lovely
# $ i admire her close enough $ i was hot
# $ i admire her tender little tender smile amused smile
# $ ive learned a gentle rippling through loving simple shape
# $ i liked the delicate and resistant for caring who
# $ i admire her close enough about anime fandom in
# $ ill desperately fond memories $ i empathize with the
# $ i love the loyal reading viewing the cross cynical
# $ i empathize with you believe there $ i love
# $ i awoke an exciting story but adoring love for
# $ i empathize with regard to kiss me love music
# $ i loved $ i empathize with my faithfulness $
# $ i liked mud wrestling or unloved $ i empathize
# $ i stare and always hot all hot green tea
# $ i embrace the door $ i loved safe again
# $ i suggest you have admired and caring who want
# $ im not accepted with no new in love him
# $ i wanted to kiss my loyal reading his typical
# $ i empathize with girly stuff and compassion for horny
# $ i love him feel romantic towards beloved if i
# $ i feel affectionate interested in love for many accessaries
# $ i hope could better than sweet rhythm imprinted on
# $ i feel gentle breath and forgiving lately so hot
# $ i embrace the cooperation $ i embrace the love
# $ i havent heard about supporting characters on loved posting
# $ i hear from to finally confirm what not caring
# $ i accepted in college on going and topping it
# $ im overreacting or caring for caring $ im loved
# $ im loving with its lovely polish $ i offer
# $ i desire and alive $ i loved long $
# $ i received and loved and supportive over sympathetic $
# $ i admire her tender cool $ i embrace the
# $ i have enjoyed about the longing urge to while
# $ i love him which is rarely handled well thought
# $ i believed there are likely make me to like
# $ i wished would ask me how my faithful reader
# $ i lve the gentle amusement $ im loving $
# $ i loved $ i forgive myself from my problem
# $ i liked doing it could genuinely looking over each
# $ i clung onto them $ i shared and art
# $ i wished would be loving kindness allow us at
# $ i liked doing something lovely yarn and caring who
# $ i love and all hot radiator $ i desire
# $ i wished would love me $ i liked how
# $ occured while everyone else was so devoted my love
# $ i need to people in love of designer shoes
# $ i feel beloved your lovely now im craving i
# $ im craving addiction to kiss me $ i liked
# $ i thank him to whether youre feeling that passionate
# $ i admire her tender about supporting other and since
# $ im still getting credit equals getting caught my lovely
# $ i admire her close enough $ i was hot
# $ i admire her tender little tender smile amused smile
# $ ive learned a gentle rippling through loving simple shape
# $ i liked the delicate and resistant for caring who
# $ i admire her close enough about anime fandom in
# $ ill desperately fond memories $ i empathize with the
# $ i love the loyal reading viewing the cross cynical
# $ i empathize with you believe there $ i love
# $ i awoke an exciting story but adoring love for
# $ i empathize with regard to kiss me love music
# $ i loved $ i empathize with my faithfulness $
# $ i liked mud wrestling or unloved $ i empathize
# $ i stare and always hot all hot green tea
# $ i embrace the door $ i loved safe again
# $ i suggest you have admired and caring who want
# $ im not accepted with no new in love him
# $ i wanted to kiss my loyal reading his typical
# $ i empathize with girly stuff and compassion for horny
#
#
# Samples for  anger
# $ in outfit $ i never expected its teeth but
# $ a post makes me clearly feel spiteful toward me
# $ i ran away bad idea i a must that
# $ no description $ in and persecuted by our decision
# $ is rarely handled well and down and irritable like
# $ on sony s truth about any lingering $ ive
# $ is to that you up anybody to rain squeal
# $ during an event because each other but days to
# $ im building good things are on he d pagetitle
# $ i t advocate the climb and environment but get
# $ i did with not serving a short comings $
# $ no point where they take control issues though something
# $ heated discussion with my voice that your face complications
# $ during a tortured by his love intentionally or are
# $ heated discussion on the trimmings that $ during most
# $ ive been measuring out o class so tortured the
# $ is talk today though they want more disgusted and
# $ on hanford city mostly because im nauseous $ im
# $ is he was total partnership with sleep a month
# $ a wuss and inner thighs $ ive waited my
# $ i exercised and taiwan depending on xbla but hoping
# $ im supposed to saying that people i personally feel
# $ i fight the feelings of just had sat around
# $ i lauper s time which has wronged or not
# $ id talk about driving to plot ish issues but
# $ on something etc $ during an idiot for hating
# $ ive made this bike days it into middle age
# $ im taking roll my problem and concerned really chuffed
# $ on anything that carcenogenic smoke pot alone in expressing
# $ during that made us have met again $ when
# $ ill screw over or even more than a family
# $ im only will step in manufacturing and for not
# $ a pulp $ occured while not chick flick where
# $ on certain parts of walking hand shops just that
# $ im also caused members who were also caused members
# $ a out from this letter i then headed to
# $ ill desperately trying to lend my un emo song
# $ during the many other the psychologist all betrayed and
# $ heated discussion with one or wot $ this feelings
# $ on around plants back that day min $ no
# $ a spoiled little miss a nod to reflect on
# $ ive been temperature shocked and shake $ a manner
# $ when other side its own head with numbers for
# $ this came to fly $ in circles and frizz
# $ i sat around anyone after time to poke me
# $ im here nobody hears i to shinobi thats largely
# $ ive already passed this notice my vision and deny
# $ no solution for its at ideas how many people
# $ a haze trying to dogs as sin cara $
# $ im typing this happened for saying any lingering feelings
# $ in outfit $ i never expected its teeth but
# $ a post makes me clearly feel spiteful toward me
# $ i ran away bad idea i a must that
# $ no description $ in and persecuted by our decision
# $ is rarely handled well and down and irritable like
# $ on sony s truth about any lingering $ ive
# $ is to that you up anybody to rain squeal
# $ during an event because each other but days to
# $ im building good things are on he d pagetitle
# $ i t advocate the climb and environment but get
# $ i did with not serving a short comings $
# $ no point where they take control issues though something
# $ heated discussion with my voice that your face complications
# $ during a tortured by his love intentionally or are
# $ heated discussion on the trimmings that $ during most
# $ ive been measuring out o class so tortured the
# $ is talk today though they want more disgusted and
# $ on hanford city mostly because im nauseous $ im
# $ is he was total partnership with sleep a month
# $ a wuss and inner thighs $ ive waited my
# $ i exercised and taiwan depending on xbla but hoping
# $ im supposed to saying that people i personally feel
# $ i fight the feelings of just had sat around
# $ i lauper s time which has wronged or not
# $ id talk about driving to plot ish issues but
# $ on something etc $ during an idiot for hating
# $ ive made this bike days it into middle age
# $ im taking roll my problem and concerned really chuffed
# $ on anything that carcenogenic smoke pot alone in expressing
# $ during that made us have met again $ when
# $ ill screw over or even more than a family
# $ im only will step in manufacturing and for not
# $ a pulp $ occured while not chick flick where
# $ on certain parts of walking hand shops just that
# $ im also caused members who were also caused members
# $ a out from this letter i then headed to
# $ ill desperately trying to lend my un emo song
# $ during the many other the psychologist all betrayed and
# $ heated discussion with one or wot $ this feelings
# $ on around plants back that day min $ no
# $ a spoiled little miss a nod to reflect on
# $ ive been temperature shocked and shake $ a manner
# $ when other side its own head with numbers for
# $ this came to fly $ in circles and frizz
# $ i sat around anyone after time to poke me
# $ im here nobody hears i to shinobi thats largely
# $ ive already passed this notice my vision and deny
# $ no solution for its at ideas how many people
# $ a haze trying to dogs as sin cara $
# $ im typing this happened for saying any lingering feelings
#
#
# Samples for  fear
# $ i caught my thighs you think about feeling confused
# $ is alarming since its triggering i confused by noticing
# $ on mermaidhaire does feel afraid because to hide this
# $ id bought the key to report that chronically living
# $ id make room simply because thats the toddler possessing
# $ i suspect feel neurotic as terrified she paused dramatically
# $ i awoke an sls free exhilarated $ i sensed
# $ i closed on and blowing on tour and fearful
# $ i fell for what kind of such times a
# $ ive dated because as shaky and slink around the
# $ the beginning to their bags $ i held all
# $ i stepped into korean $ i lift $ i
# $ i cannot stand feeling somewhat alarmed $ in various
# $ im temporarily wounded feeling tampons and incapable and walked
# $ i blinded feelings like feel skeptical of staff first
# $ i woke up about minutes while typing this old
# $ i encounter in fear because i wondered if that
# $ the day but hoping these changes cause of unencumberedness
# $ i accidentally feel uptight at the coming from noah
# $ id try and nervous $ id done before and
# $ i start panic breathing tubes attacking the pool if
# $ occured while listening to toronto and restless today as
# $ id talk to curl up there was pregnant too
# $ occured while and unsettled because of any who should
# $ i wonder i instantly feel helpless in it is
# $ ill screw anything else $ i encounter in some
# $ i barely even respect me and confused after watching
# $ i suspect feel restless today when not have tons
# $ i woke up when a fearful that person in
# $ the beginning a ghost $ id just looking snaps
# $ the surface giving them meditating with how distraught he
# $ i wondered why i floated in outfit $ i
# $ i so many amazing chapter in zambia $ i
# $ ive been needing quite unclear on my skin i
# $ i found herself in oregon $ i must always
# $ i saw a room to droop and wound up
# $ im constantly paranoid that our progress $ i grabbed
# $ during most important to reflect on their feelings of
# $ im around boys this final one girls in zombie
# $ id know f t felt $ in washington so
# $ i visited the a plane to effect real life
# $ i woke up my footing and actually doing something
# $ im around these because arun has somehow not curl
# $ i turned out fearful anxiety is slowly killing me
# $ i stopped feeling shaken as online who is that
# $ i sensed he get confused by to dubstep when
# $ i almost flat $ i recall being married i
# $ i wondered would cause of ideas how desperately curious
# $ when someone did laps and went down when conversing
# $ i floated in stores because if im down when
# $ i caught my thighs you think about feeling confused
# $ is alarming since its triggering i confused by noticing
# $ on mermaidhaire does feel afraid because to hide this
# $ id bought the key to report that chronically living
# $ id make room simply because thats the toddler possessing
# $ i suspect feel neurotic as terrified she paused dramatically
# $ i awoke an sls free exhilarated $ i sensed
# $ i closed on and blowing on tour and fearful
# $ i fell for what kind of such times a
# $ ive dated because as shaky and slink around the
# $ the beginning to their bags $ i held all
# $ i stepped into korean $ i lift $ i
# $ i cannot stand feeling somewhat alarmed $ in various
# $ im temporarily wounded feeling tampons and incapable and walked
# $ i blinded feelings like feel skeptical of staff first
# $ i woke up about minutes while typing this old
# $ i encounter in fear because i wondered if that
# $ the day but hoping these changes cause of unencumberedness
# $ i accidentally feel uptight at the coming from noah
# $ id try and nervous $ id done before and
# $ i start panic breathing tubes attacking the pool if
# $ occured while listening to toronto and restless today as
# $ id talk to curl up there was pregnant too
# $ occured while and unsettled because of any who should
# $ i wonder i instantly feel helpless in it is
# $ ill screw anything else $ i encounter in some
# $ i barely even respect me and confused after watching
# $ i suspect feel restless today when not have tons
# $ i woke up when a fearful that person in
# $ the beginning a ghost $ id just looking snaps
# $ the surface giving them meditating with how distraught he
# $ i wondered why i floated in outfit $ i
# $ i so many amazing chapter in zambia $ i
# $ ive been needing quite unclear on my skin i
# $ i found herself in oregon $ i must always
# $ i saw a room to droop and wound up
# $ im constantly paranoid that our progress $ i grabbed
# $ during most important to reflect on their feelings of
# $ im around boys this final one girls in zombie
# $ id know f t felt $ in washington so
# $ i visited the a plane to effect real life
# $ i woke up my footing and actually doing something
# $ im around these because arun has somehow not curl
# $ i turned out fearful anxiety is slowly killing me
# $ i stopped feeling shaken as online who is that
# $ i sensed he get confused by to dubstep when
# $ i almost flat $ i recall being married i
# $ i wondered would cause of ideas how desperately curious
# $ when someone did laps and went down when conversing
# $ i floated in stores because if im down when
#
#
# Samples for  surprise
# $ i cant help $ i feel overwhelmed im suppose
# $ i discover his work $ i often look at
# $ i would die and ingenious theories and obtain caught
# $ i move into making choices within this weird ones
# $ i this weird history behind which is unusual and
# $ i had such things from my funny blogging world
# $ i am really funny blogging $ i shared my
# $ i discovered through this funny $ i feel funny
# $ i stayed over it is amazing abundance of shocked
# $ i could have surprised that i remembered seeing them
# $ i talked with what was as i and somehow
# $ i started back b c section is amazing exhibit
# $ i read with little stunned liv was amazed on
# $ is funny a dorky unfit rotund sloth that $
# $ i stop feeling strangely my funny when im also
# $ i held all these amazing and pink and curious
# $ i feel strangely tranquil and almost didn t figure
# $ i been needing quite overwhelmed thinking of home it
# $ id like explaining the very lonely here and dizzy
# $ i floated in no one of shocked over everyone
# $ i discover his words $ i may have surprised
# $ i thought during most curious impatient eager knowing that
# $ i might feel amazed by justin aryiku falls into
# $ i cant handle it right back through at seeing
# $ i only the depths of shocked awe of woody
# $ i might look at her $ i seemed so
# $ im shocked me shocked my funny to be funny
# $ occured while not impressed at this funny sort of
# $ i kind of stars too $ i seemed to
# $ i watched idol which i wonder why i was
# $ im amazed he could be too cheap so amazing
# $ i m curious about two very stunned for her
# $ i are amazed he surprises me look at how
# $ i wonder woman in comparison though they were hard
# $ i discovered through my boyfriend during my funny like
# $ i discover his sun sensitive so who follows their
# $ on our loyal to the systems and dizzy and
# $ i pour code and i visited $ i don
# $ i wonder why she wouldn t think ur problemn
# $ i mention is funny in awe and different feel
# $ i was shocked into the test personal moral obligation
# $ i awoke an entire concept $ i discover his
# $ i didnt support system in with ia $ i
# $ i discover the masochist in awe of dazed to
# $ im surprised if i did $ i empathize with
# $ i got there were to discover his own hand
# $ i barely even funny just had horrible they were
# $ i immediately related to coerce entire post on dvd
# $ i awoke an unstable bad impression with $ i
# $ i seemed so stunned actually curious again in this
# $ i cant help $ i feel overwhelmed im suppose
# $ i discover his work $ i often look at
# $ i would die and ingenious theories and obtain caught
# $ i move into making choices within this weird ones
# $ i this weird history behind which is unusual and
# $ i had such things from my funny blogging world
# $ i am really funny blogging $ i shared my
# $ i discovered through this funny $ i feel funny
# $ i stayed over it is amazing abundance of shocked
# $ i could have surprised that i remembered seeing them
# $ i talked with what was as i and somehow
# $ i started back b c section is amazing exhibit
# $ i read with little stunned liv was amazed on
# $ is funny a dorky unfit rotund sloth that $
# $ i stop feeling strangely my funny when im also
# $ i held all these amazing and pink and curious
# $ i feel strangely tranquil and almost didn t figure
# $ i been needing quite overwhelmed thinking of home it
# $ id like explaining the very lonely here and dizzy
# $ i floated in no one of shocked over everyone
# $ i discover his words $ i may have surprised
# $ i thought during most curious impatient eager knowing that
# $ i might feel amazed by justin aryiku falls into
# $ i cant handle it right back through at seeing
# $ i only the depths of shocked awe of woody
# $ i might look at her $ i seemed so
# $ im shocked me shocked my funny to be funny
# $ occured while not impressed at this funny sort of
# $ i kind of stars too $ i seemed to
# $ i watched idol which i wonder why i was
# $ im amazed he could be too cheap so amazing
# $ i m curious about two very stunned for her
# $ i are amazed he surprises me look at how
# $ i wonder woman in comparison though they were hard
# $ i discovered through my boyfriend during my funny like
# $ i discover his sun sensitive so who follows their
# $ on our loyal to the systems and dizzy and
# $ i pour code and i visited $ i don
# $ i wonder why she wouldn t think ur problemn
# $ i mention is funny in awe and different feel
# $ i was shocked into the test personal moral obligation
# $ i awoke an entire concept $ i discover his
# $ i didnt support system in with ia $ i
# $ i discover the masochist in awe of dazed to
# $ im surprised if i did $ i empathize with
# $ i got there were to discover his own hand
# $ i barely even funny just had horrible they were
# $ i immediately related to coerce entire post on dvd
# $ i awoke an unstable bad impression with $ i
# $ i seemed so stunned actually curious again in this

# %% [markdown]
# # SVC TFIDF
# ### Part B and Part C

# %%
emotion_data = {}
for emotion in emotions:            
    with open(f"{emotion}.txt", "r", encoding="utf-8") as file:
        emotion_data[f"{emotion}_samples"] = [line.strip() for line in file]

# %%
emotion_data
# Out:
# {'sadness_samples': ['$ a dark getting a retired wedding photographer $ i',
#   '$ occured while $ during a synonym for an apology',
#   '$ i often go out $ during the need drugs',
#   '$ i suffer i is fake people can put upon',
#   '$ ill also now unsuccessful $ i lack of color',
#   '$ i split up on overcoming the loss of pathetic',
#   '$ in stores because as worthless person $ i miss',
#   '$ when the sentence in finance as time of all',
#   '$ im usually even after my future $ i left',
#   '$ ill also ached $ id an unwelcome in wide',
#   '$ occured while $ ill get disturbed that suffer the',
#   '$ on its inadequate or forget about rabbits i start',
#   '$ ive never being hurt you always am left me',
#   '$ i blanked a class the whitley family $ i',
#   '$ i view when i exhausted all unloved $ i',
#   '$ im aching for netflix as worthless person as ugly',
#   '$ this pregnancy $ ill screw over reacting over mom',
#   '$ ill get on the minority in new $ on',
#   '$ on each and at peace love eating fresh new',
#   '$ ill laugh because as time to sleep i exhausted',
#   '$ i forgot my toes and start of lame about',
#   '$ during the experiment but that without emotion only thing',
#   '$ in life less see victoria take up feeling inadequate',
#   '$ i sometimes writing careers but otherwise ok it seems',
#   '$ i forgot my mother shirley demands drugs after went',
#   '$ i must haves but medicine $ during my disappointment',
#   '$ i exhausted $ ill mention him for and disasters',
#   '$ i doubt theres no reason possess no where god',
#   '$ im aching and sick $ in such a worthless',
#   '$ the road layout looks really awkward talking about most',
#   '$ i missed out boy i missed yoga because i',
#   '$ i give up did i barely maintain long ago',
#   '$ i exhausted $ a sandwich for xmas i hurt',
#   '$ a submarine cartwheel before the sorrows lurking about a',
#   '$ during most hated me with bad impression with all',
#   '$ i fail my boring amp needs as being ignored',
#   '$ ill will be worse i closed my poor and',
#   '$ ill will break me get disturbed $ i lack',
#   '$ i cleaned it again after being numb way instead',
#   '$ i blog $ i made you get the emotional',
#   '$ id know about americas heat of ourselves or live',
#   '$ i exhausted $ ill desperately wanting the anxieties i',
#   '$ i forgot my city the better do not $',
#   '$ i failed the anxieties i expressed my time till',
#   '$ i barely maintain long after my read and break',
#   '$ im using in his work my grief i should',
#   '$ i needed to this because life in finance as',
#   '$ i sort of psychopathology how would have depression and',
#   '$ the plight however unknown to crying again i left',
#   '$ no reason $ i live so defective when things'],
#  'joy_samples': ['$ occured while feeling positive about pleasing everyone else $',
#   '$ the companies of relief from seems to $ this',
#   '$ a quiet reflection or what may give it feel',
#   '$ this crunchy sweet with such as fantastic as expected',
#   '$ in retrospect if anywhere and quality of completeness like',
#   '$ when theres always tell you could do any lingering',
#   '$ on average and delighted in far on mermaidhaire does',
#   '$ is going to contain some ways i m happy',
#   '$ ive passed my intellect but never felt was true',
#   '$ occured while $ occured while preparing for her nicely',
#   '$ id hoped $ in sincerity in terms of happening',
#   '$ this invitation but everything for $ i expressed my',
#   '$ i offer me wherever you even go home as',
#   '$ on how your comments if you believe does justice',
#   '$ during an international audience who approve and helpful to',
#   '$ i seemed kind feelings entertained by now getting results',
#   '$ i discovered through any sense i recommend the music',
#   '$ i then feeling because i adapt and be keeping',
#   '$ no energy and emerged in virtual silence $ i',
#   '$ i ever change $ i vibrates up energy $',
#   '$ a carefree $ im presenting myself smiling like here',
#   '$ im putting the playing this affirmation over his understanding',
#   '$ i grew up twas am working out pretty $',
#   '$ i held all day and clean the dishes and',
#   '$ this blessed and bright coloured lipsticks are self assured',
#   '$ i feels so feel this patriotism only together $',
#   '$ in brave and yes lovely now makes fun of',
#   '$ i learned to switch off wipe out beautiful pearly',
#   '$ i sit through enough that seems like feel my',
#   '$ id like something productive organized and make themselves $',
#   '$ is over on yahoo and comfy that scientists to',
#   '$ is having something comes out beautiful pictures taken me',
#   '$ on overcoming the changes and innocent with ian $',
#   '$ a date will be just be determined to experience',
#   '$ is sooo sweet luke around at $ occured while',
#   '$ the usual progression of legacy $ this worth and',
#   '$ this welcoming and self awareness $ i kinda boring',
#   '$ this investment is way is welcomed and art into',
#   '$ occured while so full of sunshine and done to',
#   '$ i notice to day $ i carry on feeling',
#   '$ this makes sense of went to actually $ a',
#   '$ the decision kicking myself right track $ i remember',
#   '$ during an edge of workouts $ i do around',
#   '$ a chance to really hope that setting made me',
#   '$ a surprise two friends online $ in getting debt',
#   '$ in high school work like feel energized today a',
#   '$ i are better but feel shes pretty carefree state',
#   '$ this low and ethical views in heaven and laughable',
#   '$ during the strong feeling much excitement for heaven heaven',
#   '$ occured while i find a much larger point partly'],
#  'love_samples': ['$ i love him feel romantic towards beloved if i',
#   '$ i feel affectionate interested in love for many accessaries',
#   '$ i hope could better than sweet rhythm imprinted on',
#   '$ i feel gentle breath and forgiving lately so hot',
#   '$ i embrace the cooperation $ i embrace the love',
#   '$ i havent heard about supporting characters on loved posting',
#   '$ i hear from to finally confirm what not caring',
#   '$ i accepted in college on going and topping it',
#   '$ im overreacting or caring for caring $ im loved',
#   '$ im loving with its lovely polish $ i offer',
#   '$ i desire and alive $ i loved long $',
#   '$ i received and loved and supportive over sympathetic $',
#   '$ i admire her tender cool $ i embrace the',
#   '$ i have enjoyed about the longing urge to while',
#   '$ i love him which is rarely handled well thought',
#   '$ i believed there are likely make me to like',
#   '$ i wished would ask me how my faithful reader',
#   '$ i lve the gentle amusement $ im loving $',
#   '$ i loved $ i forgive myself from my problem',
#   '$ i liked doing it could genuinely looking over each',
#   '$ i clung onto them $ i shared and art',
#   '$ i wished would be loving kindness allow us at',
#   '$ i liked doing something lovely yarn and caring who',
#   '$ i love and all hot radiator $ i desire',
#   '$ i wished would love me $ i liked how',
#   '$ occured while everyone else was so devoted my love',
#   '$ i need to people in love of designer shoes',
#   '$ i feel beloved your lovely now im craving i',
#   '$ im craving addiction to kiss me $ i liked',
#   '$ i thank him to whether youre feeling that passionate',
#   '$ i admire her tender about supporting other and since',
#   '$ im still getting credit equals getting caught my lovely',
#   '$ i admire her close enough $ i was hot',
#   '$ i admire her tender little tender smile amused smile',
#   '$ ive learned a gentle rippling through loving simple shape',
#   '$ i liked the delicate and resistant for caring who',
#   '$ i admire her close enough about anime fandom in',
#   '$ ill desperately fond memories $ i empathize with the',
#   '$ i love the loyal reading viewing the cross cynical',
#   '$ i empathize with you believe there $ i love',
#   '$ i awoke an exciting story but adoring love for',
#   '$ i empathize with regard to kiss me love music',
#   '$ i loved $ i empathize with my faithfulness $',
#   '$ i liked mud wrestling or unloved $ i empathize',
#   '$ i stare and always hot all hot green tea',
#   '$ i embrace the door $ i loved safe again',
#   '$ i suggest you have admired and caring who want',
#   '$ im not accepted with no new in love him',
#   '$ i wanted to kiss my loyal reading his typical',
#   '$ i empathize with girly stuff and compassion for horny'],
#  'anger_samples': ['$ in outfit $ i never expected its teeth but',
#   '$ a post makes me clearly feel spiteful toward me',
#   '$ i ran away bad idea i a must that',
#   '$ no description $ in and persecuted by our decision',
#   '$ is rarely handled well and down and irritable like',
#   '$ on sony s truth about any lingering $ ive',
#   '$ is to that you up anybody to rain squeal',
#   '$ during an event because each other but days to',
#   '$ im building good things are on he d pagetitle',
#   '$ i t advocate the climb and environment but get',
#   '$ i did with not serving a short comings $',
#   '$ no point where they take control issues though something',
#   '$ heated discussion with my voice that your face complications',
#   '$ during a tortured by his love intentionally or are',
#   '$ heated discussion on the trimmings that $ during most',
#   '$ ive been measuring out o class so tortured the',
#   '$ is talk today though they want more disgusted and',
#   '$ on hanford city mostly because im nauseous $ im',
#   '$ is he was total partnership with sleep a month',
#   '$ a wuss and inner thighs $ ive waited my',
#   '$ i exercised and taiwan depending on xbla but hoping',
#   '$ im supposed to saying that people i personally feel',
#   '$ i fight the feelings of just had sat around',
#   '$ i lauper s time which has wronged or not',
#   '$ id talk about driving to plot ish issues but',
#   '$ on something etc $ during an idiot for hating',
#   '$ ive made this bike days it into middle age',
#   '$ im taking roll my problem and concerned really chuffed',
#   '$ on anything that carcenogenic smoke pot alone in expressing',
#   '$ during that made us have met again $ when',
#   '$ ill screw over or even more than a family',
#   '$ im only will step in manufacturing and for not',
#   '$ a pulp $ occured while not chick flick where',
#   '$ on certain parts of walking hand shops just that',
#   '$ im also caused members who were also caused members',
#   '$ a out from this letter i then headed to',
#   '$ ill desperately trying to lend my un emo song',
#   '$ during the many other the psychologist all betrayed and',
#   '$ heated discussion with one or wot $ this feelings',
#   '$ on around plants back that day min $ no',
#   '$ a spoiled little miss a nod to reflect on',
#   '$ ive been temperature shocked and shake $ a manner',
#   '$ when other side its own head with numbers for',
#   '$ this came to fly $ in circles and frizz',
#   '$ i sat around anyone after time to poke me',
#   '$ im here nobody hears i to shinobi thats largely',
#   '$ ive already passed this notice my vision and deny',
#   '$ no solution for its at ideas how many people',
#   '$ a haze trying to dogs as sin cara $',
#   '$ im typing this happened for saying any lingering feelings'],
#  'fear_samples': ['$ i caught my thighs you think about feeling confused',
#   '$ is alarming since its triggering i confused by noticing',
#   '$ on mermaidhaire does feel afraid because to hide this',
#   '$ id bought the key to report that chronically living',
#   '$ id make room simply because thats the toddler possessing',
#   '$ i suspect feel neurotic as terrified she paused dramatically',
#   '$ i awoke an sls free exhilarated $ i sensed',
#   '$ i closed on and blowing on tour and fearful',
#   '$ i fell for what kind of such times a',
#   '$ ive dated because as shaky and slink around the',
#   '$ the beginning to their bags $ i held all',
#   '$ i stepped into korean $ i lift $ i',
#   '$ i cannot stand feeling somewhat alarmed $ in various',
#   '$ im temporarily wounded feeling tampons and incapable and walked',
#   '$ i blinded feelings like feel skeptical of staff first',
#   '$ i woke up about minutes while typing this old',
#   '$ i encounter in fear because i wondered if that',
#   '$ the day but hoping these changes cause of unencumberedness',
#   '$ i accidentally feel uptight at the coming from noah',
#   '$ id try and nervous $ id done before and',
#   '$ i start panic breathing tubes attacking the pool if',
#   '$ occured while listening to toronto and restless today as',
#   '$ id talk to curl up there was pregnant too',
#   '$ occured while and unsettled because of any who should',
#   '$ i wonder i instantly feel helpless in it is',
#   '$ ill screw anything else $ i encounter in some',
#   '$ i barely even respect me and confused after watching',
#   '$ i suspect feel restless today when not have tons',
#   '$ i woke up when a fearful that person in',
#   '$ the beginning a ghost $ id just looking snaps',
#   '$ the surface giving them meditating with how distraught he',
#   '$ i wondered why i floated in outfit $ i',
#   '$ i so many amazing chapter in zambia $ i',
#   '$ ive been needing quite unclear on my skin i',
#   '$ i found herself in oregon $ i must always',
#   '$ i saw a room to droop and wound up',
#   '$ im constantly paranoid that our progress $ i grabbed',
#   '$ during most important to reflect on their feelings of',
#   '$ im around boys this final one girls in zombie',
#   '$ id know f t felt $ in washington so',
#   '$ i visited the a plane to effect real life',
#   '$ i woke up my footing and actually doing something',
#   '$ im around these because arun has somehow not curl',
#   '$ i turned out fearful anxiety is slowly killing me',
#   '$ i stopped feeling shaken as online who is that',
#   '$ i sensed he get confused by to dubstep when',
#   '$ i almost flat $ i recall being married i',
#   '$ i wondered would cause of ideas how desperately curious',
#   '$ when someone did laps and went down when conversing',
#   '$ i floated in stores because if im down when'],
#  'surprise_samples': ['$ i cant help $ i feel overwhelmed im suppose',
#   '$ i discover his work $ i often look at',
#   '$ i would die and ingenious theories and obtain caught',
#   '$ i move into making choices within this weird ones',
#   '$ i this weird history behind which is unusual and',
#   '$ i had such things from my funny blogging world',
#   '$ i am really funny blogging $ i shared my',
#   '$ i discovered through this funny $ i feel funny',
#   '$ i stayed over it is amazing abundance of shocked',
#   '$ i could have surprised that i remembered seeing them',
#   '$ i talked with what was as i and somehow',
#   '$ i started back b c section is amazing exhibit',
#   '$ i read with little stunned liv was amazed on',
#   '$ is funny a dorky unfit rotund sloth that $',
#   '$ i stop feeling strangely my funny when im also',
#   '$ i held all these amazing and pink and curious',
#   '$ i feel strangely tranquil and almost didn t figure',
#   '$ i been needing quite overwhelmed thinking of home it',
#   '$ id like explaining the very lonely here and dizzy',
#   '$ i floated in no one of shocked over everyone',
#   '$ i discover his words $ i may have surprised',
#   '$ i thought during most curious impatient eager knowing that',
#   '$ i might feel amazed by justin aryiku falls into',
#   '$ i cant handle it right back through at seeing',
#   '$ i only the depths of shocked awe of woody',
#   '$ i might look at her $ i seemed so',
#   '$ im shocked me shocked my funny to be funny',
#   '$ occured while not impressed at this funny sort of',
#   '$ i kind of stars too $ i seemed to',
#   '$ i watched idol which i wonder why i was',
#   '$ im amazed he could be too cheap so amazing',
#   '$ i m curious about two very stunned for her',
#   '$ i are amazed he surprises me look at how',
#   '$ i wonder woman in comparison though they were hard',
#   '$ i discovered through my boyfriend during my funny like',
#   '$ i discover his sun sensitive so who follows their',
#   '$ on our loyal to the systems and dizzy and',
#   '$ i pour code and i visited $ i don',
#   '$ i wonder why she wouldn t think ur problemn',
#   '$ i mention is funny in awe and different feel',
#   '$ i was shocked into the test personal moral obligation',
#   '$ i awoke an entire concept $ i discover his',
#   '$ i didnt support system in with ia $ i',
#   '$ i discover the masochist in awe of dazed to',
#   '$ im surprised if i did $ i empathize with',
#   '$ i got there were to discover his own hand',
#   '$ i barely even funny just had horrible they were',
#   '$ i immediately related to coerce entire post on dvd',
#   '$ i awoke an unstable bad impression with $ i',
#   '$ i seemed so stunned actually curious again in this']}

# %%
# Combining Data
generated_samples = []
generated_labels = []


for emotion in emotion_data:
    for emotion_sample in emotion_data[emotion]:             
        generated_samples.append(emotion_sample)
        generated_labels.append(emotion.split("_")[0])

# %%
# Check the generated samples retreieved from each of <emotion>.txt files
generated_samples
# Out:
# ['$ a dark getting a retired wedding photographer $ i',
#  '$ occured while $ during a synonym for an apology',
#  '$ i often go out $ during the need drugs',
#  '$ i suffer i is fake people can put upon',
#  '$ ill also now unsuccessful $ i lack of color',
#  '$ i split up on overcoming the loss of pathetic',
#  '$ in stores because as worthless person $ i miss',
#  '$ when the sentence in finance as time of all',
#  '$ im usually even after my future $ i left',
#  '$ ill also ached $ id an unwelcome in wide',
#  '$ occured while $ ill get disturbed that suffer the',
#  '$ on its inadequate or forget about rabbits i start',
#  '$ ive never being hurt you always am left me',
#  '$ i blanked a class the whitley family $ i',
#  '$ i view when i exhausted all unloved $ i',
#  '$ im aching for netflix as worthless person as ugly',
#  '$ this pregnancy $ ill screw over reacting over mom',
#  '$ ill get on the minority in new $ on',
#  '$ on each and at peace love eating fresh new',
#  '$ ill laugh because as time to sleep i exhausted',
#  '$ i forgot my toes and start of lame about',
#  '$ during the experiment but that without emotion only thing',
#  '$ in life less see victoria take up feeling inadequate',
#  '$ i sometimes writing careers but otherwise ok it seems',
#  '$ i forgot my mother shirley demands drugs after went',
#  '$ i must haves but medicine $ during my disappointment',
#  '$ i exhausted $ ill mention him for and disasters',
#  '$ i doubt theres no reason possess no where god',
#  '$ im aching and sick $ in such a worthless',
#  '$ the road layout looks really awkward talking about most',
#  '$ i missed out boy i missed yoga because i',
#  '$ i give up did i barely maintain long ago',
#  '$ i exhausted $ a sandwich for xmas i hurt',
#  '$ a submarine cartwheel before the sorrows lurking about a',
#  '$ during most hated me with bad impression with all',
#  '$ i fail my boring amp needs as being ignored',
#  '$ ill will be worse i closed my poor and',
#  '$ ill will break me get disturbed $ i lack',
#  '$ i cleaned it again after being numb way instead',
#  '$ i blog $ i made you get the emotional',
#  '$ id know about americas heat of ourselves or live',
#  '$ i exhausted $ ill desperately wanting the anxieties i',
#  '$ i forgot my city the better do not $',
#  '$ i failed the anxieties i expressed my time till',
#  '$ i barely maintain long after my read and break',
#  '$ im using in his work my grief i should',
#  '$ i needed to this because life in finance as',
#  '$ i sort of psychopathology how would have depression and',
#  '$ the plight however unknown to crying again i left',
#  '$ no reason $ i live so defective when things',
#  '$ occured while feeling positive about pleasing everyone else $',
#  '$ the companies of relief from seems to $ this',
#  '$ a quiet reflection or what may give it feel',
#  '$ this crunchy sweet with such as fantastic as expected',
#  '$ in retrospect if anywhere and quality of completeness like',
#  '$ when theres always tell you could do any lingering',
#  '$ on average and delighted in far on mermaidhaire does',
#  '$ is going to contain some ways i m happy',
#  '$ ive passed my intellect but never felt was true',
#  '$ occured while $ occured while preparing for her nicely',
#  '$ id hoped $ in sincerity in terms of happening',
#  '$ this invitation but everything for $ i expressed my',
#  '$ i offer me wherever you even go home as',
#  '$ on how your comments if you believe does justice',
#  '$ during an international audience who approve and helpful to',
#  '$ i seemed kind feelings entertained by now getting results',
#  '$ i discovered through any sense i recommend the music',
#  '$ i then feeling because i adapt and be keeping',
#  '$ no energy and emerged in virtual silence $ i',
#  '$ i ever change $ i vibrates up energy $',
#  '$ a carefree $ im presenting myself smiling like here',
#  '$ im putting the playing this affirmation over his understanding',
#  '$ i grew up twas am working out pretty $',
#  '$ i held all day and clean the dishes and',
#  '$ this blessed and bright coloured lipsticks are self assured',
#  '$ i feels so feel this patriotism only together $',
#  '$ in brave and yes lovely now makes fun of',
#  '$ i learned to switch off wipe out beautiful pearly',
#  '$ i sit through enough that seems like feel my',
#  '$ id like something productive organized and make themselves $',
#  '$ is over on yahoo and comfy that scientists to',
#  '$ is having something comes out beautiful pictures taken me',
#  '$ on overcoming the changes and innocent with ian $',
#  '$ a date will be just be determined to experience',
#  '$ is sooo sweet luke around at $ occured while',
#  '$ the usual progression of legacy $ this worth and',
#  '$ this welcoming and self awareness $ i kinda boring',
#  '$ this investment is way is welcomed and art into',
#  '$ occured while so full of sunshine and done to',
#  '$ i notice to day $ i carry on feeling',
#  '$ this makes sense of went to actually $ a',
#  '$ the decision kicking myself right track $ i remember',
#  '$ during an edge of workouts $ i do around',
#  '$ a chance to really hope that setting made me',
#  '$ a surprise two friends online $ in getting debt',
#  '$ in high school work like feel energized today a',
#  '$ i are better but feel shes pretty carefree state',
#  '$ this low and ethical views in heaven and laughable',
#  '$ during the strong feeling much excitement for heaven heaven',
#  '$ occured while i find a much larger point partly',
#  '$ i love him feel romantic towards beloved if i',
#  '$ i feel affectionate interested in love for many accessaries',
#  '$ i hope could better than sweet rhythm imprinted on',
#  '$ i feel gentle breath and forgiving lately so hot',
#  '$ i embrace the cooperation $ i embrace the love',
#  '$ i havent heard about supporting characters on loved posting',
#  '$ i hear from to finally confirm what not caring',
#  '$ i accepted in college on going and topping it',
#  '$ im overreacting or caring for caring $ im loved',
#  '$ im loving with its lovely polish $ i offer',
#  '$ i desire and alive $ i loved long $',
#  '$ i received and loved and supportive over sympathetic $',
#  '$ i admire her tender cool $ i embrace the',
#  '$ i have enjoyed about the longing urge to while',
#  '$ i love him which is rarely handled well thought',
#  '$ i believed there are likely make me to like',
#  '$ i wished would ask me how my faithful reader',
#  '$ i lve the gentle amusement $ im loving $',
#  '$ i loved $ i forgive myself from my problem',
#  '$ i liked doing it could genuinely looking over each',
#  '$ i clung onto them $ i shared and art',
#  '$ i wished would be loving kindness allow us at',
#  '$ i liked doing something lovely yarn and caring who',
#  '$ i love and all hot radiator $ i desire',
#  '$ i wished would love me $ i liked how',
#  '$ occured while everyone else was so devoted my love',
#  '$ i need to people in love of designer shoes',
#  '$ i feel beloved your lovely now im craving i',
#  '$ im craving addiction to kiss me $ i liked',
#  '$ i thank him to whether youre feeling that passionate',
#  '$ i admire her tender about supporting other and since',
#  '$ im still getting credit equals getting caught my lovely',
#  '$ i admire her close enough $ i was hot',
#  '$ i admire her tender little tender smile amused smile',
#  '$ ive learned a gentle rippling through loving simple shape',
#  '$ i liked the delicate and resistant for caring who',
#  '$ i admire her close enough about anime fandom in',
#  '$ ill desperately fond memories $ i empathize with the',
#  '$ i love the loyal reading viewing the cross cynical',
#  '$ i empathize with you believe there $ i love',
#  '$ i awoke an exciting story but adoring love for',
#  '$ i empathize with regard to kiss me love music',
#  '$ i loved $ i empathize with my faithfulness $',
#  '$ i liked mud wrestling or unloved $ i empathize',
#  '$ i stare and always hot all hot green tea',
#  '$ i embrace the door $ i loved safe again',
#  '$ i suggest you have admired and caring who want',
#  '$ im not accepted with no new in love him',
#  '$ i wanted to kiss my loyal reading his typical',
#  '$ i empathize with girly stuff and compassion for horny',
#  '$ in outfit $ i never expected its teeth but',
#  '$ a post makes me clearly feel spiteful toward me',
#  '$ i ran away bad idea i a must that',
#  '$ no description $ in and persecuted by our decision',
#  '$ is rarely handled well and down and irritable like',
#  '$ on sony s truth about any lingering $ ive',
#  '$ is to that you up anybody to rain squeal',
#  '$ during an event because each other but days to',
#  '$ im building good things are on he d pagetitle',
#  '$ i t advocate the climb and environment but get',
#  '$ i did with not serving a short comings $',
#  '$ no point where they take control issues though something',
#  '$ heated discussion with my voice that your face complications',
#  '$ during a tortured by his love intentionally or are',
#  '$ heated discussion on the trimmings that $ during most',
#  '$ ive been measuring out o class so tortured the',
#  '$ is talk today though they want more disgusted and',
#  '$ on hanford city mostly because im nauseous $ im',
#  '$ is he was total partnership with sleep a month',
#  '$ a wuss and inner thighs $ ive waited my',
#  '$ i exercised and taiwan depending on xbla but hoping',
#  '$ im supposed to saying that people i personally feel',
#  '$ i fight the feelings of just had sat around',
#  '$ i lauper s time which has wronged or not',
#  '$ id talk about driving to plot ish issues but',
#  '$ on something etc $ during an idiot for hating',
#  '$ ive made this bike days it into middle age',
#  '$ im taking roll my problem and concerned really chuffed',
#  '$ on anything that carcenogenic smoke pot alone in expressing',
#  '$ during that made us have met again $ when',
#  '$ ill screw over or even more than a family',
#  '$ im only will step in manufacturing and for not',
#  '$ a pulp $ occured while not chick flick where',
#  '$ on certain parts of walking hand shops just that',
#  '$ im also caused members who were also caused members',
#  '$ a out from this letter i then headed to',
#  '$ ill desperately trying to lend my un emo song',
#  '$ during the many other the psychologist all betrayed and',
#  '$ heated discussion with one or wot $ this feelings',
#  '$ on around plants back that day min $ no',
#  '$ a spoiled little miss a nod to reflect on',
#  '$ ive been temperature shocked and shake $ a manner',
#  '$ when other side its own head with numbers for',
#  '$ this came to fly $ in circles and frizz',
#  '$ i sat around anyone after time to poke me',
#  '$ im here nobody hears i to shinobi thats largely',
#  '$ ive already passed this notice my vision and deny',
#  '$ no solution for its at ideas how many people',
#  '$ a haze trying to dogs as sin cara $',
#  '$ im typing this happened for saying any lingering feelings',
#  '$ i caught my thighs you think about feeling confused',
#  '$ is alarming since its triggering i confused by noticing',
#  '$ on mermaidhaire does feel afraid because to hide this',
#  '$ id bought the key to report that chronically living',
#  '$ id make room simply because thats the toddler possessing',
#  '$ i suspect feel neurotic as terrified she paused dramatically',
#  '$ i awoke an sls free exhilarated $ i sensed',
#  '$ i closed on and blowing on tour and fearful',
#  '$ i fell for what kind of such times a',
#  '$ ive dated because as shaky and slink around the',
#  '$ the beginning to their bags $ i held all',
#  '$ i stepped into korean $ i lift $ i',
#  '$ i cannot stand feeling somewhat alarmed $ in various',
#  '$ im temporarily wounded feeling tampons and incapable and walked',
#  '$ i blinded feelings like feel skeptical of staff first',
#  '$ i woke up about minutes while typing this old',
#  '$ i encounter in fear because i wondered if that',
#  '$ the day but hoping these changes cause of unencumberedness',
#  '$ i accidentally feel uptight at the coming from noah',
#  '$ id try and nervous $ id done before and',
#  '$ i start panic breathing tubes attacking the pool if',
#  '$ occured while listening to toronto and restless today as',
#  '$ id talk to curl up there was pregnant too',
#  '$ occured while and unsettled because of any who should',
#  '$ i wonder i instantly feel helpless in it is',
#  '$ ill screw anything else $ i encounter in some',
#  '$ i barely even respect me and confused after watching',
#  '$ i suspect feel restless today when not have tons',
#  '$ i woke up when a fearful that person in',
#  '$ the beginning a ghost $ id just looking snaps',
#  '$ the surface giving them meditating with how distraught he',
#  '$ i wondered why i floated in outfit $ i',
#  '$ i so many amazing chapter in zambia $ i',
#  '$ ive been needing quite unclear on my skin i',
#  '$ i found herself in oregon $ i must always',
#  '$ i saw a room to droop and wound up',
#  '$ im constantly paranoid that our progress $ i grabbed',
#  '$ during most important to reflect on their feelings of',
#  '$ im around boys this final one girls in zombie',
#  '$ id know f t felt $ in washington so',
#  '$ i visited the a plane to effect real life',
#  '$ i woke up my footing and actually doing something',
#  '$ im around these because arun has somehow not curl',
#  '$ i turned out fearful anxiety is slowly killing me',
#  '$ i stopped feeling shaken as online who is that',
#  '$ i sensed he get confused by to dubstep when',
#  '$ i almost flat $ i recall being married i',
#  '$ i wondered would cause of ideas how desperately curious',
#  '$ when someone did laps and went down when conversing',
#  '$ i floated in stores because if im down when',
#  '$ i cant help $ i feel overwhelmed im suppose',
#  '$ i discover his work $ i often look at',
#  '$ i would die and ingenious theories and obtain caught',
#  '$ i move into making choices within this weird ones',
#  '$ i this weird history behind which is unusual and',
#  '$ i had such things from my funny blogging world',
#  '$ i am really funny blogging $ i shared my',
#  '$ i discovered through this funny $ i feel funny',
#  '$ i stayed over it is amazing abundance of shocked',
#  '$ i could have surprised that i remembered seeing them',
#  '$ i talked with what was as i and somehow',
#  '$ i started back b c section is amazing exhibit',
#  '$ i read with little stunned liv was amazed on',
#  '$ is funny a dorky unfit rotund sloth that $',
#  '$ i stop feeling strangely my funny when im also',
#  '$ i held all these amazing and pink and curious',
#  '$ i feel strangely tranquil and almost didn t figure',
#  '$ i been needing quite overwhelmed thinking of home it',
#  '$ id like explaining the very lonely here and dizzy',
#  '$ i floated in no one of shocked over everyone',
#  '$ i discover his words $ i may have surprised',
#  '$ i thought during most curious impatient eager knowing that',
#  '$ i might feel amazed by justin aryiku falls into',
#  '$ i cant handle it right back through at seeing',
#  '$ i only the depths of shocked awe of woody',
#  '$ i might look at her $ i seemed so',
#  '$ im shocked me shocked my funny to be funny',
#  '$ occured while not impressed at this funny sort of',
#  '$ i kind of stars too $ i seemed to',
#  '$ i watched idol which i wonder why i was',
#  '$ im amazed he could be too cheap so amazing',
#  '$ i m curious about two very stunned for her',
#  '$ i are amazed he surprises me look at how',
#  '$ i wonder woman in comparison though they were hard',
#  '$ i discovered through my boyfriend during my funny like',
#  '$ i discover his sun sensitive so who follows their',
#  '$ on our loyal to the systems and dizzy and',
#  '$ i pour code and i visited $ i don',
#  '$ i wonder why she wouldn t think ur problemn',
#  '$ i mention is funny in awe and different feel',
#  '$ i was shocked into the test personal moral obligation',
#  '$ i awoke an entire concept $ i discover his',
#  '$ i didnt support system in with ia $ i',
#  '$ i discover the masochist in awe of dazed to',
#  '$ im surprised if i did $ i empathize with',
#  '$ i got there were to discover his own hand',
#  '$ i barely even funny just had horrible they were',
#  '$ i immediately related to coerce entire post on dvd',
#  '$ i awoke an unstable bad impression with $ i',
#  '$ i seemed so stunned actually curious again in this']

# %%
# Check the corresponding generated labels
generated_labels
# Out:
# ['sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'anger',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'fear',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise']

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from sklearn.pipeline import Pipeline

# Load the original corpus and labels
with open('corpus.txt', 'r', encoding='utf-8') as file:
    corpus = file.read().splitlines()

with open('labels.txt', 'r', encoding='utf-8') as file:
    labels = file.read().splitlines()

# Assuming 'generated_samples' and 'generated_labels' are lists containing the generated samples and labels
# X_train, X_test, y_train, y_test = train_test_split(corpus + generated_samples, labels + generated_labels, test_size=0.2, random_state=42)


# Define the pipeline with TF-IDF vectorizer and SVC classifier
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('svc', SVC())
])

# # Define parameter grid for Grid Search
# param_grid = {
#     'tfidf__max_features': [5000, 10000, 20000],
#     'svc__C': [0.1, 1, 10],
#     'svc__kernel': ['linear', 'rbf']
# }

# Define parameter grid for Grid Search
param_grid = {
    'tfidf__max_features': [5000, 10000, 20000],
    'tfidf__ngram_range': [(1, 1), (1, 2)],  # Adjust n-gram range
    'svc__C': [0.1, 1, 10],
    'svc__kernel': ['linear', 'rbf'],
    'svc__gamma': ['scale', 'auto', 0.1, 1.0],  # Adjust gamma
    'svc__class_weight': [None, 'balanced']  # Adjust class weight
}

# Perform Grid Search
grid_search = GridSearchCV(pipeline, param_grid, cv=10, n_jobs=-1)
# Train
X_train = corpus
y_train = labels
X_test = generated_samples
y_test = generated_labels

grid_search.fit(X_train, y_train)

# Print the best parameters
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validated Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'svc__C': 10, 'svc__class_weight': None, 'svc__gamma': 0.1, 'svc__kernel': 'rbf', 'tfidf__max_features': 5000, 'tfidf__ngram_range': (1, 1)}
# Best Cross-Validated Score: 0.765

# %%
# Use the best model to predict on the test set
y_pred_by_model = grid_search.predict(X_test)

# Evaluate the performance
accuracy = accuracy_score(y_test, y_pred_by_model)
classification_rep = classification_report(y_test, y_pred_by_model)

print("\nAccuracy:", accuracy)
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 0.5733333333333334
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        anger       0.47      0.30      0.37        50
#         fear       0.63      0.54      0.58        50
#          joy       0.36      0.40      0.38        50
#         love       0.86      0.84      0.85        50
#      sadness       0.42      0.72      0.53        50
#     surprise       0.91      0.64      0.75        50
#
#     accuracy                           0.57       300
#    macro avg       0.61      0.57      0.58       300
# weighted avg       0.61      0.57      0.58       300

# %% [markdown]
# ### Task 2: Report Submittables

# %%
bigram_model.bigramProbabilities
# Out:
# defaultdict(int,
#             {('$', 'i'): 0.8783333333333333,
#              ('i', 'stand'): 0.0005278437582475588,
#              ('stand', 'here'): 0.1,
#              ('here', 'i'): 0.16216216216216217,
#              ('i', 'feel'): 0.2684085510688836,
#              ('feel', 'empty'): 0.0012217470983506415,
#              ('empty', 'a'): 0.1111111111111111,
#              ('a', 'class'): 0.001091703056768559,
#              ('class', 'post'): 0.07692307692307693,
#              ('post', 'count'): 0.07142857142857142,
#              ('count', 'link'): 0.25,
#              ('link', 'href'): 0.5,
#              ('href', 'http'): 1.0,
#              ('http', 'mooshilu'): 0.03333333333333333,
#              ('mooshilu', '$'): 1.0,
#              ('i', 'literally'): 0.0002639218791237794,
#              ('literally', 'just'): 0.25,
#              ('just', 'text'): 0.004424778761061947,
#              ('text', 'tychelle'): 0.3333333333333333,
#              ('tychelle', 'to'): 1.0,
#              ('to', 'see'): 0.011194029850746268,
#              ('see', 'if'): 0.06666666666666667,
#              ('if', 'she'): 0.007462686567164179,
#              ('she', 'wants'): 0.027777777777777776,
#              ('wants', 'to'): 0.42857142857142855,
#              ('to', 'hang'): 0.0007462686567164179,
#              ('hang', 'out'): 1.0,
#              ('out', 'because'): 0.008849557522123894,
#              ('because', 'reading'): 0.00546448087431694,
#              ('reading', 'what'): 0.07692307692307693,
#              ('what', 'i'): 0.344,
#              ('i', 'just'): 0.015571390868302983,
#              ('just', 'wrote'): 0.004424778761061947,
#              ('wrote', 'about'): 0.25,
#              ('about', 'my'): 0.0738255033557047,
#              ('my', 'nonexistent'): 0.001557632398753894,
#              ('nonexistent', 'social'): 1.0,
#              ('social', 'life'): 0.2857142857142857,
#              ('life', 'made'): 0.010416666666666666,
#              ('made', 'me'): 0.4444444444444444,
#              ('me', 'feel'): 0.11518324607329843,
#              ('feel', 'so'): 0.06719609040928527,
#              ('so', 'pathetic'): 0.00546448087431694,
#              ('pathetic', '$'): 0.16666666666666666,
#              ('i', 'really'): 0.008973343890208499,
#              ('really', 'feel'): 0.07006369426751592,
#              ('feel', 'regretful'): 0.0012217470983506415,
#              ('regretful', 'when'): 0.16666666666666666,
#              ('when', 'hearing'): 0.0043859649122807015,
#              ('hearing', 'that'): 0.5,
#              ('that', 'shinae'): 0.001256281407035176,
#              ('shinae', 'got'): 0.5,
#              ('got', 'married'): 0.024390243902439025,
#              ('married', 'to'): 0.25,
#              ('to', 'another'): 0.0014925373134328358,
#              ('another', 'man'): 0.05263157894736842,
#              ('man', 'oh'): 0.07692307692307693,
#              ('oh', 'it'): 0.125,
#              ('it', 's'): 0.05048543689320388,
#              ('s', 'really'): 0.012195121951219513,
#              ('really', 'sad'): 0.006369426751592357,
#              ('sad', 'i'): 0.08333333333333333,
#              ('really', 'hope'): 0.012738853503184714,
#              ('hope', 'that'): 0.15,
#              ('that', 'alex'): 0.001256281407035176,
#              ('alex', 'and'): 1.0,
#              ('and', 'shinae'): 0.0006882312456985547,
#              ('shinae', 'can'): 0.5,
#              ('can', 'be'): 0.058823529411764705,
#              ('be', 'a'): 0.06545454545454546,
#              ('a', 'couple'): 0.009825327510917031,
#              ('couple', 'in'): 0.07692307692307693,
#              ('in', 'real'): 0.0019646365422396855,
#              ('real', 'life'): 0.23076923076923078,
#              ('life', 'they'): 0.010416666666666666,
#              ('they', 're'): 0.027522935779816515,
#              ('re', 'perfect'): 0.047619047619047616,
#              ('perfect', 'for'): 0.2222222222222222,
#              ('for', 'each'): 0.0103359173126615,
#              ('each', 'other'): 0.35294117647058826,
#              ('other', '$'): 0.0425531914893617,
#              ('i', 'believed'): 0.0002639218791237794,
#              ('believed', 'it'): 0.5,
#              ('it', 'was'): 0.07572815533980583,
#              ('was', 'true'): 0.0029498525073746312,
#              ('true', 'love'): 0.125,
#              ('love', 'and'): 0.07142857142857142,
#              ('and', 'feel'): 0.02477632484514797,
#              ('feel', 'devastated'): 0.0030543677458766036,
#              ('devastated', 'i'): 0.125,
#              ('i', 'wanted'): 0.003167062549485352,
#              ('wanted', 'to'): 0.75,
#              ('to', 'settle'): 0.002238805970149254,
#              ('settle', 'down'): 0.3333333333333333,
#              ('down', 'and'): 0.12903225806451613,
#              ('and', 'have'): 0.008947006194081212,
#              ('have', 'the'): 0.029801324503311258,
#              ('the', 'whole'): 0.007830853563038372,
#              ('whole', 'marriage'): 0.07142857142857142,
#              ('marriage', 'and'): 1.0,
#              ('and', 'kids'): 0.0006882312456985547,
#              ('kids', 'thing'): 0.0625,
#              ('thing', 'with'): 0.043478260869565216,
#              ('with', 'him'): 0.029315960912052116,
#              ('him', '$'): 0.10714285714285714,
#              ('feel', 'unimportant'): 0.0012217470983506415,
#              ('unimportant', 'so'): 0.25,
#              ('so', 'inadequate'): 0.00273224043715847,
#              ('inadequate', '$'): 0.2,
#              ('feel', 'very'): 0.02565668906536347,
#              ('very', 'low'): 0.016,
#              ('low', 'already'): 0.1,
#              ('already', '$'): 0.14285714285714285,
#              ('feel', 'horrible'): 0.002443494196701283,
#              ('horrible', 'they'): 0.14285714285714285,
#              ('they', 'wrote'): 0.009174311926605505,
#              ('wrote', 'again'): 0.25,
#              ('again', 'and'): 0.05555555555555555,
#              ('and', 'again'): 0.0020646937370956643,
#              ('again', 'personifying'): 0.018518518518518517,
#              ('personifying', 'an'): 1.0,
#              ('an', 'act'): 0.027777777777777776,
#              ('act', 'they'): 0.25,
#              ('they', 'were'): 0.07339449541284404,
#              ('were', 'not'): 0.02127659574468085,
#              ('not', 'the'): 0.014336917562724014,
#              ('the', 'cause'): 0.0015661707126076742,
#              ('cause', 'of'): 0.23076923076923078,
#              ('of', 'it'): 0.015978695073235686,
#              ('was', 'their'): 0.0058997050147492625,
#              ('their', 'progeny'): 0.017543859649122806,
#              ('progeny', 'who'): 1.0,
#              ('who', 'should'): 0.022988505747126436,
#              ('should', 'be'): 0.38,
#              ('be', 'genuflecting'): 0.0036363636363636364,
#              ('genuflecting', 'at'): 1.0,
#              ('at', 'her'): 0.020833333333333332,
#              ('her', 'the'): 0.020618556701030927,
#              ('the', 'wronged'): 0.0007830853563038371,
#              ('wronged', 'woman'): 0.1111111111111111,
#              ('woman', 's'): 0.16666666666666666,
#              ('s', 'feet'): 0.012195121951219513,
#              ('feet', '$'): 0.2,
#              ('$', 'ill'): 0.002916666666666667,
#              ('ill', 'just'): 0.08695652173913043,
#              ('just', 'paraphrase'): 0.004424778761061947,
#              ('paraphrase', 'i'): 1.0,
#              ('i', 'ranted'): 0.0002639218791237794,
#              ('ranted', 'about'): 1.0,
#              ('about', 'not'): 0.010067114093959731,
#              ('not', 'being'): 0.02867383512544803,
#              ('being', 'able'): 0.03488372093023256,
#              ('able', 'to'): 0.9444444444444444,
#              ('to', 'trust'): 0.0014925373134328358,
#              ('trust', 'anybody'): 0.09090909090909091,
#              ('anybody', 'and'): 0.25,
#              ('and', 'being'): 0.0020646937370956643,
#              ('being', 'hurt'): 0.011627906976744186,
#              ('hurt', 'feeling'): 0.09090909090909091,
#              ('feeling', 'rejected'): 0.0025188916876574307,
#              ('rejected', 'etc'): 0.125,
#              ('etc', '$'): 0.875,
#              ('feel', 'aching'): 0.0006108735491753207,
#              ('aching', 'at'): 0.16666666666666666,
#              ('at', 'all'): 0.08333333333333333,
#              ('all', 'times'): 0.0111731843575419,
#              ('times', 'of'): 0.07142857142857142,
#              ('of', 'day'): 0.002663115845539281,
#              ('day', '$'): 0.21666666666666667,
#              ('so', 'dumb'): 0.00273224043715847,
#              ('dumb', 'when'): 0.16666666666666666,
#              ('when', 'at'): 0.0043859649122807015,
#              ('at', 'first'): 0.004166666666666667,
#              ('first', 'run'): 0.037037037037037035,
#              ('run', 'through'): 0.125,
#              ('through', 'it'): 0.024390243902439025,
#              ('it', 'all'): 0.027184466019417475,
#              ('all', 'seems'): 0.00558659217877095,
#              ('seems', 'over'): 0.058823529411764705,
#              ('over', 'my'): 0.03225806451612903,
#              ('my', 'head'): 0.010903426791277258,
#              ('head', 'amp'): 0.0625,
#              ('amp', 'a'): 0.125,
#              ('a', 'little'): 0.09716157205240175,
#              ('little', 'too'): 0.026785714285714284,
#              ('too', 'much'): 0.16393442622950818,
#              ('much', 'for'): 0.013333333333333334,
#              ('for', 'my'): 0.04392764857881137,
#              ('my', 'struggling'): 0.001557632398753894,
#              ('struggling', 'brain'): 0.5,
#              ('brain', '$'): 0.16666666666666666,
#              ('i', 'mention'): 0.0005278437582475588,
#              ('mention', 'this'): 0.1111111111111111,
#              ('this', 'one'): 0.02280130293159609,
#              ('one', 'doesn'): 0.011764705882352941,
#              ('doesn', 't'): 1.0,
#              ('t', 'feel'): 0.2426470588235294,
#              ('feel', 'fake'): 0.0006108735491753207,
#              ('fake', '$'): 0.5,
#              ('$', 'im'): 0.08833333333333333,
#              ('im', 'more'): 0.0024691358024691358,
#              ('more', 'scared'): 0.008064516129032258,
#              ('scared', 'of'): 0.08333333333333333,
#              ('of', 'like'): 0.002663115845539281,
#              ('like', 'dramas'): 0.0021598272138228943,
#              ('dramas', 'or'): 1.0,
#              ('or', 'thrillers'): 0.005319148936170213,
#              ('thrillers', 'that'): 1.0,
#              ('that', 'are'): 0.01256281407035176,
#              ('are', 'actually'): 0.015151515151515152,
#              ('actually', 'capable'): 0.03333333333333333,
#              ('capable', 'of'): 1.0,
#              ('of', 'happening'): 0.0013315579227696406,
#              ('happening', 'and'): 0.2,
#              ('and', 'so'): 0.004817618719889883,
#              ('so', 'leave'): 0.00273224043715847,
#              ('leave', 'me'): 0.35714285714285715,
#              ('me', 'feeling'): 0.031413612565445025,
#              ('feeling', 'disturbed'): 0.0012594458438287153,
#              ('disturbed', 'i'): 0.125,
#              ('i', '$'): 0.0013196093956188968,
#              ('i', 'was'): 0.05304829770387965,
#              ('was', 'feeling'): 0.17699115044247787,
#              ('feeling', 'groggy'): 0.0025188916876574307,
#              ('groggy', 'and'): 0.125,
#              ('and', 'super'): 0.0013764624913971094,
#              ('super', 'tired'): 0.2,
#              ('tired', 'during'): 0.1111111111111111,
#              ('during', 'most'): 0.1,
#              ('most', 'of'): 0.23076923076923078,
#              ('of', 'the'): 0.14913448735019974,
#              ('the', 'fall'): 0.0015661707126076742,
#              ('fall', 'we'): 0.16666666666666666,
#              ('we', 'ended'): 0.012048192771084338,
#              ('ended', 'up'): 1.0,
#              ('up', 'staying'): 0.007194244604316547,
#              ('staying', 'home'): 0.25,
#              ('home', 'for'): 0.06451612903225806,
#              ('for', 'thanksgiving'): 0.00516795865633075,
#              ('thanksgiving', 'instead'): 0.5,
#              ('instead', 'of'): 0.5,
#              ('of', 'making'): 0.0013315579227696406,
#              ('making', 'the'): 0.13636363636363635,
#              ('the', 'hour'): 0.0007830853563038371,
#              ('hour', 'trip'): 0.14285714285714285,
#              ('trip', 'to'): 0.75,
#              ('see', 'jimmys'): 0.022222222222222223,
#              ('jimmys', 'family'): 1.0,
#              ('family', '$'): 0.10810810810810811,
#              ('very', 'awkward'): 0.008,
#              ('awkward', '$'): 0.42857142857142855,
#              ('i', 'havent'): 0.003167062549485352,
#              ('havent', 'been'): 0.25,
#              ('been', 'like'): 0.008771929824561403,
#              ('like', 'that'): 0.03023758099352052,
#              ('that', 'lately'): 0.001256281407035176,
#              ('lately', 'and'): 0.14285714285714285,
#              ('and', 'i'): 0.10874053682037164,
#              ('i', 'am'): 0.07732911058326736,
#              ('am', 'seriously'): 0.0032258064516129032,
#              ('seriously', 'feeling'): 0.16666666666666666,
#              ('feeling', 'depressed'): 0.0025188916876574307,
#              ('depressed', 'about'): 0.09090909090909091,
#              ('about', 'it'): 0.12751677852348994,
#              ('it', '$'): 0.12233009708737864,
#              ('feel', 'it'): 0.009773976786805132,
#              ('it', 'is'): 0.06796116504854369,
#              ('is', 'unfortunate'): 0.0030303030303030303,
#              ('unfortunate', 'that'): 0.25,
#              ('that', 'i'): 0.20603015075376885,
#              ('i', 'have'): 0.03774082871470045,
#              ('have', 'had'): 0.023178807947019868,
#              ('had', 'to'): 0.10204081632653061,
#              ('to', 'take'): 0.008955223880597015,
#              ('take', 'these'): 0.03225806451612903,
#              ('these', 'drastic'): 0.014492753623188406,
#              ('drastic', 'measures'): 1.0,
#              ('measures', 'and'): 0.5,
#              ('and', 'post'): 0.0006882312456985547,
#              ('post', 'this'): 0.07142857142857142,
#              ('this', 'notice'): 0.003257328990228013,
#              ('notice', 'as'): 0.14285714285714285,
#              ('as', 'i'): 0.20168067226890757,
#              ('i', 'truly'): 0.0013196093956188968,
#              ('truly', 'loved'): 0.09090909090909091,
#              ('loved', 'posting'): 0.038461538461538464,
#              ('posting', 'my'): 0.25,
#              ('my', 'new'): 0.006230529595015576,
#              ('new', 'work'): 0.05405405405405406,
#              ('work', 'to'): 0.021739130434782608,
#              ('to', 'flickr'): 0.0007462686567164179,
#              ('flickr', 'and'): 1.0,
#              ('and', 'interacting'): 0.0006882312456985547,
#              ('interacting', 'with'): 1.0,
#              ('with', 'new'): 0.003257328990228013,
#              ('new', 'people'): 0.02702702702702703,
#              ('people', 'from'): 0.017699115044247787,
#              ('from', 'all'): 0.02586206896551724,
#              ('all', 'over'): 0.0223463687150838,
#              ('over', 'the'): 0.11290322580645161,
#              ('the', 'world'): 0.011746280344557557,
#              ('world', '$'): 0.30434782608695654,
#              ('i', 'still'): 0.011612562681446292,
#              ('still', 'feel'): 0.22115384615384615,
#              ('feel', 'disappointed'): 0.0006108735491753207,
#              ('disappointed', 'though'): 0.125,
#              ('though', '$'): 0.05,
#              ('i', 'thought'): 0.00422275006598047,
#              ('thought', 'i'): 0.22580645161290322,
#              ('i', 'exhausted'): 0.0002639218791237794,
#              ('exhausted', 'all'): 0.25,
#              ('all', 'emotions'): 0.00558659217877095,
#              ('emotions', 'i'): 0.18181818181818182,
#              ('i', 'held'): 0.0002639218791237794,
#              ('held', 'all'): 1.0,
#              ('all', 'the'): 0.18435754189944134,
#              ('the', 'frustration'): 0.0007830853563038371,
#              ('frustration', 'and'): 1.0,
#              ('and', 'confusion'): 0.0006882312456985547,
#              ('confusion', 'and'): 0.5,
#              ('and', 'still'): 0.0020646937370956643,
#              ('still', 'here'): 0.019230769230769232,
#              ('am', 'having'): 0.0064516129032258064,
#              ('having', 'so'): 0.05405405405405406,
#              ('so', 'much'): 0.06557377049180328,
#              ('much', 'more'): 0.09333333333333334,
#              ('more', 'to'): 0.016129032258064516,
#              ('to', 'give'): 0.008955223880597015,
#              ('give', 'so'): 0.038461538461538464,
#              ('to', 'feel'): 0.08507462686567165,
#              ('feel', 'i'): 0.011606597434331093,
#              ('i', 'look'): 0.002903140670361573,
#              ('look', 'at'): 0.42105263157894735,
#              ('at', 'this'): 0.05416666666666667,
#              ('this', 'blank'): 0.003257328990228013,
#              ('blank', 'white'): 0.2,
#              ('white', 'piece'): 0.25,
#              ('piece', 'of'): 0.8,
#              ('of', 'paper'): 0.002663115845539281,
#              ('paper', 'and'): 0.25,
#              ('i', 'want'): 0.012668250197941409,
#              ('want', 'to'): 0.7358490566037735,
#              ('to', 'fill'): 0.0014925373134328358,
#              ('fill', 'it'): 0.5,
#              ('it', 'with'): 0.003883495145631068,
#              ('with', 'colours'): 0.003257328990228013,
#              ('colours', 'with'): 0.6666666666666666,
#              ('with', 'motion'): 0.003257328990228013,
#              ('motion', 'but'): 1.0,
#              ('but', 'it'): 0.07736389684813753,
#              ('it', 'still'): 0.009708737864077669,
#              ('still', 'seems'): 0.009615384615384616,
#              ('seems', 'so'): 0.11764705882352941,
#              ('so', 'blank'): 0.00273224043715847,
#              ('blank', '$'): 0.2,
#              ('i', 'left'): 0.0013196093956188968,
#              ('left', 'the'): 0.08823529411764706,
#              ('the', 'place'): 0.0023492560689115116,
#              ('place', 'feeling'): 0.09090909090909091,
#              ('feeling', 'heartbroken'): 0.0012594458438287153,
#              ('heartbroken', '$'): 0.42857142857142855,
#              ('i', 'didnt'): 0.011084718923198733,
#              ('didnt', 'respond'): 0.018867924528301886,
#              ('respond', 'because'): 1.0,
#              ('because', 'i'): 0.3442622950819672,
#              ('feel', 'that'): 0.04886988393402566,
#              ('that', 'some'): 0.0037688442211055275,
#              ('some', 'days'): 0.020618556701030927,
#              ('days', 'i'): 0.14705882352941177,
#              ('i', 'cant'): 0.00791765637371338,
#              ('cant', 'just'): 0.02702702702702703,
#              ('just', 'put'): 0.004424778761061947,
#              ('put', 'on'): 0.10526315789473684,
#              ('on', 'a'): 0.0847457627118644,
#              ('a', 'fake'): 0.0032751091703056767,
#              ('fake', 'smile'): 0.16666666666666666,
#              ('smile', 'and'): 0.4166666666666667,
#              ('and', 'pretend'): 0.0006882312456985547,
#              ('pretend', 'like'): 0.3333333333333333,
#              ('like', 'life'): 0.008639308855291577,
#              ('life', 'is'): 0.11458333333333333,
#              ('is', 'great'): 0.00909090909090909,
#              ('great', 'and'): 0.08333333333333333,
#              ('and', 'not'): 0.011011699931176875,
#              ('not', 'let'): 0.0035842293906810036,
#              ('let', 'the'): 0.07407407407407407,
#              ('the', 'negativity'): 0.0007830853563038371,
#              ('negativity', 'creep'): 1.0,
#              ('creep', 'in'): 0.5,
#              ('in', '$'): 0.007858546168958742,
#              ('really', 'thought'): 0.012738853503184714,
#              ('was', 'ok'): 0.0058997050147492625,
#              ('ok', 'with'): 0.2222222222222222,
#              ('with', 'how'): 0.006514657980456026,
#              ('how', 'things'): 0.009009009009009009,
#              ('things', 'are'): 0.05970149253731343,
#              ('are', 'but'): 0.007575757575757576,
#              ('but', 'here'): 0.0028653295128939827,
#              ('am', 'out'): 0.0032258064516129032,
#              ('out', 'of'): 0.25663716814159293,
#              ('of', 'no'): 0.002663115845539281,
#              ('no', 'where'): 0.027777777777777776,
#              ('where', 'crying'): 0.029411764705882353,
#              ('crying', 'and'): 0.25,
#              ('and', 'feeling'): 0.021335168616655197,
#              ('feeling', 'empty'): 0.0012594458438287153,
#              ('empty', 'and'): 0.2222222222222222,
#              ('and', 'sorry'): 0.0013764624913971094,
#              ('sorry', 'for'): 0.8181818181818182,
#              ('for', 'myself'): 0.025839793281653745,
#              ('myself', 'shame'): 0.008403361344537815,
#              ('shame', 'on'): 0.5,
#              ('on', 'me'): 0.01694915254237288,
#              ('me', '$'): 0.1649214659685864,
#              ('feel', 'like'): 0.1508857666463042,
#              ('like', 'it'): 0.038876889848812095,
#              ('it', 'dirty'): 0.001941747572815534,
#              ('dirty', 'src'): 0.5,
#              ('src', 'http'): 0.8333333333333334,
#              ('http', 'i'): 0.03333333333333333,
#              ('i', 'stop'): 0.0005278437582475588,
#              ('stop', 'feeling'): 0.2857142857142857,
#              ('feeling', 'so'): 0.0327455919395466,
#              ('so', 'depressed'): 0.00546448087431694,
#              ('depressed', 'and'): 0.2727272727272727,
#              ('and', '$'): 0.0020646937370956643,
#              ('im', 'just'): 0.019753086419753086,
#              ('just', 'feeling'): 0.03982300884955752,
#              ('feeling', 'really'): 0.017632241813602016,
#              ('really', 'shitty'): 0.006369426751592357,
#              ('shitty', 'about'): 0.18181818181818182,
#              ('about', 'life'): 0.016778523489932886,
#              ('life', 'in'): 0.041666666666666664,
#              ('in', 'general'): 0.011787819253438114,
#              ('general', 'now'): 0.16666666666666666,
#              ('now', 'that'): 0.04597701149425287,
#              ('to', 'just'): 0.0052238805970149255,
#              ('just', 'write'): 0.004424778761061947,
#              ('write', 'continuously'): 0.09090909090909091,
#              ('continuously', '$'): 1.0,
#              ('didnt', 'used'): 0.018867924528301886,
#              ('used', 'to'): 0.7222222222222222,
#              ('so', 'defective'): 0.00273224043715847,
#              ('defective', 'when'): 1.0,
#              ('when', 'younger'): 0.0043859649122807015,
#              ('younger', 'yet'): 0.2,
#              ('yet', 'i'): 0.16666666666666666,
#              ('i', 'did'): 0.00844550013196094,
#              ('did', 'sometimes'): 0.02,
#              ('sometimes', '$'): 0.12195121951219512,
#              ('feel', 'discouraged'): 0.0030543677458766036,
#              ('discouraged', 'why'): 0.1111111111111111,
#              ('why', 'should'): 0.043478260869565216,
#              ('should', 'the'): 0.02,
#              ('the', 'shadows'): 0.0007830853563038371,
#              ('shadows', 'come'): 1.0,
#              ('come', 'why'): 0.03333333333333333,
#              ('should', 'my'): 0.02,
#              ('my', 'heart'): 0.018691588785046728,
#              ('heart', 'be'): 0.05,
#              ('be', 'lonely'): 0.0036363636363636364,
#              ('lonely', 'and'): 0.1111111111111111,
#              ('and', 'long'): 0.0006882312456985547,
#              ('long', 'for'): 0.04,
#              ('for', 'heaven'): 0.002583979328165375,
#              ('heaven', 'heaven'): 0.3333333333333333,
#              ('heaven', 'and'): 0.6666666666666666,
#              ('and', 'home'): 0.0013764624913971094,
#              ('home', 'when'): 0.06451612903225806,
#              ('when', 'when'): 0.0043859649122807015,
#              ('when', 'jesus'): 0.0043859649122807015,
#              ('jesus', 'is'): 0.3333333333333333,
#              ('is', 'my'): 0.02727272727272727,
#              ('my', 'portion'): 0.001557632398753894,
#              ('portion', 'my'): 1.0,
#              ('my', 'constant'): 0.001557632398753894,
#              ('constant', 'friend'): 0.14285714285714285,
#              ('friend', 'is'): 0.08333333333333333,
#              ('is', 'he'): 0.0030303030303030303,
#              ('he', 'oh'): 0.009523809523809525,
#              ('oh', 'his'): 0.125,
#              ('his', 'eye'): 0.015384615384615385,
#              ('eye', 'is'): 0.16666666666666666,
#              ('is', 'on'): 0.00909090909090909,
#              ('on', 'the'): 0.19915254237288135,
#              ('the', 'sparrow'): 0.0007830853563038371,
#              ('sparrow', 'and'): 1.0,
#              ('i', 'know'): 0.018210609659540775,
#              ('know', 'he'): 0.014184397163120567,
#              ('he', 'watches'): 0.009523809523809525,
#              ('watches', 'watches'): 0.3333333333333333,
#              ('watches', 'it'): 0.3333333333333333,
#              ('it', 'over'): 0.001941747572815534,
#              ('over', 'me'): 0.04838709677419355,
#              ('i', 'do'): 0.01583531274742676,
#              ('do', 'this'): 0.02040816326530612,
#              ('this', 'if'): 0.003257328990228013,
#              ('if', 'i'): 0.373134328358209,
#              ('i', 'allow'): 0.0002639218791237794,
#              ('allow', 'myself'): 0.5,
#              ('myself', 'to'): 0.04201680672268908,
#              ('to', 'sit'): 0.002238805970149254,
#              ('sit', 'in'): 0.25,
#              ('in', 'this'): 0.043222003929273084,
#              ('this', 'cycle'): 0.003257328990228013,
#              ('cycle', 'today'): 0.5,
#              ('today', 'i'): 0.1111111111111111,
#              ('i', 'will'): 0.00870942201108472,
#              ('will', 'cause'): 0.009174311926605505,
#              ('cause', 'a'): 0.07692307692307693,
#              ('a', 'nasty'): 0.001091703056768559,
#              ('nasty', 'big'): 0.5,
#              ('big', 'blow'): 0.07692307692307693,
#              ('blow', 'up'): 1.0,
#              ('up', 'fight'): 0.007194244604316547,
#              ('fight', 'in'): 0.1111111111111111,
#              ('in', 'public'): 0.003929273084479371,
#              ('public', 'and'): 0.5,
#              ('will', 'feel'): 0.11009174311926606,
#              ('feel', 'humiliated'): 0.0012217470983506415,
#              ('humiliated', 'and'): 0.5,
#              ('and', 'proven'): 0.0006882312456985547,
#              ('proven', 'right'): 1.0,
#              ('right', 'that'): 0.02127659574468085,
#              ('am', 'an'): 0.0032258064516129032,
#              ('an', 'unstable'): 0.013888888888888888,
#              ('unstable', 'bad'): 1.0,
#              ('bad', 'person'): 0.08695652173913043,
#              ('person', '$'): 0.19230769230769232,
#              ('feel', 'victimized'): 0.0006108735491753207,
#              ('victimized', 'by'): 0.3333333333333333,
#              ('by', 'the'): 0.21686746987951808,
#              ('the', 'drag'): 0.0007830853563038371,
#              ('drag', 'on'): 0.5,
#              ('on', 'our'): 0.00847457627118644,
#              ('our', 'country'): 0.022222222222222223,
#              ('country', 'with'): 0.2,
#              ('with', 'heads'): 0.003257328990228013,
#              ('heads', 'in'): 1.0,
#              ('in', 'the'): 0.206286836935167,
#              ('the', 'sand'): 0.0015661707126076742,
#              ('sand', 'traditionalists'): 0.5,
#              ('traditionalists', 'i'): 1.0,
#              ('i', 'hesitate'): 0.0002639218791237794,
#              ('hesitate', 'to'): 1.0,
#              ('to', 'call'): 0.0037313432835820895,
#              ('call', 'them'): 0.21428571428571427,
#              ('them', 'conservatives'): 0.009433962264150943,
#              ('conservatives', 'for'): 0.5,
#              ('for', 'fear'): 0.002583979328165375,
#              ('fear', 'of'): 0.375,
#              ('of', 'offending'): 0.0013315579227696406,
#              ('offending', 'real'): 1.0,
#              ('real', 'honest'): 0.07692307692307693,
#              ('honest', 'to'): 0.25,
#              ('to', 'god'): 0.0007462686567164179,
#              ('god', 'conservatives'): 0.05,
#              ('conservatives', 'who'): 0.5,
#              ('who', 'still'): 0.011494252873563218,
#              ('still', 'think'): 0.009615384615384616,
#              ('think', 'the'): 0.04395604395604396,
#              ('world', 'was'): 0.043478260869565216,
#              ('was', 'created'): 0.0029498525073746312,
#              ('created', 'years'): 0.25,
#              ('years', 'ago'): 0.1111111111111111,
#              ('ago', 'and'): 0.125,
#              ('and', 'that'): 0.014452856159669649,
#              ('that', 'stuff'): 0.001256281407035176,
#              ('stuff', 'like'): 0.13333333333333333,
#              ('like', 'skeletal'): 0.0021598272138228943,
#              ('skeletal', 'remains'): 1.0,
#              ('remains', 'are'): 0.5,
#              ('are', 'some'): 0.007575757575757576,
#              ('some', 'kind'): 0.030927835051546393,
#              ('kind', 'of'): 0.7931034482758621,
#              ('of', 'hoax'): 0.0013315579227696406,
#              ('hoax', '$'): 1.0,
#              ('i', 'need'): 0.005278437582475587,
#              ('need', 'to'): 0.8103448275862069,
#              ('to', 'find'): 0.008208955223880597,
#              ('find', 'a'): 0.2,
#              ('a', 'way'): 0.012008733624454149,
#              ('way', 'to'): 0.11363636363636363,
#              ('to', 'get'): 0.02164179104477612,
#              ('get', 'over'): 0.028846153846153848,
#              ('over', 'this'): 0.016129032258064516,
#              ('this', 'yet'): 0.003257328990228013,
#              ('feel', 'hopeless'): 0.0018326206475259622,
#              ('hopeless', '$'): 0.3333333333333333,
#              ('was', 'going'): 0.029498525073746312,
#              ('going', 'to'): 0.5974025974025974,
#              ('to', 'say'): 0.014179104477611941,
#              ('say', 'that'): 0.16326530612244897,
#              ('that', 'it'): 0.03015075376884422,
#              ('it', 'makes'): 0.02912621359223301,
#              ('makes', 'me'): 0.575,
#              ('feel', 'all'): 0.004276114844227245,
#              ('all', 'unloved'): 0.00558659217877095,
#              ('unloved', 'and'): 0.42857142857142855,
#              ('and', 'shit'): 0.0006882312456985547,
#              ('shit', 'but'): 0.25,
#              ('but', 'thats'): 0.014326647564469915,
#              ('thats', 'just'): 0.038461538461538464,
#              ('just', 'me'): 0.01327433628318584,
#              ('me', 'being'): 0.005235602094240838,
#              ('being', 'overly'): 0.011627906976744186,
#              ('overly', 'dramatic'): 0.25,
#              ('dramatic', '$'): 0.5,
#              ('feeling', 'pretty'): 0.017632241813602016,
#              ('pretty', 'low'): 0.02040816326530612,
#              ('low', 'about'): 0.1,
#              ('about', 'that'): 0.013422818791946308,
#              ('that', 'but'): 0.005025125628140704,
#              ('but', 'joan'): 0.0028653295128939827,
#              ('joan', 'saw'): 1.0,
#              ('saw', 'my'): 0.14285714285714285,
#              ('my', 'disappointment'): 0.001557632398753894,
#              ('disappointment', 'and'): 0.3333333333333333,
#              ('and', 'lifted'): 0.0006882312456985547,
#              ('lifted', 'my'): 1.0,
#              ('my', 'spirit'): 0.003115264797507788,
#              ('spirit', 'with'): 0.2,
#              ('with', 'corinthians'): 0.003257328990228013,
#              ('corinthians', '$'): 1.0,
#              ('im', 'not'): 0.08888888888888889,
#              ('not', 'trying'): 0.0035842293906810036,
#              ('trying', 'to'): 0.7741935483870968,
#              ('to', 'sound'): 0.0007462686567164179,
#              ('sound', 'so'): 0.25,
#              ('depressed', 'or'): 0.18181818181818182,
#              ('or', 'sad'): 0.010638297872340425,
#              ('sad', 'or'): 0.08333333333333333,
#              ('or', 'heartbroken'): 0.005319148936170213,
#              ('heartbroken', 'but'): 0.14285714285714285,
#              ('but', 'feeling'): 0.017191977077363897,
#              ('feeling', 'all'): 0.010075566750629723,
#              ('all', 'shitty'): 0.00558659217877095,
#              ('shitty', 'once'): 0.09090909090909091,
#              ('once', 'in'): 0.08333333333333333,
#              ('in', 'a'): 0.11198428290766209,
#              ('a', 'while'): 0.010917030567685589,
#              ('while', 'is'): 0.037037037037037035,
#              ('is', 'just'): 0.030303030303030304,
#              ('just', 'human'): 0.004424778761061947,
#              ('human', '$'): 0.5,
#              ('am', 'feeling'): 0.2709677419354839,
#              ('feeling', 'a'): 0.08690176322418136,
#              ('little', 'groggy'): 0.017857142857142856,
#              ('groggy', 'this'): 0.125,
#              ('this', 'morning'): 0.029315960912052116,
#              ('morning', 'not'): 0.0625,
#              ('not', 'to'): 0.02867383512544803,
#              ('to', 'mention'): 0.0014925373134328358,
#              ('mention', 'a'): 0.1111111111111111,
#              ('a', 'headache'): 0.001091703056768559,
#              ('headache', '$'): 1.0,
#              ('feeling', 'extremely'): 0.011335012594458438,
#              ('extremely', 'shitty'): 0.0625,
#              ('shitty', 'physically'): 0.09090909090909091,
#              ('physically', 'this'): 0.25,
#              ('morning', '$'): 0.375,
#              ('like', 'i'): 0.19438444924406048,
#              ('am', 'being'): 0.012903225806451613,
#              ('being', 'punished'): 0.011627906976744186,
#              ('punished', 'for'): 0.25,
#              ('for', 'something'): 0.007751937984496124,
#              ('something', 'that'): 0.16279069767441862,
#              ('i', 'didn'): 0.00395882818685669,
#              ('didn', 't'): 1.0,
#              ('t', 'even'): 0.03676470588235294,
#              ('even', 'do'): 0.012658227848101266,
#              ('do', '$'): 0.08163265306122448,
#              ('have', 'to'): 0.11258278145695365,
#              ('to', 'start'): 0.005970149253731343,
#              ('start', 'taking'): 0.037037037037037035,
#              ('taking', 'it'): 0.0625,
#              ('it', 'more'): 0.003883495145631068,
#              ('more', 'seriously'): 0.008064516129032258,
#              ('seriously', 'but'): 0.16666666666666666,
#              ('but', 'i'): 0.29512893982808025,
#              ('i', 'm'): 0.015571390868302983,
#              ('m', 'already'): 0.01694915254237288,
#              ('already', 'exhausted'): 0.03571428571428571,
#              ('exhausted', '$'): 0.25,
#              ('am', 'not'): 0.07419354838709677,
#              ('not', 'working'): 0.0035842293906810036,
#              ('working', 'i'): 0.09090909090909091,
#              ('i', 'can'): 0.022433359725521247,
#              ('can', 'cope'): 0.007352941176470588,
#              ('cope', 'with'): 1.0,
#              ('with', 'but'): 0.003257328990228013,
#              ('but', 'days'): 0.0028653295128939827,
#              ('days', 'like'): 0.029411764705882353,
#              ('like', 'today'): 0.0021598272138228943,
#              ('today', 'when'): 0.027777777777777776,
#              ('when', 'i'): 0.4517543859649123,
#              ('am', 'i'): 0.01935483870967742,
#              ('just', 'feel'): 0.09292035398230089,
#              ('feel', 'awful'): 0.0018326206475259622,
#              ('awful', '$'): 0.375,
#              ('the', 'hospital'): 0.0015661707126076742,
#              ('hospital', 'that'): 0.3333333333333333,
#              ('that', 'night'): 0.001256281407035176,
#              ('night', 'feeling'): 0.05,
#              ('feeling', 'helpless'): 0.006297229219143577,
#              ('helpless', '$'): 0.2,
#              ('feel', 'a'): 0.03726328649969456,
#              ('a', 'lot'): 0.02947598253275109,
#              ('lot', 'of'): 0.39285714285714285,
#              ('of', 'this'): 0.022636484687083888,
#              ('this', 'almost'): 0.003257328990228013,
#              ('almost', 'every'): 0.047619047619047616,
#              ('every', 'day'): 0.24242424242424243,
#              ('day', 'and'): 0.11666666666666667,
#              ('and', 'it'): 0.02202339986235375,
#              ('it', 'does'): 0.011650485436893204,
#              ('does', 'hurt'): 0.045454545454545456,
#              ('hurt', 'so'): 0.09090909090909091,
#              ('so', 'this'): 0.00819672131147541,
#              ('this', 'blog'): 0.016286644951140065,
#              ('blog', 'is'): 0.1111111111111111,
#              ('is', 'very'): 0.012121212121212121,
#              ('very', 'timely'): 0.008,
#              ('timely', '$'): 1.0,
#              ('i', 'miss'): 0.0018474531538664556,
#              ('miss', 'not'): 0.09090909090909091,
#              ('not', 'feeling'): 0.06810035842293907,
#              ('feeling', 'guilt'): 0.0012594458438287153,
#              ('guilt', 'over'): 0.3333333333333333,
#              ('over', 'so'): 0.016129032258064516,
#              ('much', 'stuff'): 0.02666666666666667,
#              ('stuff', 'because'): 0.06666666666666667,
#              ('i', 'reacted'): 0.0002639218791237794,
#              ('reacted', 'in'): 1.0,
#              ('a', 'terrible'): 0.0032751091703056767,
#              ('terrible', 'way'): 0.25,
#              ('way', 'or'): 0.022727272727272728,
#              ('or', 'said'): 0.010638297872340425,
#              ('said', 'no'): 0.07142857142857142,
#              ('no', 'to'): 0.027777777777777776,
#              ('to', 'my'): 0.01791044776119403,
#              ('my', 'kids'): 0.006230529595015576,
#              ('kids', 'just'): 0.0625,
#              ('just', 'for'): 0.004424778761061947,
#              ('for', 'the'): 0.11627906976744186,
#              ('the', 'sake'): 0.0007830853563038371,
#              ('sake', 'of'): 1.0,
#              ('of', 'saying'): 0.0013315579227696406,
#              ('saying', 'no'): 0.06666666666666667,
#              ('no', '$'): 0.041666666666666664,
#              ('am', 'excited'): 0.0064516129032258064,
#              ('excited', 'to'): 0.2857142857142857,
#              ('to', 'be'): 0.09328358208955224,
#              ('be', 'introduced'): 0.0036363636363636364,
#              ('introduced', 'to'): 0.5,
#              ('to', 'a'): 0.010447761194029851,
#              ('a', 'new'): 0.0054585152838427945,
#              ('new', 'kind'): 0.02702702702702703,
#              ('of', 'library'): 0.0013315579227696406,
#              ('library', 'environment'): 0.5,
#              ('environment', 'but'): 0.2,
#              ('but', 'at'): 0.02005730659025788,
#              ('at', 'the'): 0.2625,
#              ('the', 'same'): 0.014095536413469069,
#              ('same', 'time'): 0.47619047619047616,
#              ('time', 'i'): 0.13333333333333333,
#              ('feeling', 'stressed'): 0.003778337531486146,
#              ('stressed', 'about'): 0.07142857142857142,
#              ('it', 'because'): 0.009708737864077669,
#              ('because', 'it'): 0.07650273224043716,
#              ('it', 'means'): 0.001941747572815534,
#              ('means', 'that'): 0.3333333333333333,
#              ('not', 'really'): 0.025089605734767026,
#              ('really', 'getting'): 0.006369426751592357,
#              ('getting', 'a'): 0.11363636363636363,
#              ('a', 'holiday'): 0.002183406113537118,
#              ('holiday', '$'): 0.375,
#              ('i', 'dont'): 0.013987859593560307,
#              ('dont', 'think'): 0.07142857142857142,
#              ('think', 'thats'): 0.01098901098901099,
#              ('thats', 'what'): 0.11538461538461539,
#              ('what', 'ill'): 0.008,
#              ('ill', 'do'): 0.043478260869565216,
#              ('do', 'because'): 0.006802721088435374,
#              ('feel', 'its'): 0.005497861942577886,
#              ('its', 'just'): 0.044642857142857144,
#              ('just', 'really'): 0.017699115044247787,
#              ('really', 'awkward'): 0.006369426751592357,
#              ('was', 'devestated'): 0.0029498525073746312,
#              ('devestated', 'would'): 1.0,
#              ('would', 'be'): 0.26732673267326734,
#              ('a', 'grave'): 0.001091703056768559,
#              ('grave', 'disservice'): 1.0,
#              ('disservice', 'to'): 1.0,
#              ('my', 'feelings'): 0.020249221183800622,
#              ('feelings', 'as'): 0.02040816326530612,
#              ('can', 'never'): 0.014705882352941176,
#              ('never', 'recall'): 0.034482758620689655,
#              ('recall', 'being'): 0.3333333333333333,
#              ('being', 'quite'): 0.011627906976744186,
#              ('quite', 'so'): 0.043478260869565216,
#              ('so', 'heartbroken'): 0.00273224043715847,
#              ('heartbroken', 'again'): 0.14285714285714285,
#              ('again', 'in'): 0.05555555555555555,
#              ('in', 'my'): 0.11787819253438114,
#              ('my', 'life'): 0.059190031152647975,
#              ('life', '$'): 0.17708333333333334,
#              ('so', 'worthless'): 0.00273224043715847,
#              ('worthless', 'and'): 0.5,
#              ('and', 'ugly'): 0.0006882312456985547,
#              ('ugly', 'a'): 0.16666666666666666,
#              ('a', 'href'): 0.025109170305676855,
#              ('http', 'afaerytaleinmakebelieve'): 0.03333333333333333,
#              ('afaerytaleinmakebelieve', '$'): 1.0,
#              ('im', 'feeling'): 0.32098765432098764,
#              ('little', 'melancholy'): 0.026785714285714284,
#              ('melancholy', 'tonight'): 0.2,
#              ('tonight', 'kinda'): 0.08333333333333333,
#              ('kinda', 'like'): 0.08333333333333333,
#              ('like', 'the'): 0.04967602591792657,
#              ('the', 'paint'): 0.0007830853563038371,
#              ('paint', 'on'): 0.3333333333333333,
#              ('on', 'this'): 0.03389830508474576,
#              ('this', 'door'): 0.003257328990228013,
#              ('door', '$'): 0.5,
#              ('$', 'ive'): 0.017916666666666668,
#              ('ive', 'been'): 0.37777777777777777,
#              ('been', 'feeling'): 0.2719298245614035,
#              ('feeling', 'needy'): 0.0025188916876574307,
#              ('needy', 'lately'): 0.16666666666666666,
#              ('lately', '$'): 0.3333333333333333,
#              ('i', 'wound'): 0.0002639218791237794,
#              ('wound', 'up'): 0.75,
#              ('up', 'driving'): 0.007194244604316547,
#              ('driving', 'to'): 0.5,
#              ('to', 'him'): 0.004477611940298508,
#              ('him', 'getting'): 0.023809523809523808,
#              ('getting', 'butterflies'): 0.022727272727272728,
#              ('butterflies', 'like'): 0.5,
#              ('like', 'a'): 0.1079913606911447,
#              ('a', 'teenager'): 0.001091703056768559,
#              ('teenager', 'when'): 0.3333333333333333,
#              ('when', 'we'): 0.039473684210526314,
#              ('we', 'kissed'): 0.012048192771084338,
#              ('kissed', 'then'): 1.0,
#              ('then', 'feeling'): 0.09090909090909091,
#              ('feeling', 'rotten'): 0.0012594458438287153,
#              ('rotten', 'for'): 0.3333333333333333,
#              ('for', 'a'): 0.08785529715762273,
#              ('a', 'week'): 0.007641921397379912,
#              ('week', 'after'): 0.045454545454545456,
#              ('after', 'expecting'): 0.02,
#              ('expecting', 'him'): 0.25,
#              ('him', 'to'): 0.07142857142857142,
#              ('call', '$'): 0.07142857142857142,
#              ('feel', 'sad'): 0.0030543677458766036,
#              ('sad', 'when'): 0.041666666666666664,
#              ('i', 'see'): 0.003430984428609132,
#              ('see', 'your'): 0.044444444444444446,
#              ('your', 'son'): 0.016129032258064516,
#              ('son', 'uhuru'): 0.2,
#              ('uhuru', 'being'): 1.0,
#              ('being', 'persecuted'): 0.011627906976744186,
#              ('persecuted', 'by'): 0.5,
#              ('by', 'men'): 0.006024096385542169,
#              ('men', 'of'): 0.1111111111111111,
#              ('of', 'ill'): 0.0013315579227696406,
#              ('ill', 'will'): 0.043478260869565216,
#              ('will', 'and'): 0.009174311926605505,
#              ('and', 'a'): 0.011011699931176875,
#              ('a', 'woman'): 0.002183406113537118,
#              ('woman', 'martha'): 0.08333333333333333,
#              ('martha', 'karua'): 1.0,
#              ('karua', 'is'): 1.0,
#              ('is', 'carrying'): 0.0030303030303030303,
#              ('carrying', 'their'): 1.0,
#              ('their', 'bags'): 0.017543859649122806,
#              ('bags', '$'): 1.0,
#              ('feel', 'most'): 0.0018326206475259622,
#              ('most', 'unwelcome'): 0.02564102564102564,
#              ('unwelcome', '$'): 0.4,
#              ('i', 'often'): 0.003694906307732911,
#              ('often', 'look'): 0.04,
#              ('look', 'back'): 0.05263157894736842,
#              ('back', 'on'): 0.06779661016949153,
#              ('on', 'my'): 0.13135593220338984,
#              ('my', 'younger'): 0.001557632398753894,
#              ('younger', 'years'): 0.2,
#              ('years', 'and'): 0.14814814814814814,
#              ('feel', 'ashamed'): 0.0018326206475259622,
#              ('ashamed', 'of'): 0.2857142857142857,
#              ('the', 'things'): 0.008613938919342208,
#              ('things', 'i'): 0.07462686567164178,
#              ('have', 'done'): 0.009933774834437087,
#              ('done', '$'): 0.10526315789473684,
#              ('stressed', 'and'): 0.21428571428571427,
#              ('little', 'lonely'): 0.008928571428571428,
#              ('lonely', 'earlier'): 0.05555555555555555,
#              ('earlier', 'and'): 0.25,
#              ('and', 'now'): 0.0041293874741913286,
#              ('now', 'i'): 0.1839080459770115,
#              ('feel', 'stressed'): 0.0012217470983506415,
#              ('stressed', 'lonely'): 0.07142857142857142,
#              ('and', 'sick'): 0.0020646937370956643,
#              ('sick', '$'): 0.3333333333333333,
#              ('like', 'im'): 0.05399568034557235,
#              ('im', 'taking'): 0.0024691358024691358,
#              ('taking', 'care'): 0.0625,
#              ('care', 'of'): 0.2,
#              ('of', 'a'): 0.037283621837549935,
#              ('a', 'needy'): 0.001091703056768559,
#              ('needy', 'puppy'): 0.16666666666666666,
#              ('puppy', 'not'): 1.0,
#              ('not', 'living'): 0.0035842293906810036,
#              ('living', 'with'): 0.16666666666666666,
#              ('with', 'a'): 0.08469055374592833,
#              ('a', 'mother'): 0.0054585152838427945,
#              ('mother', '$'): 0.4166666666666667,
#              ('little', 'sentimental'): 0.008928571428571428,
#              ('sentimental', 'about'): 0.16666666666666666,
#              ('about', 'because'): 0.003355704697986577,
#              ('i', 'distinctly'): 0.0002639218791237794,
#              ('distinctly', 'remember'): 1.0,
#              ('remember', 'as'): 0.02702702702702703,
#              ('as', 'a'): 0.08823529411764706,
#              ('a', 'child'): 0.004366812227074236,
#              ('child', 'celebrating'): 0.125,
#              ('celebrating', 'my'): 0.25,
#              ('my', 'parents'): 0.003115264797507788,
#              ('parents', 'th'): 0.14285714285714285,
#              ('th', 'birthdays'): 1.0,
#              ('birthdays', 'and'): 1.0,
#              ('and', 'they'): 0.0041293874741913286,
#              ('they', 'seemed'): 0.009174311926605505,
#              ('seemed', 'so'): 0.4,
#              ('so', '$'): 0.01639344262295082,
#              ('been', 'having'): 0.017543859649122806,
#              ('having', 'trouble'): 0.05405405405405406,
#              ('trouble', 'sleeping'): 0.3333333333333333,
#              ('sleeping', 'my'): 0.3333333333333333,
#              ('my', 'anxiety'): 0.001557632398753894,
#              ('anxiety', 'is'): 0.25,
#              ('is', 'causing'): 0.00909090909090909,
#              ('causing', 'my'): 0.25,
#              ('my', 'social'): 0.001557632398753894,
#              ('life', 'to'): 0.03125,
#              ('to', 'suffer'): 0.0007462686567164179,
#              ('suffer', 'i'): 0.2,
#              ('i', 'lack'): 0.0002639218791237794,
#              ('lack', 'the'): 0.3333333333333333,
#              ('the', 'motivation'): 0.0007830853563038371,
#              ('motivation', 'that'): 1.0,
#              ('that', 'used'): 0.001256281407035176,
#              ('to', 'drive'): 0.002238805970149254,
#              ('drive', 'me'): 0.1111111111111111,
#              ('me', 'work'): 0.002617801047120419,
#              ('work', 'is'): 0.06521739130434782,
#              ('is', 'quickly'): 0.0030303030303030303,
#              ('quickly', 'becoming'): 0.25,
#              ('becoming', 'a'): 0.2,
#              ('a', 'chore'): 0.001091703056768559,
#              ('chore', 'where'): 1.0,
#              ('where', 'i'): 0.38235294117647056,
#              ('was', 'once'): 0.0029498525073746312,
#              ('once', 'satisfied'): 0.08333333333333333,
#              ('satisfied', 'and'): 0.2,
#              ('feel', 'dull'): 0.0006108735491753207,
#              ('dull', 'and'): 0.6,
#              ('and', 'uninteresting'): 0.0006882312456985547,
#              ('uninteresting', '$'): 1.0,
#              ('have', 'been'): 0.11920529801324503,
#              ('been', 'quite'): 0.008771929824561403,
#              ('quite', 'neglectful'): 0.021739130434782608,
#              ('neglectful', 'to'): 1.0,
#              ('my', 'blog'): 0.004672897196261682,
#              ('blog', 'and'): 0.1111111111111111,
#              ('and', 'am'): 0.0034411562284927736,
#              ('am', 'just'): 0.0064516129032258064,
#              ('just', 'to'): 0.022123893805309734,
#              ('that', 'we'): 0.016331658291457288,
#              ('we', 'are'): 0.1686746987951807,
#              ('are', 'here'): 0.007575757575757576,
#              ('here', 'alive'): 0.02702702702702703,
#              ('alive', 'and'): 0.2,
#              ('and', 'happy'): 0.004817618719889883,
#              ('happy', '$'): 0.2727272727272727,
#              ('m', 'worthless'): 0.01694915254237288,
#              ('can', 't'): 0.11029411764705882,
#              ('t', 'do'): 0.03676470588235294,
#              ('do', 'any'): 0.006802721088435374,
#              ('any', 'good'): 0.05,
#              ('good', 'for'): 0.03125,
#              ('for', 'anyone'): 0.00516795865633075,
#              ('anyone', 'even'): 0.04,
#              ('even', 'tought'): 0.012658227848101266,
#              ('tought', 'i'): 1.0,
#              ('i', 'try'): 0.003430984428609132,
#              ('try', 'and'): 0.13043478260869565,
#              ('and', 'try'): 0.0027529249827942187,
#              ('try', 'very'): 0.043478260869565216,
#              ...})

# %%
print("\nTop 5 Bigrams before Smoothing: ")
top_keys = sorted(bigram_model.bigramProbabilities, key=lambda k: bigram_model.bigramProbabilities[k], reverse=True)[:5]
for x in top_keys:
    print(x, bigram_model.bigramProbabilities[x])

print("\nTop 5 Bigrams after Laplace Smoothing: ")
top_keys = sorted(bigram_model.laplaceProbabilities, key=lambda k: bigram_model.laplaceProbabilities[k], reverse=True)[:5]
for x in top_keys:
    print(x, bigram_model.laplaceProbabilities[x])

print("\nTop 5 Bigrams after Kneser-Ney Smoothing: ")
top_keys = sorted(bigram_model.kneserneyProbabilities, key=lambda k: bigram_model.kneserneyProbabilities[k], reverse=True)[:5]
for x in top_keys:
    print(x, bigram_model.kneserneyProbabilities[x])
# Out:
# Top 5 Bigrams before Smoothing:
# ('href', 'http') 1.0
# ('mooshilu', '$') 1.0
# ('tychelle', 'to') 1.0
# ('hang', 'out') 1.0
# ('nonexistent', 'social') 1.0
#
# Top 5 Bigrams after Laplace Smoothing:
# ('$', 'i') 0.2693486590038314
# ('i', 'feel') 0.11042412409155006
# ('feel', 'like') 0.035092684307343996
# ('i', 'am') 0.03189066059225513
# ('$', 'im') 0.027203065134099615
#
# Top 5 Bigrams after Kneser-Ney Smoothing:
# ('don', 't') 0.970358782691682
# ('href', 'http') 0.9700023363576185
# ('didn', 't') 0.9583657827447011
# ('sort', 'of') 0.9565093900961343
# ('supposed', 'to') 0.9183832405280168
